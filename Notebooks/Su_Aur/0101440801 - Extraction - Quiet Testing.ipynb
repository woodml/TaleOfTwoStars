# %% [markdown]
# Environment: Observing
#
# Run: initialize_sas.bash

# %%
import sys
module_path = '/Users/woodml/Code/XMM_SAS/xmmsas_20230412_1735/lib/python' # or the path to your source code
sys.path.insert(0, module_path)
# %env SAS_PATH=/Users/woodml/Code/XMM_SAS/xmmsas_20230412_1735
from pysas.wrapper import Wrapper as w
import os
import os.path
from os import path
import numpy as np
from astropy.io import fits
from astropy.table import Table

from extraction_fcns import extract_lc, extract_spectrum, plot_LC, plot_region, plot_spectrum, rolling_median

import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from matplotlib.collections import PatchCollection
from matplotlib.patches import Circle
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Georgia']
rcParams['font.weight'] = 'bold'
rcParams['axes.labelweight'] = 'bold'
rcParams['axes.linewidth'] = 1
# Out:
# env: SAS_PATH=/Users/woodml/Code/XMM_SAS/xmmsas_20230412_1735

# %%
work_dir = '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/'
sas_file = '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/'

inargs = [f'sas_ccf={sas_file}ccf.cif', f'sas_odf={sas_file}0327_0101440801_SCX00000SUM.SAS', f'workdir={work_dir}']

w('startsas', inargs).run()
# Out:
# startsas - WARNING - Executing /Users/woodml/Code/XMM_SAS/xmmsas_20230412_1735/lib/python/pysas/startsas/startsas.py {'odfid': '', 'workdir': '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/', 'sasfiles': 'yes', 'sas_ccf': '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/ccf.cif', 'sas_odf': '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_SCX00000SUM.SAS', 'level': 'ODF', 'cifbuild_opts': '', 'odfingest_opts': ''}
# startsas - ERROR - Summary file PATH /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0101440801 does not exist.
#         Starting SAS session
#
#         Working directory = /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/
#
#
# SAS_CCF = /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/ccf.cif
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[9], line 6
#       2 sas_file = '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/'
#       4 inargs = [f'sas_ccf={sas_file}ccf.cif', f'sas_odf={sas_file}0327_0101440801_SCX00000SUM.SAS', f'workdir={work_dir}']
# ----> 6 w('startsas', inargs).run()
#
# File ~/Code/XMM_SAS/xmmsas_20230412_1735/lib/python/pysas/wrapper.py:49, in Wrapper.run(self)
#      47 t.readparfile()
#      48 t.processargs()
# ---> 49 t.runtask()
#
# File ~/Code/XMM_SAS/xmmsas_20230412_1735/lib/python/pysas/sastask.py:329, in MyTask.runtask(self)
#     327     return self.Exit
#     328 r = RunTask(self.taskname, self.iparsdic,self.logFile)
# --> 329 r.run()
#
# File ~/Code/XMM_SAS/xmmsas_20230412_1735/lib/python/pysas/runtask.py:94, in RunTask.run(self)
#      90 if self.taskname in pysaspkgs:
#      92     m = import_module('pysas.' + self.taskname + '.' + self.taskname)
# ---> 94     m.run(self.iparsdic)
#      96 else:
#      97     cmd = ''
#
# File ~/Code/XMM_SAS/xmmsas_20230412_1735/lib/python/pysas/startsas/startsas.py:479, in run(iparsdic)
#     477 if not os.path.exists(path):
#     478     logger.log('error', f'Summary file PATH {path} does not exist.')
# --> 479     raise Exception(f'Summary file PATH {path} does not exist.')
#     480 MANIFEST = glob.glob(os.path.join(path, 'MANIFEST*'))
#     481 if not os.path.exists(MANIFEST[0]):
#
# Exception: Summary file PATH /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0101440801 does not exist.

# %% [markdown]
# # LC's
# Plot LC's to get time limits.
# LC's extracted in the other notebook (Extraction.ipynb)

# %%
# Load 2002 Lightcurves
hdul = fits.open('/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/SUAur_0101440801_combined.lc')
lc = Table(hdul[1].data)
x = np.arange(hdul[1].header['TSTART'], hdul[1].header['TSTOP'], hdul[1].header['TIMEDEL'])
y = np.sum(lc['RATE'], 1)
y_err = np.sum(lc['ERROR'], 1)

hdul = fits.open('/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/SUAur_0101440801_combined_soft.lc')
lc_soft = Table(hdul[1].data)
x_soft = np.arange(hdul[1].header['TSTART'], hdul[1].header['TSTOP'], hdul[1].header['TIMEDEL'])
y_soft = np.sum(lc_soft['RATE'], 1)
y_err_soft = np.sum(lc_soft['ERROR'], 1)

hdul = fits.open('/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/SUAur_0101440801_combined_hard.lc')
lc_hard = Table(hdul[1].data)
x_hard = np.arange(hdul[1].header['TSTART'], hdul[1].header['TSTOP'], hdul[1].header['TIMEDEL'])
y_hard = np.sum(lc_hard['RATE'], 1)
y_err_hard = np.sum(lc_hard['ERROR'], 1)
# Out:
# /Users/woodml/anaconda3/envs/Observing/lib/python3.10/site-packages/numpy/core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)

# %%
# Plot all SU Aur LCs, 0101440801
x3 = np.array([np.median(x[i:i+3]) for i in range(0,len(x),3)])
y3 = np.array([np.sum(y[i:i+3]) for i in range(0,len(x),3)])
y_err3 = np.array([np.sum(y_err[i:i+3])/3 for i in range(0,len(x),3)])

xs3 = np.array([np.median(x_soft[i:i+3]) for i in range(0,len(x_soft),3)])
ys3 = np.array([np.sum(y_soft[i:i+3]) for i in range(0,len(x_soft),3)])
ys_err3 = np.array([np.sum(y_err_soft[i:i+3])/3 for i in range(0,len(x_soft),3)])

xh3 = np.array([np.median(x_hard[i:i+3]) for i in range(0,len(x_hard),3)])
yh3 = np.array([np.sum(y_hard[i:i+3]) for i in range(0,len(x_hard),3)])
yh_err3 = np.array([np.sum(y_err_hard[i:i+3])/3 for i in range(0,len(x_hard),3)])

ratio_err = 2/(yh3+ys3)**2 * np.sqrt(ys3**2*yh_err3**2 + yh3**2*ys_err3**2)

t0 = 117423319
t1 = 117446000  # first flare end
t2 = 117469000  # second flare start
t3 = 117493000  # second flare end
t4 = 117506000  # third flare start
t5 = 117526000  # third flare end
t_end = x3[-1]

plt.figure(figsize=(12,2.5))
plt.errorbar(x3, y3, yerr=y_err3, lw=0.5, ms=8, marker='.', markeredgecolor='k', markeredgewidth=.5, capsize=2, elinewidth=1.2, label='Combined')
plt.errorbar(xs3, ys3, yerr=ys_err3, lw=0.5, ms=8, marker='.', markeredgecolor='k', markeredgewidth=.5, capsize=2, elinewidth=1.2, label='Soft')
plt.errorbar(xh3, yh3, yerr=yh_err3, lw=0.5, ms=8, marker='.', markeredgecolor='k', markeredgewidth=.5, capsize=2, elinewidth=1.2, label='Hard')
plt.vlines([t0, t1, t2, t3, t4, t5, t_end], 0, 3.5, 'k', '--')
plt.text(t0, 3.6, 't0', ha='center')
plt.text(t1, 3.6, 't1', ha='center')
plt.text(t2, 3.6, 't2', ha='center')
plt.text(t3, 3.6, 't3', ha='center')
plt.text(t4, 3.6, 't4', ha='center')
plt.text(t5, 3.6, 't5', ha='center')
plt.text(t_end, 3.6, 't_end', ha='center')
plt.grid('both','major',c='lightgray',ls='--', zorder=0)
plt.xlabel('Time (s)')
plt.ylabel('Counts/s', labelpad=18)
plt.ylim(0, 3.9)
plt.legend(loc=(0.79, 0.6))
plt.show()

# %% [markdown]
# # Extract Spectra
# Now I need to worry about separating out the flare. Here I am testing the difference between different quiescent extractions. Final spectra are extracted in the other notebook (Extraction.ipynb)
#
# There are three flares visible in the LC. The first is big and the second two are small. We are going to extract three spectra to test the differences:
# 1. Just the first (big) flare (Flare 1)
# 2. Everything other than the first big flare (Inclusive Quiet)
# 3. Only the quiet parts between the three flares (Fully Quiet)

# %% [markdown]
# ## Flare 1

# %%
# EMOS 1

# Parameters
q_flag       = "#XMMEA_EMOS1" # Quality flag
n_pattern    = 12           # Pattern selection. Should be 12 for MOS detectors
region_1     = (24475.391, 24618.401)
radius       = 800
bkg_1        = (24475.391, 21000.5)
bkg_radius   = 1400
spec_min     = 0
spec_max     = 11999
bin_size     = 15
time_min     = t0
time_max     = t1

# Input Files
work_dir         = '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/'
event_file       = '0327_0101440801_EMOS1_S001_ImagingEvts.ds'
# Output Files
source_file      = 'EMOS1_spec_flare.fits'
bkg_file         = 'EMOS1_bkg_spec_flare.fits'
response_file    = 'EMOS1_flare.rmf'
ancillary_file   = 'EMOS1_flare.anc'
final_file       = 'EMOS1_spec_flare_final.fits'

# Extract
extract_spectrum(q_flag, n_pattern, bin_size, region_1, radius, bkg_1, bkg_radius, spec_min, spec_max,
                 work_dir, event_file, source_file, bkg_file, response_file, ancillary_file, final_file,
                 time_min=time_min, time_max=time_max)
# Out:
# Checking for Event Files...
#
#
# File 0327_0101440801_EMOS1_S001_ImagingEvts.ds exists.
#
#
#
# Extracting source spectrum...
#
#
# Executing:
# evselect table='0327_0101440801_EMOS1_S001_ImagingEvts.ds' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='#XMMEA_EMOS1&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,24618.401,800)) && (117423319 < TIME) && (TIME < 117446000)' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits' spectralbinsize='15' withspecranges='yes' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=0327_0101440801_EMOS1_S001_ImagingEvts.ds filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='#XMMEA_EMOS1&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,24618.401,800)) && (117423319 < TIME) && (TIME < 117446000)' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits spectralbinsize=15 specchannelmin=0 specchannelmax=11999 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:39.000
# evselect:- selected 7318 rows from the input table.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:39.000
#
#
# Extracting background spectrum...
#
#
# Executing:
# evselect table='0327_0101440801_EMOS1_S001_ImagingEvts.ds' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='#XMMEA_EMOS1&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,21000.5,1400))  && (117423319 < TIME) && (TIME < 117446000)' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_bkg_spec_flare.fits' spectralbinsize='15' withspecranges='yes' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=0327_0101440801_EMOS1_S001_ImagingEvts.ds filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='#XMMEA_EMOS1&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,21000.5,1400))  && (117423319 < TIME) && (TIME < 117446000)' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_bkg_spec_flare.fits spectralbinsize=15 specchannelmin=0 specchannelmax=11999 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:40.000
# evselect:- selected 246 rows from the input table.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:40.000
#
#
# Backscaling source spectrum...
#
#
# Executing:
# backscale spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits' badpixlocation='0327_0101440801_EMOS1_S001_ImagingEvts.ds' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits badpixlocation=0327_0101440801_EMOS1_S001_ImagingEvts.ds withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:41.000
# backscale:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS1_S001_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:41.000
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits...
# backscale::arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS1, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_MODEPARAM_0006.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS1, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS1_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT1, XAREAEF, 10, /Users/woodml/Observing/XMM-Newton/Calibration/XRT1_XAREAEF_0010.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# backscale::arfgen:- Using a source position in DET coordinates of x=42.3642 y=-78.9559
# backscale::arfgen:-  The source position in focal plane coords is  theta=7.09929 phi=0.411113
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=-842.8492914 xmax=927.5775935 xbins=1 ymin=-964.1694643 ymax=806.257599 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:41.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:41.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:41.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:41.000
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...2.5 2400 11997.5
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:41.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:41.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:41.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:41.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:42.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:42.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:42.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:42.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:42.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:42.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:42.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:42.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:42.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:42.000
# backscale::arfgen:- Bad pixel & chip gap fraction: ~0 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits...
# backscale::arfgen:- Opened spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits...
# backscale::arfgen:- Opened table /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits...
# backscale::arfgen:- Backscale value is: 2014100
# backscale::arfgen:- added att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits...
# backscale::arfgen:- closed spec/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:45.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:45.000
#
#
# Backscaling background spectrum...
#
#
# Executing:
# backscale spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_bkg_spec_flare.fits' badpixlocation='0327_0101440801_EMOS1_S001_ImagingEvts.ds' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_bkg_spec_flare.fits badpixlocation=0327_0101440801_EMOS1_S001_ImagingEvts.ds withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:45.000
# backscale:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_bkg_spec_flare.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS1_S001_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:45.000
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_bkg_spec_flare.fits...
# backscale::arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_bkg_spec_flare.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS1, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_MODEPARAM_0006.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS1, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS1_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT1, XAREAEF, 10, /Users/woodml/Observing/XMM-Newton/Calibration/XRT1_XAREAEF_0010.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# backscale::arfgen:- Using a source position in DET coordinates of x=3637.6 y=-484.598
# backscale::arfgen:-  The source position in focal plane coords is  theta=177.458 phi=4.63469
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=2088.890334 xmax=5186.303155 xbins=1 ymin=-2033.305855 ymax=1064.110197 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:46.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:46.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:46.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:46.000
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...2.5 2400 11997.5
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:46.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:46.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:46.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:46.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:46.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:46.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:46.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:46.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:46.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:46.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:46.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:46.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:46.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:46.000
# backscale::arfgen:- Bad pixel & chip gap fraction: ~2.181283546 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_bkg_spec_flare.fits...
# backscale::arfgen:- Opened spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_bkg_spec_flare.fits...
# backscale::arfgen:- Opened table /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_bkg_spec_flare.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_bkg_spec_flare.fits...
# backscale::arfgen:- Backscale value is: 5942616
# backscale::arfgen:- added att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_bkg_spec_flare.fits...
# backscale::arfgen:- closed spec/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_bkg_spec_flare.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:52.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:52.000
#
#
# Generating Response File...
#
#
# Executing:
# rmfgen rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EPIC_MOS1_flare.rmf' threshold='1e-06' withenergybins='no' energymin='0' energymax='15' nenergybins='30' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits' format='var' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='yes' detxbins='160' detybins='160' correctforpileup='no' raweventfile='rawevents.ds' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withrmfset='no' psfenergy='2' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='no' modelquantumeff='no' modelfiltertrans='no' modelcontamination='no' modelee='yes' modelootcorr='no' eegridfactor='100' withbadpixcorr='no' badpixlocation='notSpecified' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset='' psfmodel='notSpecified' withbadpixres='no' badpixelresolution='2' applyxcaladjustment='no' acceptchanrange='no' applyabsfluxcorr='no'
# rmfgen:- Executing (routine): rmfgen rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EPIC_MOS1_flare.rmf threshold=1e-06 withenergybins=no energymin=0 energymax=15 nenergybins=30 spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits format=var detmaptype=psf detmaparray=detmapfile.ds: withdetbounds=no detxoffset=1200 detyoffset=1200 detxbins=160 detybins=160 withdetbins=yes raweventfile=rawevents.ds correctforpileup=no filterdss=yes withfilteredset=no filteredset=filteredpixellist.ds withrmfset=no psfenergy=2 withsourcepos=no sourcecoords=eqpos sourcex=0 sourcey=0 extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=no modelee=yes modelootcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no psfmodel=notSpecified badpixelresolution=2 withbadpixres=no applyxcaladjustment=no acceptchanrange=no applyabsfluxcorr=no  -w 1 -V 4
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:53.000
# Set to: notSpecified
# rmfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits...
# rmfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits.
# rmfgen:- Computing source position from region extent..
# rmfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS1, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_MODEPARAM_0006.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS1, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS1_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT1, XAREAEF, 10, /Users/woodml/Observing/XMM-Newton/Calibration/XRT1_XAREAEF_0010.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# rmfgen:- Using a source position in DET coordinates of x=42.3642 y=-78.9559
# rmfgen:-  The source position in focal plane coords is  theta=7.09929 phi=0.411113
# rmfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# rmfgen:- detector map binning will be: xbins: 160 ybins: 160
# rmfgen:- Constructing a psf detector map with  xmin=-842.8492914 xmax=927.5775935 xbins=160 ymin=-964.1694643 ymax=806.257599 ybins=160
# rmfgen:- PSF type: 2 [EXTENDED] will be used
# rmfgen:-  Creating RmfDataServer...
# rmfgen:-  EventGrades:5 PrimeFullWindow 302
# rmfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# rmfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:41:54.000
# rmfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:41:54.000
# rmfgen:-  RmfDataServer created ok.
# rmfgen:- Opening data set ...
# rmfgen:- Opened data set.
# rmfgen:- Adding MATRIX table. There will be 2400 rows in table
# rmfgen:- Initialising table iterator ..
# rmfgen:- Populating table ..
# rmfgen:- No groups found for row 0 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 1 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 2 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 3 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 4 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 5 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- Adding EBOUNDS extension ...
# rmfgen:-  Cleanup ...
# rmfgen:-  Closing data set ...
# rmfgen:-  Closed data set.
# rmfgen:-  Cleanup complete.
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:42:21.000
#
#
# Checking for Response File...
#
#
# File /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EPIC_MOS1_flare.rmf exists.
#
#
#
# Generating ancillary file...
#
#
# Executing:
# arfgen spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits' withrmfset='yes' rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EPIC_MOS1_flare.rmf' arfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EPIC_MOS1_flare.anc' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='no' detxbins='5' detybins='5' psfenergy='2' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='yes' modelquantumeff='yes' modelfiltertrans='yes' modelcontamination='yes' modelee='yes' modelootcorr='yes' applyxcaladjustment='no' applyabsfluxcorr='no' eegridfactor='100' withbadpixcorr='yes' badpixlocation='0327_0101440801_EMOS1_S001_ImagingEvts.ds' psfmodel='ELLBETA' withbadpixres='no' badpixelresolution='2' badpixmaptype='flat' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset=''
# arfgen:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EPIC_MOS1_flare.rmf withrmfset=yes arfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EPIC_MOS1_flare.anc detmaptype=psf detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS1_S001_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:42:22.000
# arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits...
# arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits.
# arfgen:- Computing source position from region extent..
# arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS1, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_MODEPARAM_0006.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS1, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS1_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT1, XAREAEF, 10, /Users/woodml/Observing/XMM-Newton/Calibration/XRT1_XAREAEF_0010.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# arfgen:- Using a source position in DET coordinates of x=42.3642 y=-78.9559
# arfgen:-  The source position in focal plane coords is  theta=7.09929 phi=0.411113
# arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# arfgen:- detector map binning will be: xbins: 5 ybins: 5
# arfgen:- Constructing a psf detector map with  xmin=-842.8492914 xmax=927.5775935 xbins=5 ymin=-964.1694643 ymax=806.257599 ybins=5
# arfgen:- PSF type: 3 [ELLBETA] will be used
# arfgen:- Opening arfset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EPIC_MOS1_flare.anc...
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:42:22.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:42:22.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:42:22.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:42:22.000
# Making file temp_badcol.ds
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- Writing energy data into dataset ..
# arfgen:- Calculating Area curve ...
# arfgen:- Calculating Area curve ...2.499999944 2400 11997.49994
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:42:23.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:42:23.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:42:23.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:42:23.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:42:23.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:42:23.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:42:23.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:42:23.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:42:23.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:42:23.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:42:23.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:42:23.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:42:23.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:42:23.000
# arfgen:- Bad pixel & chip gap fraction: ~0 %
# arfgen:- Writing area data into dataset ..
# arfgen:- Closing arfset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EPIC_MOS1_flare.anc.
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:42:28.000
#
#
# Finalizing spectrum...
#
#
# Executing:
# specgroup spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits' overwrite='no' groupedset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare_final.fits' withbgdset='yes' backgndset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_bkg_spec_flare.fits' withCounts='yes' mincounts='25' withminSN='no' minSN='5' withratioabovebgnd='no' ratioabovebgnd='' withoversampling='yes' oversample='3' withtemplate='no' grouptemplate='grptemplate.ds' withranges='no' ranges='' withRegularBins='no' regbinstart='' regbinend='' regbinwid='' units='CHAN' withrmfset='yes' rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EPIC_MOS1_flare.rmf' witharfset='yes' arfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EPIC_MOS1_flare.anc' addfilenames='yes' hightolow='no' lastbin='addtogroup' setbad='CCF'
# specgroup:- Executing (routine): specgroup spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare.fits groupedset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare_final.fits overwrite=no backgndset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_bkg_spec_flare.fits withbgdset=yes mincounts=25 withCounts=yes minSN=5 withminSN=no ratioabovebgnd=0 withratioabovebgnd=no oversample=3 withoversampling=yes grouptemplate=grptemplate.ds withtemplate=no ranges='' withranges=no regbinstart=0 regbinend=0 regbinwid=0 withRegularBins=no units=CHAN rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EPIC_MOS1_flare.rmf withrmfset=yes arfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EPIC_MOS1_flare.anc witharfset=yes addfilenames=yes hightolow=no lastbin=addtogroup setbad=CCF  -w 1 -V 4
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:42:29.000
# specgroup:- Prepared spectrum /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare_final.fits with 82 groups
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:42:30.000

# %%
# EMOS 2

# Parameters
q_flag       = "#XMMEA_EMOS2" # Quality flag
n_pattern    = 12           # Pattern selection. Should be 12 for MOS detectors
region_2     = (24476.384, 24620.342)
radius       = 800.
bkg_2        = (24476.384, 21000.5) 
bkg_radius   = 1800.
spec_min     = 0
spec_max     = 11999
bin_size     = 15
time_min     = t0
time_max     = t1

# Input Files
work_dir           = '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/'
event_file         = '0327_0101440801_EMOS2_S002_ImagingEvts.ds'
# Output Files
source_file        = 'EMOS2_spec_flare.fits'
bkg_file           = 'EMOS2_bkg_spec_flare.fits'
response_file      = 'EMOS2_flare.rmf'
ancillary_file     = 'EMOS2_flare.anc'
final_file         = 'EMOS2_spec_flare_final.fits'

extract_spectrum(q_flag, n_pattern, bin_size, region_2, radius, bkg_2, bkg_radius,spec_min,
                 spec_max, work_dir, event_file, source_file,bkg_file,response_file,ancillary_file, final_file,
                 time_min=time_min, time_max=time_max)
# Out:
# Checking for Event Files...
#
#
# File 0327_0101440801_EMOS2_S002_ImagingEvts.ds exists.
#
#
#
# Extracting source spectrum...
#
#
# Executing:
# evselect table='0327_0101440801_EMOS2_S002_ImagingEvts.ds' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='#XMMEA_EMOS2&&(PATTERN<=12) && ((X,Y) IN circle(24476.384,24620.342,800.0)) && (117423319 < TIME) && (TIME < 117446000)' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits' spectralbinsize='15' withspecranges='yes' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=0327_0101440801_EMOS2_S002_ImagingEvts.ds filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='#XMMEA_EMOS2&&(PATTERN<=12) && ((X,Y) IN circle(24476.384,24620.342,800.0)) && (117423319 < TIME) && (TIME < 117446000)' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits spectralbinsize=15 specchannelmin=0 specchannelmax=11999 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:43:53.000
# evselect:- selected 7484 rows from the input table.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:43:53.000
#
#
# Extracting background spectrum...
#
#
# Executing:
# evselect table='0327_0101440801_EMOS2_S002_ImagingEvts.ds' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='#XMMEA_EMOS2&&(PATTERN<=12) && ((X,Y) IN circle(24476.384,21000.5,1800.0))  && (117423319 < TIME) && (TIME < 117446000)' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_bkg_spec_flare.fits' spectralbinsize='15' withspecranges='yes' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=0327_0101440801_EMOS2_S002_ImagingEvts.ds filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='#XMMEA_EMOS2&&(PATTERN<=12) && ((X,Y) IN circle(24476.384,21000.5,1800.0))  && (117423319 < TIME) && (TIME < 117446000)' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_bkg_spec_flare.fits spectralbinsize=15 specchannelmin=0 specchannelmax=11999 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:43:54.000
# evselect:- selected 384 rows from the input table.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:43:54.000
#
#
# Backscaling source spectrum...
#
#
# Executing:
# backscale spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits' badpixlocation='0327_0101440801_EMOS2_S002_ImagingEvts.ds' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits badpixlocation=0327_0101440801_EMOS2_S002_ImagingEvts.ds withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:43:55.000
# backscale:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS2_S002_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:43:55.000
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits...
# backscale::arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS2, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_MODEPARAM_0006.CCF, 1999-01-01T00:00:00.000}
# CifEntry{EMOS2, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS2, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS2_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT2, XAREAEF, 11, /Users/woodml/Observing/XMM-Newton/Calibration/XRT2_XAREAEF_0011.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# backscale::arfgen:- Using a source position in DET coordinates of x=-90.4505 y=-176.403
# backscale::arfgen:-  The source position in focal plane coords is  theta=62.9215 phi=5.23658
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=-979.3251283 xmax=798.4242275 xbins=1 ymin=-1065.277839 ymax=712.4712881 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:43:55.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:43:55.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:43:55.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:43:55.000
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...2.5 2400 11997.5
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:43:55.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:43:55.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:43:55.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:43:55.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:43:55.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:43:55.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:43:55.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:43:55.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:43:55.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:43:55.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:43:55.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:43:55.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:43:55.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:43:55.000
# backscale::arfgen:- Bad pixel & chip gap fraction: ~0.7980116972 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits...
# backscale::arfgen:- Opened spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits...
# backscale::arfgen:- Opened table /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits...
# backscale::arfgen:- Backscale value is: 1926028
# backscale::arfgen:- added att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits...
# backscale::arfgen:- closed spec/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:00.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:00.000
#
#
# Backscaling background spectrum...
#
#
# Executing:
# backscale spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_bkg_spec_flare.fits' badpixlocation='0327_0101440801_EMOS2_S002_ImagingEvts.ds' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_bkg_spec_flare.fits badpixlocation=0327_0101440801_EMOS2_S002_ImagingEvts.ds withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:01.000
# backscale:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_bkg_spec_flare.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS2_S002_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:01.000
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_bkg_spec_flare.fits...
# backscale::arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_bkg_spec_flare.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS2, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_MODEPARAM_0006.CCF, 1999-01-01T00:00:00.000}
# CifEntry{EMOS2, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS2, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS2_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT2, XAREAEF, 11, /Users/woodml/Observing/XMM-Newton/Calibration/XRT2_XAREAEF_0011.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# backscale::arfgen:- Using a source position in DET coordinates of x=333.802 y=3418.99
# backscale::arfgen:-  The source position in focal plane coords is  theta=234.451 phi=4.75626
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=-1665.470704 xmax=2333.075216 xbins=1 ymin=1419.7152 ymax=5418.256481 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:02.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:02.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:02.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:02.000
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...2.5 2400 11997.5
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:02.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:02.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:02.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:02.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:02.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:02.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:02.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:02.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:02.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:02.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:02.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:02.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:02.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:02.000
# backscale::arfgen:- Bad pixel & chip gap fraction: ~0.3363987182 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_bkg_spec_flare.fits...
# backscale::arfgen:- Opened spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_bkg_spec_flare.fits...
# backscale::arfgen:- Opened table /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_bkg_spec_flare.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_bkg_spec_flare.fits...
# backscale::arfgen:- Backscale value is: 9816812
# backscale::arfgen:- added att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_bkg_spec_flare.fits...
# backscale::arfgen:- closed spec/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_bkg_spec_flare.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:09.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:09.000
#
#
# Generating Response File...
#
#
# Executing:
# rmfgen rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_flare.rmf' threshold='1e-06' withenergybins='no' energymin='0' energymax='15' nenergybins='30' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits' format='var' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='yes' detxbins='160' detybins='160' correctforpileup='no' raweventfile='rawevents.ds' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withrmfset='no' psfenergy='2' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='no' modelquantumeff='no' modelfiltertrans='no' modelcontamination='no' modelee='yes' modelootcorr='no' eegridfactor='100' withbadpixcorr='no' badpixlocation='notSpecified' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset='' psfmodel='notSpecified' withbadpixres='no' badpixelresolution='2' applyxcaladjustment='no' acceptchanrange='no' applyabsfluxcorr='no'
# rmfgen:- Executing (routine): rmfgen rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_flare.rmf threshold=1e-06 withenergybins=no energymin=0 energymax=15 nenergybins=30 spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits format=var detmaptype=psf detmaparray=detmapfile.ds: withdetbounds=no detxoffset=1200 detyoffset=1200 detxbins=160 detybins=160 withdetbins=yes raweventfile=rawevents.ds correctforpileup=no filterdss=yes withfilteredset=no filteredset=filteredpixellist.ds withrmfset=no psfenergy=2 withsourcepos=no sourcecoords=eqpos sourcex=0 sourcey=0 extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=no modelee=yes modelootcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no psfmodel=notSpecified badpixelresolution=2 withbadpixres=no applyxcaladjustment=no acceptchanrange=no applyabsfluxcorr=no  -w 1 -V 4
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:10.000
# Set to: notSpecified
# rmfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits...
# rmfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits.
# rmfgen:- Computing source position from region extent..
# rmfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS2, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_MODEPARAM_0006.CCF, 1999-01-01T00:00:00.000}
# CifEntry{EMOS2, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS2, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS2_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT2, XAREAEF, 11, /Users/woodml/Observing/XMM-Newton/Calibration/XRT2_XAREAEF_0011.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# rmfgen:- Using a source position in DET coordinates of x=-90.4505 y=-176.403
# rmfgen:-  The source position in focal plane coords is  theta=62.9215 phi=5.23658
# rmfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# rmfgen:- detector map binning will be: xbins: 160 ybins: 160
# rmfgen:- Constructing a psf detector map with  xmin=-979.3251283 xmax=798.4242275 xbins=160 ymin=-1065.277839 ymax=712.4712881 ybins=160
# rmfgen:- PSF type: 2 [EXTENDED] will be used
# rmfgen:-  Creating RmfDataServer...
# rmfgen:-  EventGrades:5 PrimeFullWindow 296
# rmfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# rmfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:11.000
# rmfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:11.000
# rmfgen:-  RmfDataServer created ok.
# rmfgen:- Opening data set ...
# rmfgen:- Opened data set.
# rmfgen:- Adding MATRIX table. There will be 2400 rows in table
# rmfgen:- Initialising table iterator ..
# rmfgen:- Populating table ..
# rmfgen:- No groups found for row 0 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 1 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 2 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 3 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 4 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 5 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- Adding EBOUNDS extension ...
# rmfgen:-  Cleanup ...
# rmfgen:-  Closing data set ...
# rmfgen:-  Closed data set.
# rmfgen:-  Cleanup complete.
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:36.000
#
#
# Checking for Response File...
#
#
# File /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_flare.rmf exists.
#
#
#
# Generating ancillary file...
#
#
# Executing:
# arfgen spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits' withrmfset='yes' rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_flare.rmf' arfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_flare.anc' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='no' detxbins='5' detybins='5' psfenergy='2' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='yes' modelquantumeff='yes' modelfiltertrans='yes' modelcontamination='yes' modelee='yes' modelootcorr='yes' applyxcaladjustment='no' applyabsfluxcorr='no' eegridfactor='100' withbadpixcorr='yes' badpixlocation='0327_0101440801_EMOS2_S002_ImagingEvts.ds' psfmodel='ELLBETA' withbadpixres='no' badpixelresolution='2' badpixmaptype='flat' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset=''
# arfgen:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_flare.rmf withrmfset=yes arfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_flare.anc detmaptype=psf detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS2_S002_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:37.000
# arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits...
# arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits.
# arfgen:- Computing source position from region extent..
# arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS2, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_MODEPARAM_0006.CCF, 1999-01-01T00:00:00.000}
# CifEntry{EMOS2, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS2, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS2_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT2, XAREAEF, 11, /Users/woodml/Observing/XMM-Newton/Calibration/XRT2_XAREAEF_0011.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# arfgen:- Using a source position in DET coordinates of x=-90.4505 y=-176.403
# arfgen:-  The source position in focal plane coords is  theta=62.9215 phi=5.23658
# arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# arfgen:- detector map binning will be: xbins: 5 ybins: 5
# arfgen:- Constructing a psf detector map with  xmin=-979.3251283 xmax=798.4242275 xbins=5 ymin=-1065.277839 ymax=712.4712881 ybins=5
# arfgen:- PSF type: 3 [ELLBETA] will be used
# arfgen:- Opening arfset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_flare.anc...
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:37.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:37.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:38.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:38.000
# Making file temp_badcol.ds
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- Writing energy data into dataset ..
# arfgen:- Calculating Area curve ...
# arfgen:- Calculating Area curve ...2.499999944 2400 11997.49994
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:38.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:38.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:38.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:38.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:38.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:38.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:38.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:38.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:38.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:38.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:38.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:38.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:38.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:38.000
# arfgen:- Bad pixel & chip gap fraction: ~0.9313246483 %
# arfgen:- Writing area data into dataset ..
# arfgen:- Closing arfset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_flare.anc.
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:46.000
#
#
# Finalizing spectrum...
#
#
# Executing:
# specgroup spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits' overwrite='no' groupedset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare_final.fits' withbgdset='yes' backgndset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_bkg_spec_flare.fits' withCounts='yes' mincounts='25' withminSN='no' minSN='5' withratioabovebgnd='no' ratioabovebgnd='' withoversampling='yes' oversample='3' withtemplate='no' grouptemplate='grptemplate.ds' withranges='no' ranges='' withRegularBins='no' regbinstart='' regbinend='' regbinwid='' units='CHAN' withrmfset='yes' rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_flare.rmf' witharfset='yes' arfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_flare.anc' addfilenames='yes' hightolow='no' lastbin='addtogroup' setbad='CCF'
# specgroup:- Executing (routine): specgroup spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare.fits groupedset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare_final.fits overwrite=no backgndset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_bkg_spec_flare.fits withbgdset=yes mincounts=25 withCounts=yes minSN=5 withminSN=no ratioabovebgnd=0 withratioabovebgnd=no oversample=3 withoversampling=yes grouptemplate=grptemplate.ds withtemplate=no ranges='' withranges=no regbinstart=0 regbinend=0 regbinwid=0 withRegularBins=no units=CHAN rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_flare.rmf withrmfset=yes arfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_flare.anc witharfset=yes addfilenames=yes hightolow=no lastbin=addtogroup setbad=CCF  -w 1 -V 4
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:44:47.000
# specgroup:- Prepared spectrum /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare_final.fits with 81 groups
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:44:47.000

# %%
# Plot
plt.figure(figsize=(6,3))
plot_spectrum('/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare_final.fits', label='EMOS 1')
plot_spectrum('/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare_final.fits', label='EMOS 2')
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xscale('log')
plt.legend()
plt.show()

# %% [markdown]
# ## Inclusive Quiescent

# %%
# EMOS 1

# Parameters
q_flag       = "#XMMEA_EMOS1" # Quality flag
n_pattern    = 12           # Pattern selection. Should be 12 for MOS detectors
region_1     = (24475.391, 24618.401)
radius       = 800
bkg_1        = (24475.391, 21000.5)
bkg_radius   = 1400
spec_min     = 0
spec_max     = 11999
bin_size     = 15
time_min     = t1
time_max     = t_end

# Input Files
work_dir           = '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/'
event_file         = '0327_0101440801_EMOS1_S001_ImagingEvts.ds'
# Output Files
source_file        = 'Quiet_Testing/EMOS1_spec_inquiet.fits'
bkg_file           = 'Quiet_Testing/EMOS1_bkg_spec_inquiet.fits'
response_file      = 'Quiet_Testing/EMOS1_inquiet.rmf'
ancillary_file     = 'Quiet_Testing/EMOS1_inquiet.anc'
final_file         = 'Quiet_Testing/EMOS1_spec_inquiet_final.fits'

# Extract
extract_spectrum(q_flag, n_pattern, bin_size, region_1, radius, bkg_1, bkg_radius, spec_min, spec_max,
                 work_dir, event_file, source_file, bkg_file, response_file, ancillary_file, final_file,
                 time_min=time_min, time_max=time_max)
# Out:
# Checking for Event Files...
#
#
# File 0327_0101440801_EMOS1_S001_ImagingEvts.ds exists.
#
#
#
# Extracting source spectrum...
#
#
# Executing:
# evselect table='0327_0101440801_EMOS1_S001_ImagingEvts.ds' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='#XMMEA_EMOS1&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,24618.401,800)) && (117446000 < TIME) && (TIME < 117552515.136132)' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits' spectralbinsize='15' withspecranges='yes' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=0327_0101440801_EMOS1_S001_ImagingEvts.ds filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='#XMMEA_EMOS1&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,24618.401,800)) && (117446000 < TIME) && (TIME < 117552515.136132)' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits spectralbinsize=15 specchannelmin=0 specchannelmax=11999 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:19.000
# evselect:- selected 19247 rows from the input table.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:19.000
#
#
# Extracting background spectrum...
#
#
# Executing:
# evselect table='0327_0101440801_EMOS1_S001_ImagingEvts.ds' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='#XMMEA_EMOS1&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,21000.5,1400))  && (117446000 < TIME) && (TIME < 117552515.136132)' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_inquiet.fits' spectralbinsize='15' withspecranges='yes' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=0327_0101440801_EMOS1_S001_ImagingEvts.ds filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='#XMMEA_EMOS1&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,21000.5,1400))  && (117446000 < TIME) && (TIME < 117552515.136132)' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_inquiet.fits spectralbinsize=15 specchannelmin=0 specchannelmax=11999 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:20.000
# evselect:- selected 1305 rows from the input table.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:20.000
#
#
# Backscaling source spectrum...
#
#
# Executing:
# backscale spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits' badpixlocation='0327_0101440801_EMOS1_S001_ImagingEvts.ds' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits badpixlocation=0327_0101440801_EMOS1_S001_ImagingEvts.ds withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:21.000
# backscale:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS1_S001_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:21.000
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits...
# backscale::arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS1, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_MODEPARAM_0006.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS1, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS1_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT1, XAREAEF, 10, /Users/woodml/Observing/XMM-Newton/Calibration/XRT1_XAREAEF_0010.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# backscale::arfgen:- Using a source position in DET coordinates of x=42.3642 y=-78.9559
# backscale::arfgen:-  The source position in focal plane coords is  theta=7.09929 phi=0.411113
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=-842.8492914 xmax=927.5775935 xbins=1 ymin=-964.1694643 ymax=806.257599 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:21.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:21.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:21.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:21.000
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...2.5 2400 11997.5
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:21.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:21.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:21.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:21.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:21.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:21.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:22.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:22.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:22.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:22.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:22.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:22.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:22.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:22.000
# backscale::arfgen:- Bad pixel & chip gap fraction: ~0 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits...
# backscale::arfgen:- Opened spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits...
# backscale::arfgen:- Opened table /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits...
# backscale::arfgen:- Backscale value is: 2014100
# backscale::arfgen:- added att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits...
# backscale::arfgen:- closed spec/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:25.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:25.000
#
#
# Backscaling background spectrum...
#
#
# Executing:
# backscale spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_inquiet.fits' badpixlocation='0327_0101440801_EMOS1_S001_ImagingEvts.ds' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_inquiet.fits badpixlocation=0327_0101440801_EMOS1_S001_ImagingEvts.ds withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:25.000
# backscale:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_inquiet.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS1_S001_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:25.000
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_inquiet.fits...
# backscale::arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_inquiet.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS1, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_MODEPARAM_0006.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS1, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS1_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT1, XAREAEF, 10, /Users/woodml/Observing/XMM-Newton/Calibration/XRT1_XAREAEF_0010.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# backscale::arfgen:- Using a source position in DET coordinates of x=3637.6 y=-484.598
# backscale::arfgen:-  The source position in focal plane coords is  theta=177.458 phi=4.63469
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=2088.890334 xmax=5186.303155 xbins=1 ymin=-2033.305855 ymax=1064.110197 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:26.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:26.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:26.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:26.000
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...2.5 2400 11997.5
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:26.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:26.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:26.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:26.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:26.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:26.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:26.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:26.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:26.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:26.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:26.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:26.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:26.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:26.000
# backscale::arfgen:- Bad pixel & chip gap fraction: ~2.181283546 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_inquiet.fits...
# backscale::arfgen:- Opened spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_inquiet.fits...
# backscale::arfgen:- Opened table /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_inquiet.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_inquiet.fits...
# backscale::arfgen:- Backscale value is: 5942616
# backscale::arfgen:- added att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_inquiet.fits...
# backscale::arfgen:- closed spec/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_inquiet.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:32.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:32.000
#
#
# Generating Response File...
#
#
# Executing:
# rmfgen rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_inquiet.rmf' threshold='1e-06' withenergybins='no' energymin='0' energymax='15' nenergybins='30' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits' format='var' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='yes' detxbins='160' detybins='160' correctforpileup='no' raweventfile='rawevents.ds' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withrmfset='no' psfenergy='2' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='no' modelquantumeff='no' modelfiltertrans='no' modelcontamination='no' modelee='yes' modelootcorr='no' eegridfactor='100' withbadpixcorr='no' badpixlocation='notSpecified' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset='' psfmodel='notSpecified' withbadpixres='no' badpixelresolution='2' applyxcaladjustment='no' acceptchanrange='no' applyabsfluxcorr='no'
# rmfgen:- Executing (routine): rmfgen rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_inquiet.rmf threshold=1e-06 withenergybins=no energymin=0 energymax=15 nenergybins=30 spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits format=var detmaptype=psf detmaparray=detmapfile.ds: withdetbounds=no detxoffset=1200 detyoffset=1200 detxbins=160 detybins=160 withdetbins=yes raweventfile=rawevents.ds correctforpileup=no filterdss=yes withfilteredset=no filteredset=filteredpixellist.ds withrmfset=no psfenergy=2 withsourcepos=no sourcecoords=eqpos sourcex=0 sourcey=0 extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=no modelee=yes modelootcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no psfmodel=notSpecified badpixelresolution=2 withbadpixres=no applyxcaladjustment=no acceptchanrange=no applyabsfluxcorr=no  -w 1 -V 4
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:33.000
# Set to: notSpecified
# rmfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits...
# rmfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits.
# rmfgen:- Computing source position from region extent..
# rmfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS1, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_MODEPARAM_0006.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS1, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS1_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT1, XAREAEF, 10, /Users/woodml/Observing/XMM-Newton/Calibration/XRT1_XAREAEF_0010.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# rmfgen:- Using a source position in DET coordinates of x=42.3642 y=-78.9559
# rmfgen:-  The source position in focal plane coords is  theta=7.09929 phi=0.411113
# rmfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# rmfgen:- detector map binning will be: xbins: 160 ybins: 160
# rmfgen:- Constructing a psf detector map with  xmin=-842.8492914 xmax=927.5775935 xbins=160 ymin=-964.1694643 ymax=806.257599 ybins=160
# rmfgen:- PSF type: 2 [EXTENDED] will be used
# rmfgen:-  Creating RmfDataServer...
# rmfgen:-  EventGrades:5 PrimeFullWindow 302
# rmfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# rmfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:52:34.000
# rmfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:52:34.000
# rmfgen:-  RmfDataServer created ok.
# rmfgen:- Opening data set ...
# rmfgen:- Opened data set.
# rmfgen:- Adding MATRIX table. There will be 2400 rows in table
# rmfgen:- Initialising table iterator ..
# rmfgen:- Populating table ..
# rmfgen:- No groups found for row 0 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 1 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 2 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 3 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 4 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 5 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- Adding EBOUNDS extension ...
# rmfgen:-  Cleanup ...
# rmfgen:-  Closing data set ...
# rmfgen:-  Closed data set.
# rmfgen:-  Cleanup complete.
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:01.000
#
#
# Checking for Response File...
#
#
# File /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_inquiet.rmf exists.
#
#
#
# Generating ancillary file...
#
#
# Executing:
# arfgen spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits' withrmfset='yes' rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_inquiet.rmf' arfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_inquiet.anc' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='no' detxbins='5' detybins='5' psfenergy='2' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='yes' modelquantumeff='yes' modelfiltertrans='yes' modelcontamination='yes' modelee='yes' modelootcorr='yes' applyxcaladjustment='no' applyabsfluxcorr='no' eegridfactor='100' withbadpixcorr='yes' badpixlocation='0327_0101440801_EMOS1_S001_ImagingEvts.ds' psfmodel='ELLBETA' withbadpixres='no' badpixelresolution='2' badpixmaptype='flat' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset=''
# arfgen:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_inquiet.rmf withrmfset=yes arfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_inquiet.anc detmaptype=psf detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS1_S001_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:02.000
# arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits...
# arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits.
# arfgen:- Computing source position from region extent..
# arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS1, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_MODEPARAM_0006.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS1, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS1_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT1, XAREAEF, 10, /Users/woodml/Observing/XMM-Newton/Calibration/XRT1_XAREAEF_0010.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# arfgen:- Using a source position in DET coordinates of x=42.3642 y=-78.9559
# arfgen:-  The source position in focal plane coords is  theta=7.09929 phi=0.411113
# arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# arfgen:- detector map binning will be: xbins: 5 ybins: 5
# arfgen:- Constructing a psf detector map with  xmin=-842.8492914 xmax=927.5775935 xbins=5 ymin=-964.1694643 ymax=806.257599 ybins=5
# arfgen:- PSF type: 3 [ELLBETA] will be used
# arfgen:- Opening arfset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_inquiet.anc...
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:02.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:02.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:02.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:02.000
# Making file temp_badcol.ds
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- Writing energy data into dataset ..
# arfgen:- Calculating Area curve ...
# arfgen:- Calculating Area curve ...2.499999944 2400 11997.49994
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:03.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:03.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:03.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:03.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:03.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:03.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:03.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:03.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:03.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:03.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:03.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:03.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:03.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:03.000
# arfgen:- Bad pixel & chip gap fraction: ~0 %
# arfgen:- Writing area data into dataset ..
# arfgen:- Closing arfset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_inquiet.anc.
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:08.000
#
#
# Finalizing spectrum...
#
#
# Executing:
# specgroup spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits' overwrite='no' groupedset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet_final.fits' withbgdset='yes' backgndset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_inquiet.fits' withCounts='yes' mincounts='25' withminSN='no' minSN='5' withratioabovebgnd='no' ratioabovebgnd='' withoversampling='yes' oversample='3' withtemplate='no' grouptemplate='grptemplate.ds' withranges='no' ranges='' withRegularBins='no' regbinstart='' regbinend='' regbinwid='' units='CHAN' withrmfset='yes' rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_inquiet.rmf' witharfset='yes' arfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_inquiet.anc' addfilenames='yes' hightolow='no' lastbin='addtogroup' setbad='CCF'
# specgroup:- Executing (routine): specgroup spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet.fits groupedset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet_final.fits overwrite=no backgndset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_inquiet.fits withbgdset=yes mincounts=25 withCounts=yes minSN=5 withminSN=no ratioabovebgnd=0 withratioabovebgnd=no oversample=3 withoversampling=yes grouptemplate=grptemplate.ds withtemplate=no ranges='' withranges=no regbinstart=0 regbinend=0 regbinwid=0 withRegularBins=no units=CHAN rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_inquiet.rmf withrmfset=yes arfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_inquiet.anc witharfset=yes addfilenames=yes hightolow=no lastbin=addtogroup setbad=CCF  -w 1 -V 4
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:09.000
# specgroup:- Prepared spectrum /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_inquiet_final.fits with 94 groups
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:09.000

# %%
# EMOS 2

# Parameters
q_flag       = "#XMMEA_EMOS2" # Quality flag
n_pattern    = 12           # Pattern selection. Should be 12 for MOS detectors
region_2     = (24476.384, 24620.342)
radius       = 800.
bkg_2        = (24476.384, 21000.5) 
bkg_radius   = 1800.
spec_min     = 0
spec_max     = 11999
bin_size     = 15
time_min     = t1
time_max     = t_end

# Input Files
work_dir           = '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/'
event_file         = '0327_0101440801_EMOS2_S002_ImagingEvts.ds'
# Output Files
source_file        = 'Quiet_Testing/EMOS2_spec_inquiet.fits'
bkg_file           = 'Quiet_Testing/EMOS2_bkg_spec_inquiet.fits'
response_file      = 'Quiet_Testing/EMOS2_inquiet.rmf'
ancillary_file     = 'Quiet_Testing/EMOS2_inquiet.anc'
final_file         = 'Quiet_Testing/EMOS2_spec_inquiet_final.fits'

extract_spectrum(q_flag, n_pattern, bin_size, region_2, radius, bkg_2, bkg_radius,spec_min,
                 spec_max, work_dir, event_file, source_file,bkg_file,response_file,ancillary_file, final_file,
                 time_min=time_min, time_max=time_max)
# Out:
# Checking for Event Files...
#
#
# File 0327_0101440801_EMOS2_S002_ImagingEvts.ds exists.
#
#
#
# Extracting source spectrum...
#
#
# Executing:
# evselect table='0327_0101440801_EMOS2_S002_ImagingEvts.ds' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='#XMMEA_EMOS2&&(PATTERN<=12) && ((X,Y) IN circle(24476.384,24620.342,800.0)) && (117446000 < TIME) && (TIME < 117552515.136132)' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits' spectralbinsize='15' withspecranges='yes' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=0327_0101440801_EMOS2_S002_ImagingEvts.ds filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='#XMMEA_EMOS2&&(PATTERN<=12) && ((X,Y) IN circle(24476.384,24620.342,800.0)) && (117446000 < TIME) && (TIME < 117552515.136132)' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits spectralbinsize=15 specchannelmin=0 specchannelmax=11999 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:55.000
# evselect:- selected 19712 rows from the input table.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:55.000
#
#
# Extracting background spectrum...
#
#
# Executing:
# evselect table='0327_0101440801_EMOS2_S002_ImagingEvts.ds' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='#XMMEA_EMOS2&&(PATTERN<=12) && ((X,Y) IN circle(24476.384,21000.5,1800.0))  && (117446000 < TIME) && (TIME < 117552515.136132)' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_inquiet.fits' spectralbinsize='15' withspecranges='yes' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=0327_0101440801_EMOS2_S002_ImagingEvts.ds filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='#XMMEA_EMOS2&&(PATTERN<=12) && ((X,Y) IN circle(24476.384,21000.5,1800.0))  && (117446000 < TIME) && (TIME < 117552515.136132)' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_inquiet.fits spectralbinsize=15 specchannelmin=0 specchannelmax=11999 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:56.000
# evselect:- selected 2019 rows from the input table.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:56.000
#
#
# Backscaling source spectrum...
#
#
# Executing:
# backscale spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits' badpixlocation='0327_0101440801_EMOS2_S002_ImagingEvts.ds' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits badpixlocation=0327_0101440801_EMOS2_S002_ImagingEvts.ds withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:57.000
# backscale:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS2_S002_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:57.000
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits...
# backscale::arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS2, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_MODEPARAM_0006.CCF, 1999-01-01T00:00:00.000}
# CifEntry{EMOS2, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS2, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS2_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT2, XAREAEF, 11, /Users/woodml/Observing/XMM-Newton/Calibration/XRT2_XAREAEF_0011.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# backscale::arfgen:- Using a source position in DET coordinates of x=-90.4505 y=-176.403
# backscale::arfgen:-  The source position in focal plane coords is  theta=62.9215 phi=5.23658
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=-979.3251283 xmax=798.4242275 xbins=1 ymin=-1065.277839 ymax=712.4712881 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:57.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:57.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:57.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:57.000
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...2.5 2400 11997.5
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:57.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:57.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:57.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:57.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:57.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:57.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:57.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:57.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:58.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:58.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:58.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:58.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:53:58.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:53:58.000
# backscale::arfgen:- Bad pixel & chip gap fraction: ~0.7980116972 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits...
# backscale::arfgen:- Opened spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits...
# backscale::arfgen:- Opened table /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits...
# backscale::arfgen:- Backscale value is: 1926028
# backscale::arfgen:- added att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits...
# backscale::arfgen:- closed spec/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:03.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:03.000
#
#
# Backscaling background spectrum...
#
#
# Executing:
# backscale spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_inquiet.fits' badpixlocation='0327_0101440801_EMOS2_S002_ImagingEvts.ds' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_inquiet.fits badpixlocation=0327_0101440801_EMOS2_S002_ImagingEvts.ds withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:04.000
# backscale:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_inquiet.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS2_S002_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:04.000
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_inquiet.fits...
# backscale::arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_inquiet.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS2, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_MODEPARAM_0006.CCF, 1999-01-01T00:00:00.000}
# CifEntry{EMOS2, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS2, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS2_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT2, XAREAEF, 11, /Users/woodml/Observing/XMM-Newton/Calibration/XRT2_XAREAEF_0011.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# backscale::arfgen:- Using a source position in DET coordinates of x=333.802 y=3418.99
# backscale::arfgen:-  The source position in focal plane coords is  theta=234.451 phi=4.75626
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=-1665.470704 xmax=2333.075216 xbins=1 ymin=1419.7152 ymax=5418.256481 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:04.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:04.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:04.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:04.000
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...2.5 2400 11997.5
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:04.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:04.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:04.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:04.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:04.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:04.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:04.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:04.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:04.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:04.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:04.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:04.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:04.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:04.000
# backscale::arfgen:- Bad pixel & chip gap fraction: ~0.3363987182 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_inquiet.fits...
# backscale::arfgen:- Opened spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_inquiet.fits...
# backscale::arfgen:- Opened table /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_inquiet.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_inquiet.fits...
# backscale::arfgen:- Backscale value is: 9816812
# backscale::arfgen:- added att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_inquiet.fits...
# backscale::arfgen:- closed spec/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_inquiet.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:12.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:12.000
#
#
# Generating Response File...
#
#
# Executing:
# rmfgen rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_inquiet.rmf' threshold='1e-06' withenergybins='no' energymin='0' energymax='15' nenergybins='30' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits' format='var' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='yes' detxbins='160' detybins='160' correctforpileup='no' raweventfile='rawevents.ds' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withrmfset='no' psfenergy='2' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='no' modelquantumeff='no' modelfiltertrans='no' modelcontamination='no' modelee='yes' modelootcorr='no' eegridfactor='100' withbadpixcorr='no' badpixlocation='notSpecified' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset='' psfmodel='notSpecified' withbadpixres='no' badpixelresolution='2' applyxcaladjustment='no' acceptchanrange='no' applyabsfluxcorr='no'
# rmfgen:- Executing (routine): rmfgen rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_inquiet.rmf threshold=1e-06 withenergybins=no energymin=0 energymax=15 nenergybins=30 spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits format=var detmaptype=psf detmaparray=detmapfile.ds: withdetbounds=no detxoffset=1200 detyoffset=1200 detxbins=160 detybins=160 withdetbins=yes raweventfile=rawevents.ds correctforpileup=no filterdss=yes withfilteredset=no filteredset=filteredpixellist.ds withrmfset=no psfenergy=2 withsourcepos=no sourcecoords=eqpos sourcex=0 sourcey=0 extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=no modelee=yes modelootcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no psfmodel=notSpecified badpixelresolution=2 withbadpixres=no applyxcaladjustment=no acceptchanrange=no applyabsfluxcorr=no  -w 1 -V 4
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:13.000
# Set to: notSpecified
# rmfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits...
# rmfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits.
# rmfgen:- Computing source position from region extent..
# rmfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS2, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_MODEPARAM_0006.CCF, 1999-01-01T00:00:00.000}
# CifEntry{EMOS2, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS2, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS2_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT2, XAREAEF, 11, /Users/woodml/Observing/XMM-Newton/Calibration/XRT2_XAREAEF_0011.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# rmfgen:- Using a source position in DET coordinates of x=-90.4505 y=-176.403
# rmfgen:-  The source position in focal plane coords is  theta=62.9215 phi=5.23658
# rmfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# rmfgen:- detector map binning will be: xbins: 160 ybins: 160
# rmfgen:- Constructing a psf detector map with  xmin=-979.3251283 xmax=798.4242275 xbins=160 ymin=-1065.277839 ymax=712.4712881 ybins=160
# rmfgen:- PSF type: 2 [EXTENDED] will be used
# rmfgen:-  Creating RmfDataServer...
# rmfgen:-  EventGrades:5 PrimeFullWindow 296
# rmfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# rmfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:13.000
# rmfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:13.000
# rmfgen:-  RmfDataServer created ok.
# rmfgen:- Opening data set ...
# rmfgen:- Opened data set.
# rmfgen:- Adding MATRIX table. There will be 2400 rows in table
# rmfgen:- Initialising table iterator ..
# rmfgen:- Populating table ..
# rmfgen:- No groups found for row 0 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 1 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 2 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 3 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 4 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 5 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- Adding EBOUNDS extension ...
# rmfgen:-  Cleanup ...
# rmfgen:-  Closing data set ...
# rmfgen:-  Closed data set.
# rmfgen:-  Cleanup complete.
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:39.000
#
#
# Checking for Response File...
#
#
# File /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_inquiet.rmf exists.
#
#
#
# Generating ancillary file...
#
#
# Executing:
# arfgen spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits' withrmfset='yes' rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_inquiet.rmf' arfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_inquiet.anc' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='no' detxbins='5' detybins='5' psfenergy='2' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='yes' modelquantumeff='yes' modelfiltertrans='yes' modelcontamination='yes' modelee='yes' modelootcorr='yes' applyxcaladjustment='no' applyabsfluxcorr='no' eegridfactor='100' withbadpixcorr='yes' badpixlocation='0327_0101440801_EMOS2_S002_ImagingEvts.ds' psfmodel='ELLBETA' withbadpixres='no' badpixelresolution='2' badpixmaptype='flat' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset=''
# arfgen:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_inquiet.rmf withrmfset=yes arfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_inquiet.anc detmaptype=psf detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS2_S002_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:40.000
# arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits...
# arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits.
# arfgen:- Computing source position from region extent..
# arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS2, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_MODEPARAM_0006.CCF, 1999-01-01T00:00:00.000}
# CifEntry{EMOS2, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS2, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS2_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT2, XAREAEF, 11, /Users/woodml/Observing/XMM-Newton/Calibration/XRT2_XAREAEF_0011.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# arfgen:- Using a source position in DET coordinates of x=-90.4505 y=-176.403
# arfgen:-  The source position in focal plane coords is  theta=62.9215 phi=5.23658
# arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# arfgen:- detector map binning will be: xbins: 5 ybins: 5
# arfgen:- Constructing a psf detector map with  xmin=-979.3251283 xmax=798.4242275 xbins=5 ymin=-1065.277839 ymax=712.4712881 ybins=5
# arfgen:- PSF type: 3 [ELLBETA] will be used
# arfgen:- Opening arfset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_inquiet.anc...
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:40.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:40.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:40.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:40.000
# Making file temp_badcol.ds
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- Writing energy data into dataset ..
# arfgen:- Calculating Area curve ...
# arfgen:- Calculating Area curve ...2.499999944 2400 11997.49994
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:40.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:40.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:40.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:40.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:41.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:41.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:41.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:41.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:41.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:41.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:41.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:41.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:41.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:41.000
# arfgen:- Bad pixel & chip gap fraction: ~0.9313246483 %
# arfgen:- Writing area data into dataset ..
# arfgen:- Closing arfset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_inquiet.anc.
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:48.000
#
#
# Finalizing spectrum...
#
#
# Executing:
# specgroup spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits' overwrite='no' groupedset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet_final.fits' withbgdset='yes' backgndset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_inquiet.fits' withCounts='yes' mincounts='25' withminSN='no' minSN='5' withratioabovebgnd='no' ratioabovebgnd='' withoversampling='yes' oversample='3' withtemplate='no' grouptemplate='grptemplate.ds' withranges='no' ranges='' withRegularBins='no' regbinstart='' regbinend='' regbinwid='' units='CHAN' withrmfset='yes' rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_inquiet.rmf' witharfset='yes' arfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_inquiet.anc' addfilenames='yes' hightolow='no' lastbin='addtogroup' setbad='CCF'
# specgroup:- Executing (routine): specgroup spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet.fits groupedset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet_final.fits overwrite=no backgndset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_inquiet.fits withbgdset=yes mincounts=25 withCounts=yes minSN=5 withminSN=no ratioabovebgnd=0 withratioabovebgnd=no oversample=3 withoversampling=yes grouptemplate=grptemplate.ds withtemplate=no ranges='' withranges=no regbinstart=0 regbinend=0 regbinwid=0 withRegularBins=no units=CHAN rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_inquiet.rmf withrmfset=yes arfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_inquiet.anc witharfset=yes addfilenames=yes hightolow=no lastbin=addtogroup setbad=CCF  -w 1 -V 4
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T16:54:49.000
# specgroup:- Prepared spectrum /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_inquiet_final.fits with 99 groups
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T16:54:49.000

# %%
# Plot
plt.figure()
plot_spectrum('Quiet_Testing/EMOS1_spec_inquiet_final.fits', label='EMOS 1')
plot_spectrum('Quiet_Testing/EMOS2_spec_inquiet_final.fits', label='EMOS 2')
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xscale('log')
plt.legend()
plt.show()

# %% [markdown]
# ## Exclusive Quiescent

# %%
# EMOS 1
# Quiet is from time t1 to t2, t3 to t4, ang t5 to t_end

# Parameters
q_flag       = "#XMMEA_EMOS1" # Quality flag
n_pattern    = 12           # Pattern selection. Should be 12 for MOS detectors
region_1     = (24475.391, 24618.401)
radius       = 800
bkg_1        = (24475.391, 21000.5)
bkg_radius   = 1400
spec_min     = 0
spec_max     = 11999
bin_size     = 15

# Input Files
work_dir           = '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/'
event_file         = '0327_0101440801_EMOS1_S001_ImagingEvts.ds'
# Output Files
source_file        = 'Quiet_Testing/EMOS1_spec_exquiet.fits'
bkg_file           = 'Quiet_Testing/EMOS1_bkg_spec_exquiet.fits'
response_file      = 'Quiet_Testing/EMOS1_exquiet.rmf'
ancillary_file     = 'Quiet_Testing/EMOS1_exqiuet.anc'
final_file         = 'Quiet_Testing/EMOS1_spec_exquiet_final.fits'

# Extract - Special Case

# Open the event file
eventfile = work_dir + event_file

print("\n\nChecking for Event Files...\n\n")

# Extract the source spectrum
# - - - - - - - - - - - - - - - - - - -
print('\n\nExtracting source spectrum...\n\n')
source_file = work_dir + source_file  # Name of the output source spectrum

# Arguments of SAS Command

expression = f'{q_flag}&&(PATTERN<={n_pattern}) && ((X,Y) IN circle({region_1[0]},{region_1[1]},{radius}))'  # event filter expression
print(expression)

time_expression = f'&& (  ( ({t1} < TIME) && (TIME < {t2}) ) ||  ( ({t3} < TIME) && (TIME < {t4}) ) || ( ( {t5} < TIME) && (TIME < {t_end}) ) )'
# time_expression = f'&& ((({t1} < TIME) && (TIME < {t2})) ||  ( ({t3} < TIME) && (TIME < {t4}) ))'


expression = expression + time_expression
print(expression)

inargs = [f'table={event_file}', 'withspectrumset=yes', f'spectrumset={source_file}', 'energycolumn=PI',
              f'spectralbinsize={bin_size}', f'specchannelmin={spec_min}', f'specchannelmax={spec_max}',
              f'expression={expression}']

# Execute the SAS task with the parameters to produce the source spectrum
w("evselect", inargs).run()

# Extract the background spectrum
# - - - - - - - - - - - - - - - - -
print('\n\nExtracting background spectrum...\n\n')
bkg_file = work_dir + bkg_file  # Name of the output background spectrum

# Arguments of SAS Command
expression = f'{q_flag}&&(PATTERN<={n_pattern}) && ((X,Y) IN circle({bkg_1[0]},{bkg_1[1]},{bkg_radius}))  && ({time_min} < TIME) && (TIME < {time_max})'

expression = expression + time_expression
print(expression)

inargs = [f'table={event_file}', 'withspectrumset=yes', f'spectrumset={bkg_file}', 'energycolumn=PI',
          f'spectralbinsize={bin_size}', f'specchannelmin={spec_min}', f'specchannelmax={spec_max}',
          f'expression={expression}']

# Execute the SAS task with the parameters to produce the background spectrum
w("evselect", inargs).run()

# Backscale source spectrum
# - - - - - - - - - - - - - - - - - -

inargs = [f'spectrumset={source_file}', f'badpixlocation={event_file}']

print("\n\nBackscaling source spectrum...\n\n")

w("backscale", inargs).run()

# Backscale background spectrum
# - - - - - - - - - - - - - - - - - -

inargs = [f'spectrumset={bkg_file}', f'badpixlocation={event_file}']

print("\n\nBackscaling background spectrum...\n\n")

w("backscale", inargs).run()

# Generate response file
# - - - - - - - - - - - - - - - - - -
response_file = work_dir + response_file  # Name of the output redistribution

# Arguments of SAS Command
inargs = [f'spectrumset={source_file}', f'rmfset={response_file}']

print("\n\nGenerating Response File...\n\n")

w("rmfgen", inargs).run()

# Generate ancillary file
# - - - - - - - - - - - - - -
ancillary_file = work_dir + ancillary_file  # Name of the output ancillary

# SAS Command
cmd = "arfgen"  # SAS task to be executed

# Arguments of SAS Command
inargs = [f'spectrumset={source_file}', f'arfset={ancillary_file}',
          'withrmfset=yes', f'rmfset={response_file}', f'badpixlocation={event_file}', 'detmaptype=psf']

print("\n\nGenerating ancillary file...\n\n")

w("arfgen", inargs).run()

# Finalize spectrum
# - - - - - - - - - - - - - -
output_file = work_dir + final_file  # Name of the output specgruop

# Arguments of SAS Command
inargs = [f'spectrumset={source_file}', 'mincounts=25', 'oversample=3',
          f'rmfset={response_file}', f'arfset={ancillary_file}',
          f'backgndset={bkg_file}', f'groupedset={output_file}']

print("\n\nFinalizing spectrum...\n\n")

w("specgroup", inargs).run()
# Out:
# Checking for Event Files...
#
#
#
#
# Extracting source spectrum...
#
#
# #XMMEA_EMOS1&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,24618.401,800))
# #XMMEA_EMOS1&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,24618.401,800))&& (  ( (117446000 < TIME) && (TIME < 117469000) ) ||  ( (117493000 < TIME) && (TIME < 117506000) ) || ( ( 117526000 < TIME) && (TIME < 117552515.136132) ) )
# Executing:
# evselect table='0327_0101440801_EMOS1_S001_ImagingEvts.ds' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='#XMMEA_EMOS1&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,24618.401,800))&& (  ( (117446000 < TIME) && (TIME < 117469000) ) ||  ( (117493000 < TIME) && (TIME < 117506000) ) || ( ( 117526000 < TIME) && (TIME < 117552515.136132) ) )' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits' spectralbinsize='15' withspecranges='yes' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=0327_0101440801_EMOS1_S001_ImagingEvts.ds filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='#XMMEA_EMOS1&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,24618.401,800))&& (  ( (117446000 < TIME) && (TIME < 117469000) ) ||  ( (117493000 < TIME) && (TIME < 117506000) ) || ( ( 117526000 < TIME) && (TIME < 117552515.136132) ) )' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits spectralbinsize=15 specchannelmin=0 specchannelmax=11999 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:02.000
# evselect:- selected 9752 rows from the input table.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:02.000
#
#
# Extracting background spectrum...
#
#
# #XMMEA_EMOS1&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,21000.5,1400))  && (117446000 < TIME) && (TIME < 117552515.136132)&& (  ( (117446000 < TIME) && (TIME < 117469000) ) ||  ( (117493000 < TIME) && (TIME < 117506000) ) || ( ( 117526000 < TIME) && (TIME < 117552515.136132) ) )
# Executing:
# evselect table='0327_0101440801_EMOS1_S001_ImagingEvts.ds' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='#XMMEA_EMOS1&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,21000.5,1400))  && (117446000 < TIME) && (TIME < 117552515.136132)&& (  ( (117446000 < TIME) && (TIME < 117469000) ) ||  ( (117493000 < TIME) && (TIME < 117506000) ) || ( ( 117526000 < TIME) && (TIME < 117552515.136132) ) )' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_exquiet.fits' spectralbinsize='15' withspecranges='yes' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=0327_0101440801_EMOS1_S001_ImagingEvts.ds filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='#XMMEA_EMOS1&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,21000.5,1400))  && (117446000 < TIME) && (TIME < 117552515.136132)&& (  ( (117446000 < TIME) && (TIME < 117469000) ) ||  ( (117493000 < TIME) && (TIME < 117506000) ) || ( ( 117526000 < TIME) && (TIME < 117552515.136132) ) )' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_exquiet.fits spectralbinsize=15 specchannelmin=0 specchannelmax=11999 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:03.000
# evselect:- selected 832 rows from the input table.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:03.000
#
#
# Backscaling source spectrum...
#
#
# Executing:
# backscale spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits' badpixlocation='0327_0101440801_EMOS1_S001_ImagingEvts.ds' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits badpixlocation=0327_0101440801_EMOS1_S001_ImagingEvts.ds withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:04.000
# backscale:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS1_S001_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:04.000
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits...
# backscale::arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS1, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_MODEPARAM_0006.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS1, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS1_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT1, XAREAEF, 10, /Users/woodml/Observing/XMM-Newton/Calibration/XRT1_XAREAEF_0010.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# backscale::arfgen:- Using a source position in DET coordinates of x=42.3642 y=-78.9559
# backscale::arfgen:-  The source position in focal plane coords is  theta=7.09929 phi=0.411113
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=-842.8492914 xmax=927.5775935 xbins=1 ymin=-964.1694643 ymax=806.257599 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:05.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:05.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:05.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:05.000
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...2.5 2400 11997.5
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:05.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:05.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:05.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:05.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:05.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:05.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:05.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:05.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:05.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:05.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:06.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:06.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:06.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:06.000
# backscale::arfgen:- Bad pixel & chip gap fraction: ~0 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits...
# backscale::arfgen:- Opened spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits...
# backscale::arfgen:- Opened table /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits...
# backscale::arfgen:- Backscale value is: 2014100
# backscale::arfgen:- added att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits...
# backscale::arfgen:- closed spec/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:09.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:09.000
#
#
# Backscaling background spectrum...
#
#
# Executing:
# backscale spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_exquiet.fits' badpixlocation='0327_0101440801_EMOS1_S001_ImagingEvts.ds' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_exquiet.fits badpixlocation=0327_0101440801_EMOS1_S001_ImagingEvts.ds withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:09.000
# backscale:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_exquiet.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS1_S001_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:09.000
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_exquiet.fits...
# backscale::arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_exquiet.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS1, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_MODEPARAM_0006.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS1, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS1_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT1, XAREAEF, 10, /Users/woodml/Observing/XMM-Newton/Calibration/XRT1_XAREAEF_0010.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# backscale::arfgen:- Using a source position in DET coordinates of x=3637.6 y=-484.598
# backscale::arfgen:-  The source position in focal plane coords is  theta=177.458 phi=4.63469
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=2088.890334 xmax=5186.303155 xbins=1 ymin=-2033.305855 ymax=1064.110197 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:10.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:10.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:10.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:10.000
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...2.5 2400 11997.5
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:10.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:10.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:10.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:10.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:10.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:10.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:11.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:11.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:11.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:11.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:11.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:11.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:11.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:11.000
# backscale::arfgen:- Bad pixel & chip gap fraction: ~2.181283546 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_exquiet.fits...
# backscale::arfgen:- Opened spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_exquiet.fits...
# backscale::arfgen:- Opened table /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_exquiet.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_exquiet.fits...
# backscale::arfgen:- Backscale value is: 5942616
# backscale::arfgen:- added att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_exquiet.fits...
# backscale::arfgen:- closed spec/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_exquiet.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:17.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:17.000
#
#
# Generating Response File...
#
#
# Executing:
# rmfgen rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_exquiet.rmf' threshold='1e-06' withenergybins='no' energymin='0' energymax='15' nenergybins='30' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits' format='var' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='yes' detxbins='160' detybins='160' correctforpileup='no' raweventfile='rawevents.ds' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withrmfset='no' psfenergy='2' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='no' modelquantumeff='no' modelfiltertrans='no' modelcontamination='no' modelee='yes' modelootcorr='no' eegridfactor='100' withbadpixcorr='no' badpixlocation='notSpecified' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset='' psfmodel='notSpecified' withbadpixres='no' badpixelresolution='2' applyxcaladjustment='no' acceptchanrange='no' applyabsfluxcorr='no'
# rmfgen:- Executing (routine): rmfgen rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_exquiet.rmf threshold=1e-06 withenergybins=no energymin=0 energymax=15 nenergybins=30 spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits format=var detmaptype=psf detmaparray=detmapfile.ds: withdetbounds=no detxoffset=1200 detyoffset=1200 detxbins=160 detybins=160 withdetbins=yes raweventfile=rawevents.ds correctforpileup=no filterdss=yes withfilteredset=no filteredset=filteredpixellist.ds withrmfset=no psfenergy=2 withsourcepos=no sourcecoords=eqpos sourcex=0 sourcey=0 extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=no modelee=yes modelootcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no psfmodel=notSpecified badpixelresolution=2 withbadpixres=no applyxcaladjustment=no acceptchanrange=no applyabsfluxcorr=no  -w 1 -V 4
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:18.000
# Set to: notSpecified
# rmfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits...
# rmfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits.
# rmfgen:- Computing source position from region extent..
# rmfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS1, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_MODEPARAM_0006.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS1, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS1_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT1, XAREAEF, 10, /Users/woodml/Observing/XMM-Newton/Calibration/XRT1_XAREAEF_0010.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# rmfgen:- Using a source position in DET coordinates of x=42.3642 y=-78.9559
# rmfgen:-  The source position in focal plane coords is  theta=7.09929 phi=0.411113
# rmfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# rmfgen:- detector map binning will be: xbins: 160 ybins: 160
# rmfgen:- Constructing a psf detector map with  xmin=-842.8492914 xmax=927.5775935 xbins=160 ymin=-964.1694643 ymax=806.257599 ybins=160
# rmfgen:- PSF type: 2 [EXTENDED] will be used
# rmfgen:-  Creating RmfDataServer...
# rmfgen:-  EventGrades:5 PrimeFullWindow 302
# rmfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# rmfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:18.000
# rmfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:18.000
# rmfgen:-  RmfDataServer created ok.
# rmfgen:- Opening data set ...
# rmfgen:- Opened data set.
# rmfgen:- Adding MATRIX table. There will be 2400 rows in table
# rmfgen:- Initialising table iterator ..
# rmfgen:- Populating table ..
# rmfgen:- No groups found for row 0 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 1 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 2 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 3 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 4 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 5 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- Adding EBOUNDS extension ...
# rmfgen:-  Cleanup ...
# rmfgen:-  Closing data set ...
# rmfgen:-  Closed data set.
# rmfgen:-  Cleanup complete.
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:46.000
#
#
# Generating ancillary file...
#
#
# Executing:
# arfgen spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits' withrmfset='yes' rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_exquiet.rmf' arfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_exqiuet.anc' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='no' detxbins='5' detybins='5' psfenergy='2' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='yes' modelquantumeff='yes' modelfiltertrans='yes' modelcontamination='yes' modelee='yes' modelootcorr='yes' applyxcaladjustment='no' applyabsfluxcorr='no' eegridfactor='100' withbadpixcorr='yes' badpixlocation='0327_0101440801_EMOS1_S001_ImagingEvts.ds' psfmodel='ELLBETA' withbadpixres='no' badpixelresolution='2' badpixmaptype='flat' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset=''
# arfgen:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_exquiet.rmf withrmfset=yes arfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_exqiuet.anc detmaptype=psf detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS1_S001_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:47.000
# arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits...
# arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits.
# arfgen:- Computing source position from region extent..
# arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS1, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_MODEPARAM_0006.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS1, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS1, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS1_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS1, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS1_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT1, XAREAEF, 10, /Users/woodml/Observing/XMM-Newton/Calibration/XRT1_XAREAEF_0010.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# arfgen:- Using a source position in DET coordinates of x=42.3642 y=-78.9559
# arfgen:-  The source position in focal plane coords is  theta=7.09929 phi=0.411113
# arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# arfgen:- detector map binning will be: xbins: 5 ybins: 5
# arfgen:- Constructing a psf detector map with  xmin=-842.8492914 xmax=927.5775935 xbins=5 ymin=-964.1694643 ymax=806.257599 ybins=5
# arfgen:- PSF type: 3 [ELLBETA] will be used
# arfgen:- Opening arfset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_exqiuet.anc...
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:47.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:47.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:47.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:47.000
# Making file temp_badcol.ds
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- Writing energy data into dataset ..
# arfgen:- Calculating Area curve ...
# arfgen:- Calculating Area curve ...2.499999944 2400 11997.49994
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:48.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:48.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:48.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:48.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:48.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:48.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:48.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:48.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:48.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:48.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:49.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:49.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:49.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:49.000
# arfgen:- Bad pixel & chip gap fraction: ~0 %
# arfgen:- Writing area data into dataset ..
# arfgen:- Closing arfset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_exqiuet.anc.
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:54.000
#
#
# Finalizing spectrum...
#
#
# Executing:
# specgroup spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits' overwrite='no' groupedset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet_final.fits' withbgdset='yes' backgndset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_exquiet.fits' withCounts='yes' mincounts='25' withminSN='no' minSN='5' withratioabovebgnd='no' ratioabovebgnd='' withoversampling='yes' oversample='3' withtemplate='no' grouptemplate='grptemplate.ds' withranges='no' ranges='' withRegularBins='no' regbinstart='' regbinend='' regbinwid='' units='CHAN' withrmfset='yes' rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_exquiet.rmf' witharfset='yes' arfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_exqiuet.anc' addfilenames='yes' hightolow='no' lastbin='addtogroup' setbad='CCF'
# specgroup:- Executing (routine): specgroup spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet.fits groupedset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet_final.fits overwrite=no backgndset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_bkg_spec_exquiet.fits withbgdset=yes mincounts=25 withCounts=yes minSN=5 withminSN=no ratioabovebgnd=0 withratioabovebgnd=no oversample=3 withoversampling=yes grouptemplate=grptemplate.ds withtemplate=no ranges='' withranges=no regbinstart=0 regbinend=0 regbinwid=0 withRegularBins=no units=CHAN rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_exquiet.rmf withrmfset=yes arfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_exqiuet.anc witharfset=yes addfilenames=yes hightolow=no lastbin=addtogroup setbad=CCF  -w 1 -V 4
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:06:55.000
# specgroup:- Prepared spectrum /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS1_spec_exquiet_final.fits with 81 groups
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:06:55.000

# %%
# EMOS 2
# Quiet is from time t1 to t2, t3 to t4, ang t5 to t_end

# Parameters
q_flag       = "#XMMEA_EMOS2" # Quality flag
n_pattern    = 12           # Pattern selection. Should be 12 for MOS detectors
region_1     = (24475.391, 24618.401)
radius       = 800
bkg_1        = (24475.391, 21000.5)
bkg_radius   = 1400
spec_min     = 0
spec_max     = 11999
bin_size     = 15

# Input Files
work_dir           = '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/'
event_file         = '0327_0101440801_EMOS2_S002_ImagingEvts.ds'
# Output Files
source_file        = 'Quiet_Testing/EMOS2_spec_exquiet.fits'
bkg_file           = 'Quiet_Testing/EMOS2_bkg_spec_exquiet.fits'
response_file      = 'Quiet_Testing/EMOS2_exquiet.rmf'
ancillary_file     = 'Quiet_Testing/EMOS2_exqiuet.anc'
final_file         = 'Quiet_Testing/EMOS2_spec_exquiet_final.fits'

# Extract - Special Case

# Open the event file
eventfile = work_dir + event_file

print("\n\nChecking for Event Files...\n\n")

# Extract the source spectrum
# - - - - - - - - - - - - - - - - - - -
print('\n\nExtracting source spectrum...\n\n')
source_file = work_dir + source_file  # Name of the output source spectrum

# Arguments of SAS Command

expression = f'{q_flag}&&(PATTERN<={n_pattern}) && ((X,Y) IN circle({region_1[0]},{region_1[1]},{radius}))'  # event filter expression
print(expression)

time_expression = f'&& (  ( ({t1} < TIME) && (TIME < {t2}) ) ||  ( ({t3} < TIME) && (TIME < {t4}) ) || ( ( {t5} < TIME) && (TIME < {t_end}) ) )'
# time_expression = f'&& ((({t1} < TIME) && (TIME < {t2})) ||  ( ({t3} < TIME) && (TIME < {t4}) ))'


expression = expression + time_expression
print(expression)

inargs = [f'table={event_file}', 'withspectrumset=yes', f'spectrumset={source_file}', 'energycolumn=PI',
              f'spectralbinsize={bin_size}', f'specchannelmin={spec_min}', f'specchannelmax={spec_max}',
              f'expression={expression}']

# Execute the SAS task with the parameters to produce the source spectrum
w("evselect", inargs).run()

# Extract the background spectrum
# - - - - - - - - - - - - - - - - -
print('\n\nExtracting background spectrum...\n\n')
bkg_file = work_dir + bkg_file  # Name of the output background spectrum

# Arguments of SAS Command
expression = f'{q_flag}&&(PATTERN<={n_pattern}) && ((X,Y) IN circle({bkg_1[0]},{bkg_1[1]},{bkg_radius}))  && ({time_min} < TIME) && (TIME < {time_max})'

expression = expression + time_expression
print(expression)

inargs = [f'table={event_file}', 'withspectrumset=yes', f'spectrumset={bkg_file}', 'energycolumn=PI',
          f'spectralbinsize={bin_size}', f'specchannelmin={spec_min}', f'specchannelmax={spec_max}',
          f'expression={expression}']

# Execute the SAS task with the parameters to produce the background spectrum
w("evselect", inargs).run()

# Backscale source spectrum
# - - - - - - - - - - - - - - - - - -

inargs = [f'spectrumset={source_file}', f'badpixlocation={event_file}']

print("\n\nBackscaling source spectrum...\n\n")

w("backscale", inargs).run()

# Backscale background spectrum
# - - - - - - - - - - - - - - - - - -

inargs = [f'spectrumset={bkg_file}', f'badpixlocation={event_file}']

print("\n\nBackscaling background spectrum...\n\n")

w("backscale", inargs).run()

# Generate response file
# - - - - - - - - - - - - - - - - - -
response_file = work_dir + response_file  # Name of the output redistribution

# Arguments of SAS Command
inargs = [f'spectrumset={source_file}', f'rmfset={response_file}']

print("\n\nGenerating Response File...\n\n")

w("rmfgen", inargs).run()

# Generate ancillary file
# - - - - - - - - - - - - - -
ancillary_file = work_dir + ancillary_file  # Name of the output ancillary

# SAS Command
cmd = "arfgen"  # SAS task to be executed

# Arguments of SAS Command
inargs = [f'spectrumset={source_file}', f'arfset={ancillary_file}',
          'withrmfset=yes', f'rmfset={response_file}', f'badpixlocation={event_file}', 'detmaptype=psf']

print("\n\nGenerating ancillary file...\n\n")

w("arfgen", inargs).run()

# Finalize spectrum
# - - - - - - - - - - - - - -
output_file = work_dir + final_file  # Name of the output specgruop

# Arguments of SAS Command
inargs = [f'spectrumset={source_file}', 'mincounts=25', 'oversample=3',
          f'rmfset={response_file}', f'arfset={ancillary_file}',
          f'backgndset={bkg_file}', f'groupedset={output_file}']

print("\n\nFinalizing spectrum...\n\n")

w("specgroup", inargs).run()
# Out:
# Checking for Event Files...
#
#
#
#
# Extracting source spectrum...
#
#
# #XMMEA_EMOS2&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,24618.401,800))
# #XMMEA_EMOS2&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,24618.401,800))&& (  ( (117446000 < TIME) && (TIME < 117469000) ) ||  ( (117493000 < TIME) && (TIME < 117506000) ) || ( ( 117526000 < TIME) && (TIME < 117552515.136132) ) )
# Executing:
# evselect table='0327_0101440801_EMOS2_S002_ImagingEvts.ds' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='#XMMEA_EMOS2&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,24618.401,800))&& (  ( (117446000 < TIME) && (TIME < 117469000) ) ||  ( (117493000 < TIME) && (TIME < 117506000) ) || ( ( 117526000 < TIME) && (TIME < 117552515.136132) ) )' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits' spectralbinsize='15' withspecranges='yes' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=0327_0101440801_EMOS2_S002_ImagingEvts.ds filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='#XMMEA_EMOS2&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,24618.401,800))&& (  ( (117446000 < TIME) && (TIME < 117469000) ) ||  ( (117493000 < TIME) && (TIME < 117506000) ) || ( ( 117526000 < TIME) && (TIME < 117552515.136132) ) )' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits spectralbinsize=15 specchannelmin=0 specchannelmax=11999 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:34.000
# evselect:- selected 9949 rows from the input table.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:34.000
#
#
# Extracting background spectrum...
#
#
# #XMMEA_EMOS2&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,21000.5,1400))  && (117446000 < TIME) && (TIME < 117552515.136132)&& (  ( (117446000 < TIME) && (TIME < 117469000) ) ||  ( (117493000 < TIME) && (TIME < 117506000) ) || ( ( 117526000 < TIME) && (TIME < 117552515.136132) ) )
# Executing:
# evselect table='0327_0101440801_EMOS2_S002_ImagingEvts.ds' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='#XMMEA_EMOS2&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,21000.5,1400))  && (117446000 < TIME) && (TIME < 117552515.136132)&& (  ( (117446000 < TIME) && (TIME < 117469000) ) ||  ( (117493000 < TIME) && (TIME < 117506000) ) || ( ( 117526000 < TIME) && (TIME < 117552515.136132) ) )' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_exquiet.fits' spectralbinsize='15' withspecranges='yes' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=0327_0101440801_EMOS2_S002_ImagingEvts.ds filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='#XMMEA_EMOS2&&(PATTERN<=12) && ((X,Y) IN circle(24475.391,21000.5,1400))  && (117446000 < TIME) && (TIME < 117552515.136132)&& (  ( (117446000 < TIME) && (TIME < 117469000) ) ||  ( (117493000 < TIME) && (TIME < 117506000) ) || ( ( 117526000 < TIME) && (TIME < 117552515.136132) ) )' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_exquiet.fits spectralbinsize=15 specchannelmin=0 specchannelmax=11999 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:35.000
# evselect:- selected 743 rows from the input table.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:36.000
#
#
# Backscaling source spectrum...
#
#
# Executing:
# backscale spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits' badpixlocation='0327_0101440801_EMOS2_S002_ImagingEvts.ds' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits badpixlocation=0327_0101440801_EMOS2_S002_ImagingEvts.ds withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:36.000
# backscale:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS2_S002_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:36.000
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits...
# backscale::arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS2, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_MODEPARAM_0006.CCF, 1999-01-01T00:00:00.000}
# CifEntry{EMOS2, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS2, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS2_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT2, XAREAEF, 11, /Users/woodml/Observing/XMM-Newton/Calibration/XRT2_XAREAEF_0011.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# backscale::arfgen:- Using a source position in DET coordinates of x=-91.2093 y=-174.3
# backscale::arfgen:-  The source position in focal plane coords is  theta=63.0315 phi=5.23626
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=-980.0839386 xmax=797.6654191 xbins=1 ymin=-1063.174246 ymax=714.5748887 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:37.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:37.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:37.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:37.000
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...2.5 2400 11997.5
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:37.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:37.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:37.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:37.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:37.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:37.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:37.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:37.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:38.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:38.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:38.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:38.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:38.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:38.000
# backscale::arfgen:- Bad pixel & chip gap fraction: ~0.7973605354 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits...
# backscale::arfgen:- Opened spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits...
# backscale::arfgen:- Opened table /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits...
# backscale::arfgen:- Backscale value is: 1926028
# backscale::arfgen:- added att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits...
# backscale::arfgen:- closed spec/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:43.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:43.000
#
#
# Backscaling background spectrum...
#
#
# Executing:
# backscale spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_exquiet.fits' badpixlocation='0327_0101440801_EMOS2_S002_ImagingEvts.ds' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_exquiet.fits badpixlocation=0327_0101440801_EMOS2_S002_ImagingEvts.ds withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:44.000
# backscale:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_exquiet.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS2_S002_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:44.000
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_exquiet.fits...
# backscale::arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_exquiet.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS2, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_MODEPARAM_0006.CCF, 1999-01-01T00:00:00.000}
# CifEntry{EMOS2, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS2, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS2_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT2, XAREAEF, 11, /Users/woodml/Observing/XMM-Newton/Calibration/XRT2_XAREAEF_0011.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# backscale::arfgen:- Using a source position in DET coordinates of x=332.809 y=3419.1
# backscale::arfgen:-  The source position in focal plane coords is  theta=234.459 phi=4.75647
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=-1222.30431 xmax=1887.922762 xbins=1 ymin=1863.991922 ymax=4974.215385 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:44.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:44.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:44.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:44.000
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...2.5 2400 11997.5
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:45.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:45.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:45.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:45.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:45.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:45.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:45.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:45.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:45.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:45.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:45.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:45.000
# backscale::arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:45.000
# backscale::arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:45.000
# backscale::arfgen:- Bad pixel & chip gap fraction: ~0.2820498115 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_exquiet.fits...
# backscale::arfgen:- Opened spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_exquiet.fits...
# backscale::arfgen:- Opened table /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_exquiet.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_exquiet.fits...
# backscale::arfgen:- Backscale value is: 5947624
# backscale::arfgen:- added att/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_exquiet.fits...
# backscale::arfgen:- closed spec/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_exquiet.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:52.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:52.000
#
#
# Generating Response File...
#
#
# Executing:
# rmfgen rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_exquiet.rmf' threshold='1e-06' withenergybins='no' energymin='0' energymax='15' nenergybins='30' spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits' format='var' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='yes' detxbins='160' detybins='160' correctforpileup='no' raweventfile='rawevents.ds' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withrmfset='no' psfenergy='2' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='no' modelquantumeff='no' modelfiltertrans='no' modelcontamination='no' modelee='yes' modelootcorr='no' eegridfactor='100' withbadpixcorr='no' badpixlocation='notSpecified' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset='' psfmodel='notSpecified' withbadpixres='no' badpixelresolution='2' applyxcaladjustment='no' acceptchanrange='no' applyabsfluxcorr='no'
# rmfgen:- Executing (routine): rmfgen rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_exquiet.rmf threshold=1e-06 withenergybins=no energymin=0 energymax=15 nenergybins=30 spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits format=var detmaptype=psf detmaparray=detmapfile.ds: withdetbounds=no detxoffset=1200 detyoffset=1200 detxbins=160 detybins=160 withdetbins=yes raweventfile=rawevents.ds correctforpileup=no filterdss=yes withfilteredset=no filteredset=filteredpixellist.ds withrmfset=no psfenergy=2 withsourcepos=no sourcecoords=eqpos sourcex=0 sourcey=0 extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=no modelee=yes modelootcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no psfmodel=notSpecified badpixelresolution=2 withbadpixres=no applyxcaladjustment=no acceptchanrange=no applyabsfluxcorr=no  -w 1 -V 4
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:52.000
# Set to: notSpecified
# rmfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits...
# rmfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits.
# rmfgen:- Computing source position from region extent..
# rmfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS2, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_MODEPARAM_0006.CCF, 1999-01-01T00:00:00.000}
# CifEntry{EMOS2, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS2, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS2_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT2, XAREAEF, 11, /Users/woodml/Observing/XMM-Newton/Calibration/XRT2_XAREAEF_0011.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# rmfgen:- Using a source position in DET coordinates of x=-91.2093 y=-174.3
# rmfgen:-  The source position in focal plane coords is  theta=63.0315 phi=5.23626
# rmfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# rmfgen:- detector map binning will be: xbins: 160 ybins: 160
# rmfgen:- Constructing a psf detector map with  xmin=-980.0839386 xmax=797.6654191 xbins=160 ymin=-1063.174246 ymax=714.5748887 ybins=160
# rmfgen:- PSF type: 2 [EXTENDED] will be used
# rmfgen:-  Creating RmfDataServer...
# rmfgen:-  EventGrades:5 PrimeFullWindow 296
# rmfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# rmfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:08:53.000
# rmfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:08:53.000
# rmfgen:-  RmfDataServer created ok.
# rmfgen:- Opening data set ...
# rmfgen:- Opened data set.
# rmfgen:- Adding MATRIX table. There will be 2400 rows in table
# rmfgen:- Initialising table iterator ..
# rmfgen:- Populating table ..
# rmfgen:- No groups found for row 0 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 1 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 2 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 3 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 4 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- No groups found for row 5 Will fill F_CHAN, N_CHAN and MATRIX columns with zeroes
# rmfgen:- Adding EBOUNDS extension ...
# rmfgen:-  Cleanup ...
# rmfgen:-  Closing data set ...
# rmfgen:-  Closed data set.
# rmfgen:-  Cleanup complete.
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:09:19.000
#
#
# Generating ancillary file...
#
#
# Executing:
# arfgen spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits' withrmfset='yes' rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_exquiet.rmf' arfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_exqiuet.anc' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='no' detxbins='5' detybins='5' psfenergy='2' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='yes' modelquantumeff='yes' modelfiltertrans='yes' modelcontamination='yes' modelee='yes' modelootcorr='yes' applyxcaladjustment='no' applyabsfluxcorr='no' eegridfactor='100' withbadpixcorr='yes' badpixlocation='0327_0101440801_EMOS2_S002_ImagingEvts.ds' psfmodel='ELLBETA' withbadpixres='no' badpixelresolution='2' badpixmaptype='flat' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset=''
# arfgen:- Executing (routine): arfgen spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_exquiet.rmf withrmfset=yes arfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_exqiuet.anc detmaptype=psf detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=0327_0101440801_EMOS2_S002_ImagingEvts.ds psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:09:20.000
# arfgen:- Opening spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits...
# arfgen:- Closing spectrumset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits.
# arfgen:- Computing source position from region extent..
# arfgen:- CCF constituents accessed by the calibration server:
# CifEntry{EMOS2, CONTAMINATION, 2, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_CONTAMINATION_0002.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, FILTERTRANSX, 15, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_FILTERTRANSX_0015.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, LINCOORD, 18, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_LINCOORD_0018.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, MODEPARAM, 6, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_MODEPARAM_0006.CCF, 1999-01-01T00:00:00.000}
# CifEntry{EMOS2, PATTERNLIB, 5, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_PATTERNLIB_0005.CCF, 1998-01-01T00:00:00.000}
# CifEntry{EMOS2, QUANTUMEF, 20, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_QUANTUMEF_0020.CCF, 2000-01-01T00:00:00.000}
# CifEntry{EMOS2, TIMECORR, 3, /Users/woodml/Observing/XMM-Newton/Calibration/EMOS2_TIMECORR_0003.CCF, 1998-01-01T00:00:00.000}
# CifEntry{RGS2, LINCOORD, 8, /Users/woodml/Observing/XMM-Newton/Calibration/RGS2_LINCOORD_0008.CCF, 1998-01-01T00:00:00.000}
# CifEntry{XMM, ABSCOEFS, 4, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_ABSCOEFS_0004.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XMM, BORESIGHT, 33, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_BORESIGHT_0033.CCF, 2000-01-01T00:00:00.000}
# CifEntry{XMM, MISCDATA, 22, /Users/woodml/Observing/XMM-Newton/Calibration/XMM_MISCDATA_0022.CCF, 1999-01-01T00:00:00.000}
# CifEntry{XRT2, XAREAEF, 11, /Users/woodml/Observing/XMM-Newton/Calibration/XRT2_XAREAEF_0011.CCF, 2000-01-13T00:00:00.000}
# CifEntry{XRT3, XAREAEF, 14, /Users/woodml/Observing/XMM-Newton/Calibration/XRT3_XAREAEF_0014.CCF, 2000-01-13T00:00:00.000}
#
#
# arfgen:- Using a source position in DET coordinates of x=-91.2093 y=-174.3
# arfgen:-  The source position in focal plane coords is  theta=63.0315 phi=5.23626
# arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# arfgen:- detector map binning will be: xbins: 5 ybins: 5
# arfgen:- Constructing a psf detector map with  xmin=-980.0839386 xmax=797.6654191 xbins=5 ymin=-1063.174246 ymax=714.5748887 ybins=5
# arfgen:- PSF type: 3 [ELLBETA] will be used
# arfgen:- Opening arfset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_exqiuet.anc...
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:09:20.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:09:20.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:09:20.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:09:20.000
# Making file temp_badcol.ds
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX01:RAWX and temp_badcol.ds:BADPIX01:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX02:RAWX and temp_badcol.ds:BADPIX02:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX03:RAWX and temp_badcol.ds:BADPIX03:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX05:RAWX and temp_badcol.ds:BADPIX05:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX06:RAWX and temp_badcol.ds:BADPIX06:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX07:RAWX and temp_badcol.ds:BADPIX07:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- Writing energy data into dataset ..
# arfgen:- Calculating Area curve ...
# arfgen:- Calculating Area curve ...2.499999944 2400 11997.49994
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:09:21.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:09:21.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:09:21.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:09:21.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:09:21.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:09:21.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:09:21.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:09:21.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:09:21.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:09:21.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:09:22.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:09:22.000
# arfgen:- Executing (routine): attcalc eventset=rawpixellist.ds:EVENTS fixedra=73.97325 fixeddec=30.585333 fixedposangle=83.562321 attitudelabel=fixed nominalra=73.97325 nominaldec=30.585333 setpnttouser=no refpointlabel=user atthkset=atthk.dat withatthkset=no withmedianpnt=yes calctlmax=no imagesize=0.36  -w 1 -V 4
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:09:22.000
# arfgen:- attcalc (attcalc-4.39)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:09:22.000
# arfgen:- Bad pixel & chip gap fraction: ~0.9305712143 %
# arfgen:- Writing area data into dataset ..
# arfgen:- Closing arfset /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_exqiuet.anc.
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:09:29.000
#
#
# Finalizing spectrum...
#
#
# Executing:
# specgroup spectrumset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits' overwrite='no' groupedset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet_final.fits' withbgdset='yes' backgndset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_exquiet.fits' withCounts='yes' mincounts='25' withminSN='no' minSN='5' withratioabovebgnd='no' ratioabovebgnd='' withoversampling='yes' oversample='3' withtemplate='no' grouptemplate='grptemplate.ds' withranges='no' ranges='' withRegularBins='no' regbinstart='' regbinend='' regbinwid='' units='CHAN' withrmfset='yes' rmfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_exquiet.rmf' witharfset='yes' arfset='/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_exqiuet.anc' addfilenames='yes' hightolow='no' lastbin='addtogroup' setbad='CCF'
# specgroup:- Executing (routine): specgroup spectrumset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet.fits groupedset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet_final.fits overwrite=no backgndset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_bkg_spec_exquiet.fits withbgdset=yes mincounts=25 withCounts=yes minSN=5 withminSN=no ratioabovebgnd=0 withratioabovebgnd=no oversample=3 withoversampling=yes grouptemplate=grptemplate.ds withtemplate=no ranges='' withranges=no regbinstart=0 regbinend=0 regbinwid=0 withRegularBins=no units=CHAN rmfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_exquiet.rmf withrmfset=yes arfset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_exqiuet.anc witharfset=yes addfilenames=yes hightolow=no lastbin=addtogroup setbad=CCF  -w 1 -V 4
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-05-15T17:09:30.000
# specgroup:- Prepared spectrum /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/Flare_Testing/EMOS2_spec_exquiet_final.fits with 82 groups
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-05-15T17:09:30.000

# %% [markdown]
# # Plot & Compare

# %%
plt.figure(figsize=(8,3))
plot_spectrum('Quiet_Testing/EMOS1_spec_inquiet_final.fits', label='Inclusive')
plot_spectrum('Quiet_Testing/EMOS1_spec_exquiet_final.fits', label='Exclusive')
plt.legend(loc='upper right')
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xscale('log')
plt.title('EMOS 1 Comparison')
plt.show()

plt.figure(figsize=(8,3))
plot_spectrum('Quiet_Testing/EMOS2_spec_inquiet_final.fits', label='Inclusive')
plot_spectrum('Quiet_Testing/EMOS2_spec_exquiet_final.fits', label='Exclusive')
plt.legend(loc='upper right')
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xscale('log')
plt.title('EMOS 2 Comparison')
plt.show()
