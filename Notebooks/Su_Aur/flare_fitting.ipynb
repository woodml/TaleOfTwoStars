# %% [markdown]
# Environment: ciao-4.15

# %%
from sherpa.astro import ui

import numpy as np
import astropy.units as u
import astropy.constants as c
from astropy.io import fits
from astropy.table import Table

import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Georgia']
rcParams['font.weight'] = 'bold'
rcParams['axes.labelweight'] = 'bold'
rcParams['axes.linewidth'] = 1

# %% [markdown]
# # Load 2002 Flare Data

# %%
ui.load_data('2002_emos1', '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_flare_final.fits')

ui.load_data('2002_emos2', '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_flare_final.fits')

ui.set_analysis('wave')  # set analysis to give wavelength instead of channel, needs a loaded rmf

ui.ignore_id('2002_emos1', 25, None)
ui.ignore_id('2002_emos2', 25, None)

ui.group_counts('2002_emos1', 20)
ui.group_counts('2002_emos2', 20)
# Out:
# read ARF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_flare.anc
# read RMF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_flare.rmf
# read background file /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_bkg_spec_flare.fits
# read ARF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_flare.anc
# read RMF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_flare.rmf
# read background file /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_bkg_spec_flare.fits
# dataset 2002_emos1: 1.0332:inf -> 1.0332:24.3106 Wavelength (Angstrom)
# dataset 2002_emos2: 1.0332:inf -> 1.0332:22.96 Wavelength (Angstrom)
# /Users/woodml/anaconda3/envs/ciao-4.15/lib/python3.10/site-packages/sherpa/astro/data.py:990: UserWarning: The minimum ENERG_LO in the ARF '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_flare.anc' was 0 and has been replaced by 1e-10
#   warnings.warn(wmsg)
# /Users/woodml/anaconda3/envs/ciao-4.15/lib/python3.10/site-packages/sherpa/astro/data.py:990: UserWarning: The minimum ENERG_LO in the RMF '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_flare.rmf' was 0 and has been replaced by 1e-10
#   warnings.warn(wmsg)
# /Users/woodml/anaconda3/envs/ciao-4.15/lib/python3.10/site-packages/sherpa/astro/data.py:990: UserWarning: The minimum ENERG_LO in the ARF '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_flare.anc' was 0 and has been replaced by 1e-10
#   warnings.warn(wmsg)
# /Users/woodml/anaconda3/envs/ciao-4.15/lib/python3.10/site-packages/sherpa/astro/data.py:990: UserWarning: The minimum ENERG_LO in the RMF '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_flare.rmf' was 0 and has been replaced by 1e-10
#   warnings.warn(wmsg)

# %%
plt.figure(figsize=(10,3))
ui.plot_data('2002_emos1')
ui.plot_data('2002_emos2', overplot=True)
plt.title('SU Aur - EMOS 1 & 2')
g = plt.gcf().axes
g[0].lines[1].set_label('EMOS 1 - 2002')
g[0].lines[3].set_label('EMOS 2 - 2002')
plt.legend()
plt.show()

# %%
ui.subtract('2002_emos1')
ui.subtract('2002_emos2')

# %% [markdown]
# # Load 2012 Flare Data

# %%
ui.load_data('2012_emos1', '/Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS1_spec_flare_final.fits')

ui.load_data('2012_emos2', '/Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS2_spec_flare_final.fits')

ui.set_analysis('wave')  # set analysis to give wavelength instead of channel, needs a loaded rmf

ui.ignore_id('2012_emos1', 25, None)
ui.ignore_id('2012_emos2', 25, None)

ui.group_counts('2012_emos1', 20)
ui.group_counts('2012_emos2', 20)
# Out:
# read ARF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS1_flare.anc
# read RMF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS1_flare.rmf
# read background file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS1_bkg_spec_flare.fits
# read ARF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS2_flare.anc
# read RMF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS2_flare.rmf
# read background file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS2_bkg_spec_flare.fits
# dataset 2012_emos1: 1.0332:inf -> 1.0332:21.7516 Wavelength (Angstrom)
# dataset 2012_emos2: 1.0332:inf -> 1.0332:20.664 Wavelength (Angstrom)
# /Users/woodml/anaconda3/envs/ciao-4.15/lib/python3.10/site-packages/sherpa/astro/data.py:990: UserWarning: The minimum ENERG_LO in the ARF '/Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS1_flare.anc' was 0 and has been replaced by 1e-10
#   warnings.warn(wmsg)
# /Users/woodml/anaconda3/envs/ciao-4.15/lib/python3.10/site-packages/sherpa/astro/data.py:990: UserWarning: The minimum ENERG_LO in the RMF '/Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS1_flare.rmf' was 0 and has been replaced by 1e-10
#   warnings.warn(wmsg)
# /Users/woodml/anaconda3/envs/ciao-4.15/lib/python3.10/site-packages/sherpa/astro/data.py:990: UserWarning: The minimum ENERG_LO in the ARF '/Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS2_flare.anc' was 0 and has been replaced by 1e-10
#   warnings.warn(wmsg)
# /Users/woodml/anaconda3/envs/ciao-4.15/lib/python3.10/site-packages/sherpa/astro/data.py:990: UserWarning: The minimum ENERG_LO in the RMF '/Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS2_flare.rmf' was 0 and has been replaced by 1e-10
#   warnings.warn(wmsg)

# %%
ui.load_data('2012_epn', '/Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EPN_spec_flare_final.fits')

ui.set_analysis('wave')  # set analysis to give wavelength instead of channel, needs a loaded rmf

ui.ignore_id('2012_epn', 25, None)  # wave

ui.group_counts('2012_epn', 20)
# Out:
# read ARF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EPN_flare.anc
# read RMF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EPN_flare.rmf
# read background file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EPN_bkg_spec_flare.fits
# dataset 2012_epn: 0.605392:inf -> 0.605392:24.3106 Wavelength (Angstrom)

# %%
plt.figure(figsize=(10,3))
ui.plot_data('2012_emos1')
ui.plot_data('2012_emos2', overplot=True)
ui.plot_data('2012_epn', overplot=True)
plt.title('SU Aur - EMOS 1 & 2')
g = plt.gcf().axes
g[0].lines[1].set_label('EMOS 1 - 2012')
g[0].lines[3].set_label('EMOS 2 - 2012')
plt.legend()
plt.show()

# %%
ui.subtract('2012_emos1')
ui.subtract('2012_emos2')
ui.subtract('2012_epn')

# %%
# Set Fit Parameters
ui.set_xsabund('aspl')
ui.set_method('levmar')
ui.set_stat('chi2gehrels')
# Out:
#  Solar Abundance Vector set to aspl:  Asplund M., Grevesse N., Sauval A.J. & Scott P., ARAA, 47, 481 (2009)

# %% [markdown]
# # Model B
#
# ## 2002

# %%
ui.set_source('2002_emos1', ui.xsphabs.abs1*(ui.xsvapec.v1 + ui.xsvapec.v2 + ui.xsvapec.v3))
ui.set_source('2002_emos2', abs1*(v1 + v2 + v3))

# %%
# Reset Links
for v in (v1, v2, v3):
    for p in v.pars[1:-1]:
        p.link = None

# %%
abs1.nH = 0.374948
v1.kT =  0.756257
v2.kT =  1.93027
v3.kT =  5.7593
v1.norm = 0.000548224
v2.norm = 0.000987716
v3.norm = 0.0014265
 
v1.O  = 0.469211
v1.Ne = 3.36361
v1.Fe = 0.815142 

# Unlock/Lock parameters
abs1.nH.frozen = 0
v1.norm.frozen = 0
v2.norm.frozen = 0
v3.norm.frozen = 0
v1.kT.frozen = 0
v2.kT.frozen = 0
v3.kT.frozen = 0

v1.O.frozen  = 0
v1.Ne.frozen = 0
v1.Fe.frozen = 0

# Links
v1.Al = v1.Fe
v1.Ca = v1.Fe
v1.Mg = v1.Fe
v1.Si = v1.Fe
v1.Ni = v1.Fe

v1.C = v1.O
v1.N = v1.O
v1.S = v1.O

for v in (v2, v3):
    for p in v.pars[1:-1]:
        p.link = getattr(v1, p.name)

# %%
ui.fit('2002_emos1', '2002_emos2')
# Out:
# Datasets              = '2002_emos1', '2002_emos2'
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 354.441
# Final fit statistic   = 247.221 at function evaluation 110
# Data points           = 342
# Degrees of freedom    = 332
# Probability [Q-value] = 0.999838
# Reduced statistic     = 0.744642
# Change in statistic   = 107.22
#    abs1.nH        0.374736     +/- 0.0276544
#    v1.kT          0.756326     +/- 0.0321066
#    v1.O           0.469442     +/- 0.226619
#    v1.Ne          3.37785      +/- 1.12698
#    v1.Fe          0.816926     +/- 0.144697
#    v1.norm        0.000406517  +/- 7.94646e-05
#    v2.kT          1.93276      +/- 0.38274
#    v2.norm        0.00179236   +/- 0.000529988
#    v3.kT          5.75937      +/- 2.33749
#    v3.norm        0.00101957   +/- 0.000584439

# %%
# Plot
el = ['He','C','N','O','Ne','Mg','Fe', 'Al','Si']
caption = "".join(['%s = %.3f \n' %(e, ui.get_par('v1.'+e).val) for e in el])

plt.figure(figsize=(10,3.5))
ui.plot_fit('2002_emos1')
ui.plot_fit('2002_emos2', overplot=True)
g = plt.gcf().axes
g[0].lines[1].set_label('EMOS 1')
g[0].lines[1].set_markersize(10)
g[0].lines[1].set_markeredgecolor('k')
g[0].lines[5].set_label('EMOS 2')
g[0].lines[5].set_markersize(10)
g[0].lines[5].set_markeredgecolor('k')
plt.xlim(0.2, 20)
plt.vlines([12.135, 10.239],         0, 0.05, 'k','--', label='Ne')  
plt.vlines([8.4245, 7.1069, 9.1688], 0, 0.05, 'k','-.', label='Mg')
plt.vlines([6.18, 5.21],             0, 0.05, 'k',':', label='Si')
plt.vlines([4.7273, 4.7327],         0, 0.05, 'k',(0,(5,3,1,3,1,3)), label='S')
plt.vlines([3.7311, 3.15],           0, 0.05, 'k',(0,(1,5)), label='Ar')
plt.vlines([1.778, 1.5024],          0, 0.05, 'k',(0,(6,2)), label='Fe')
plt.vlines([16.006],                 0, 0.05, 'k',(0,(5,2,1,2,5,2)), label='O')
# plt.text(0.95, 0.35, caption, transform=g[0].transAxes, horizontalalignment='right')
plt.xlabel('Wavelength (Angstroms)')
plt.title('2002 EMOS Flare')
plt.legend(loc=(1.01, 0.2))
plt.show()

# %%
ui.covar('2002_emos1','2002_emos2')
cov = ui.get_covar_results()
# Out:
# WARNING: hard minimum hit for parameter abs1.nH
# WARNING: hard maximum hit for parameter abs1.nH
# Datasets              = '2002_emos1', '2002_emos2'
# Confidence Method     = covariance
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# covariance 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    abs1.nH          0.374736        -----        -----
#    v1.kT            0.756326  -0.00697446   0.00697446
#    v1.O             0.469442    -0.209145     0.209145
#    v1.Ne             3.37785    -0.553919     0.553919
#    v1.Fe            0.816926   -0.0821219    0.0821219
#    v1.norm       0.000406517 -6.00966e-05  6.00966e-05
#    v2.kT             1.93276   -0.0294387    0.0294387
#    v2.norm        0.00179236 -0.000206552  0.000206552
#    v3.kT             5.75937    -0.240002     0.240002
#    v3.norm        0.00101957 -0.000170631  0.000170631

# %%
# Write out
# Create table
output_2002 = Table(names=('Parameter', 'Value','e_lower','e_upper'), dtype=('str','float','float','float'))

# Get error dictionaries
cov_min = dict(zip(list(cov.parnames), list(cov.parmins)))
cov_max = dict(zip(list(cov.parnames), list(cov.parmaxes)))

for a in (abs1): 
    for p in a.pars:
        parname = str(a.name[-4:]) + '.' + str(p.name)
        if parname in cov_min.keys():
            e_lower = cov_min[parname]
            e_upper = cov_max[parname]
            output_2002.add_row([parname, float(p.val), e_lower, e_upper])
        else:
            output_2002.add_row([parname, float(p.val), float('inf'), float('inf')])

i = 0
for v in (v1, v2, v3):
    for p in v.pars:
        parname = str(v.name[-2:]) + '.' + str(p.name)
        if p.name in ['He','C','N','O','Ne','Mg','Al','Si','S','Ar','Ca','Fe','Ni'] and i > 0:
            continue
        if parname in cov_min.keys():
            e_lower = cov_min[parname]
            e_upper = cov_max[parname]
            output_2002.add_row([parname, float(p.val), e_lower, e_upper])
        else:
            output_2002.add_row([parname, float(p.val), float('inf'), float('inf')])
    i += 1

output_2002['Value'].format= '.3f'
output_2002['e_lower'].format= '.3f'
output_2002['e_upper'].format= '.3f'

# norm = 1e-14* EM /(4*pi*d^2)
# EM = 4*pi*d^2 * norm / 1 e-14
d = 1000/6.3700 * u.pc  # parallax is 6.37 mas (Gaia DR3)
d = d.to(u.cm)

for row in output_2002:
    if 'norm' in row['Parameter']:
        v = row['Parameter'][:2] + '.EM'
        # norm = EM * 10**-14/(4*np.pi*d**2)
        em = row['Value']/(10**-14)*(4*np.pi*d**2)
        e_plus = row['e_upper']/(10**-14)*(4*np.pi*d**2)
        e_minus = row['e_lower']/(10**-14)*(4*np.pi*d**2)
        output_2002.add_row([v, em/1e53, e_minus/1e53, e_plus/1e53])
    elif 'kT' in row['Parameter']:
        v = row['Parameter'][:2] + '.T'
        # kT = k_B * T
        T = (row['Value'] / c.k_B.to('keV/K')).value
        t_minus = (row['e_lower'] / c.k_B.to('keV/K')).value
        t_plus = (row['e_upper'] / c.k_B.to('keV/K')).value
        output_2002.add_row([v, T/1e6, t_minus/1e6, t_plus/1e6])

output_2002.pprint_all()

output_2002.write('/Users/woodml/Documents/X-Ray/TaleofTwoStars/SU_Aur/2002_flare_fit_results.txt', format='latex', overwrite=True)
# Out:
#  Parameter  Value  e_lower e_upper
# ----------- ------ ------- -------
#     abs1.nH  0.375     nan     nan
#       v1.kT  0.756  -0.007   0.007
#       v1.He  1.000     inf     inf
#        v1.C  0.469     inf     inf
#        v1.N  0.469     inf     inf
#        v1.O  0.469  -0.209   0.209
#       v1.Ne  3.378  -0.554   0.554
#       v1.Mg  0.817     inf     inf
#       v1.Al  0.817     inf     inf
#       v1.Si  0.817     inf     inf
#        v1.S  0.469     inf     inf
#       v1.Ar  1.000     inf     inf
#       v1.Ca  0.817     inf     inf
#       v1.Fe  0.817  -0.082   0.082
#       v1.Ni  0.817     inf     inf
# v1.redshift  0.000     inf     inf
#     v1.norm  0.000  -0.000   0.000
#       v2.kT  1.933  -0.029   0.029
# v2.redshift  0.000     inf     inf
#     v2.norm  0.002  -0.000   0.000
#       v3.kT  5.759  -0.240   0.240
# v3.redshift  0.000     inf     inf
#     v3.norm  0.001  -0.000   0.000
#        v1.T  8.777  -0.081   0.081
#       v1.EM  1.199  -0.177   0.177
#        v2.T 22.429  -0.342   0.342
#       v2.EM  5.285  -0.609   0.609
#        v3.T 66.835  -2.785   2.785
#       v3.EM  3.006  -0.503   0.503

# %% [markdown]
# ## 2012

# %%
ui.set_source('2012_emos1', ui.xsphabs.abs1*(ui.xsvapec.v1 + ui.xsvapec.v2 + ui.xsvapec.v3))
ui.set_source('2012_emos2', abs1*(v1 + v2 + v3))
ui.set_source('2012_epn', abs1*(v1 + v2 + v3))

# Reset Links
for v in (v1, v2, v3):
    for p in v.pars[1:-1]:
        p.link = None

abs1.nH = 0.46
v1.kT = 0.46
v2.kT =  1.08
v3.kT =  3.63
v1.norm = 0.0001
v2.norm = 0.0001
v3.norm = 0.0001
 
v1.O  = 1.0  
v1.Ne = 1.0
v1.Fe = 1.0

# Unlock/Lock parameters
abs1.nH.frozen = 0
v1.norm.frozen = 0
v2.norm.frozen = 0
v3.norm.frozen = 0
v1.kT.frozen = 0
v2.kT.frozen = 0
v3.kT.frozen = 1

v1.O.frozen  = 0
v1.Ne.frozen = 0
v1.Fe.frozen = 0

# Links
v1.Al = v1.Fe
v1.Ca = v1.Fe
v1.Mg = v1.Fe
v1.Si = v1.Fe
v1.Ni = v1.Fe

v1.C = v1.O
v1.N = v1.O
v1.S = v1.O

for v in (v2, v3):
    for p in v.pars[1:-1]:
        p.link = getattr(v1, p.name)

# %%
abs1.nH.frozen = 0
v1.norm.frozen = 0
v2.norm.frozen = 0
v3.norm.frozen = 0
v1.kT.frozen = 0
v2.kT.frozen = 0
v3.kT.frozen = 0

v1.O.frozen  = 0
v1.Ne.frozen = 0
v1.Fe.frozen = 0
ui.fit('2012_emos1', '2012_emos2', '2012_epn')
# Out:
# Datasets              = '2012_emos1', '2012_emos2', '2012_epn'
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 459.267
# Final fit statistic   = 456.41 at function evaluation 125
# Data points           = 630
# Degrees of freedom    = 620
# Probability [Q-value] = 1
# Reduced statistic     = 0.736145
# Change in statistic   = 2.85709
#    abs1.nH        0.46397      +/- 0.0459694
#    v1.kT          0.461617     +/- 0.147134
#    v1.O           0.891583     +/- 0.429531
#    v1.Ne          0.234224     +/- 1.21222
#    v1.Fe          1.2581       +/- 0.177544
#    v1.norm        0.000199231  +/- 7.72925e-05
#    v2.kT          1.07662      +/- 0.0607918
#    v2.norm        0.000454057  +/- 0.000115148
#    v3.kT          3.63473      +/- 0.245497
#    v3.norm        0.00226591   +/- 0.000133835

# %%
# Plot
el = ['He','C','N','O','Ne','Mg','Fe', 'Al','Si']
caption = "".join(['%s = %.3f \n' %(e, ui.get_par('v1.'+e).val) for e in el])

plt.figure(figsize=(10,3.5))
ui.plot_fit('2012_emos1')
ui.plot_fit('2012_emos2', overplot=True)
g = plt.gcf().axes
g[0].lines[1].set_label('EMOS 1')
g[0].lines[1].set_markersize(10)
g[0].lines[1].set_markeredgecolor('k')
g[0].lines[5].set_label('EMOS 2')
g[0].lines[5].set_markersize(10)
g[0].lines[5].set_markeredgecolor('k')
plt.xlim(0.2, 20)
plt.vlines([12.135, 10.239],         0, 0.05, 'k','--', label='Ne')  
plt.vlines([8.4245, 7.1069, 9.1688], 0, 0.05, 'k','-.', label='Mg')
plt.vlines([6.18, 5.21],             0, 0.05, 'k',':', label='Si')
plt.vlines([4.7273, 4.7327],         0, 0.05, 'k',(0,(5,3,1,3,1,3)), label='S')
plt.vlines([3.7311, 3.15],           0, 0.05, 'k',(0,(1,5)), label='Ar')
plt.vlines([1.778, 1.5024],          0, 0.05, 'k',(0,(6,2)), label='Fe')
plt.vlines([16.006],                 0, 0.05, 'k',(0,(5,2,1,2,5,2)), label='O')
plt.xlabel('Wavelength (Angstroms)')
plt.title('2012 EMOS')
plt.legend(loc=(1.01, 0.2))
plt.show()

plt.figure(figsize=(10, 3.5))
ui.plot_fit('2012_epn')
g = plt.gcf().axes
g[0].lines[1].set_markersize(10)
g[0].lines[1].set_markeredgecolor('k')
plt.xlim(0.2, 20)
plt.vlines([12.135, 10.239],         0, 0.15, 'k','--', label='Ne')  
plt.vlines([8.4245, 7.1069, 9.1688], 0, 0.15, 'k','-.', label='Mg')
plt.vlines([6.18, 5.21],             0, 0.15, 'k',':', label='Si')
plt.vlines([4.7273, 4.7327],         0, 0.15, 'k',(0,(5,3,1,3,1,3)), label='S')
plt.vlines([3.7311, 3.15],           0, 0.15, 'k',(0,(1,5)), label='Ar')
plt.vlines([1.78, 1.50],             0, 0.15, 'k',(0,(6,2)), label='Fe')
plt.vlines([16.006],                 0, 0.15, 'k',(0,(5,2,1,2,5,2)), label='O')
plt.xlabel('Wavelength (Angstroms)')
plt.title('2012 EPN')
plt.legend(loc=(1.01, 0.2))
plt.show()

# %%
ui.covar('2012_emos1','2012_emos2', '2012_epn')
cov = ui.get_covar_results()
# Out:
# Datasets              = '2012_emos1', '2012_emos2', '2012_epn'
# Confidence Method     = covariance
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# covariance 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    abs1.nH           0.46397  -0.00862251   0.00862251
#    v1.kT            0.461617    -0.113336     0.113336
#    v1.O             0.891583    -0.391821     0.391821
#    v1.Ne            0.234224    -0.192028     0.192028
#    v1.Fe              1.2581    -0.167409     0.167409
#    v1.norm       0.000199231 -4.85349e-05  4.85349e-05
#    v2.kT             1.07662   -0.0265799    0.0265799
#    v2.norm       0.000454057 -7.25576e-05  7.25576e-05
#    v3.kT             3.63473    -0.163686     0.163686
#    v3.norm        0.00226591 -0.000113586  0.000113586

# %%
# Write out
# Create table
output = Table(names=('Parameter', 'Value','e_lower','e_upper'), dtype=('str','float','float','float'))

# Get error dictionaries
cov_min = dict(zip(list(cov.parnames), list(cov.parmins)))
cov_max = dict(zip(list(cov.parnames), list(cov.parmaxes)))

for a in (abs1): 
    for p in a.pars:
        parname = str(a.name[-4:]) + '.' + str(p.name)
        if parname in cov_min.keys():
            e_lower = cov_min[parname]
            e_upper = cov_max[parname]
            output.add_row([parname, float(p.val), e_lower, e_upper])
        else:
            output.add_row([parname, float(p.val), float('inf'), float('inf')])

i = 0
for v in (v1, v2, v3):
    for p in v.pars:
        parname = str(v.name[-2:]) + '.' + str(p.name)
        if p.name in ['He','C','N','O','Ne','Mg','Al','Si','S','Ar','Ca','Fe','Ni'] and i > 0:
            continue
        if parname in cov_min.keys():
            e_lower = cov_min[parname]
            e_upper = cov_max[parname]
            output.add_row([parname, float(p.val), e_lower, e_upper])
        else:
            output.add_row([parname, float(p.val), float('inf'), float('inf')])
    i += 1

output['Value'].format= '.3f'
output['e_lower'].format= '.3f'
output['e_upper'].format= '.3f'

# norm = 1e-14* EM /(4*pi*d^2)
# EM = 4*pi*d^2 * norm / 1 e-14
d = 1000/6.3700 * u.pc  # parallax is 6.37 mas (Gaia DR3)
d = d.to(u.cm)

for row in output:
    if 'norm' in row['Parameter']:
        v = row['Parameter'][:2] + '.EM'
        # norm = EM * 10**-14/(4*np.pi*d**2)
        em = row['Value']/(10**-14)*(4*np.pi*d**2)
        e_plus = row['e_upper']/(10**-14)*(4*np.pi*d**2)
        e_minus = row['e_lower']/(10**-14)*(4*np.pi*d**2)
        output.add_row([v, em/1e53, e_minus/1e53, e_plus/1e53])
    elif 'kT' in row['Parameter']:
        v = row['Parameter'][:2] + '.T'
        # kT = k_B * T
        T = (row['Value'] / c.k_B.to('keV/K')).value
        t_minus = (row['e_lower'] / c.k_B.to('keV/K')).value
        t_plus = (row['e_upper'] / c.k_B.to('keV/K')).value
        output.add_row([v, T/1e6, t_minus/1e6, t_plus/1e6])

output.pprint_all()

output.write('/Users/woodml/Documents/X-Ray/TaleOfTwoStars/SU_Aur/2012_flare_fit_results.txt', format='latex', overwrite=True)
# Out:
#  Parameter  Value  e_lower e_upper
# ----------- ------ ------- -------
#     abs1.nH  0.464  -0.009   0.009
#       v1.kT  0.462  -0.113   0.113
#       v1.He  1.000     inf     inf
#        v1.C  0.892     inf     inf
#        v1.N  0.892     inf     inf
#        v1.O  0.892  -0.392   0.392
#       v1.Ne  0.234  -0.192   0.192
#       v1.Mg  1.258     inf     inf
#       v1.Al  1.258     inf     inf
#       v1.Si  1.258     inf     inf
#        v1.S  0.892     inf     inf
#       v1.Ar  1.000     inf     inf
#       v1.Ca  1.258     inf     inf
#       v1.Fe  1.258  -0.167   0.167
#       v1.Ni  1.258     inf     inf
# v1.redshift  0.000     inf     inf
#     v1.norm  0.000  -0.000   0.000
#       v2.kT  1.077  -0.027   0.027
# v2.redshift  0.000     inf     inf
#     v2.norm  0.000  -0.000   0.000
#       v3.kT  3.635  -0.164   0.164
# v3.redshift  0.000     inf     inf
#     v3.norm  0.002  -0.000   0.000
#        v1.T  5.357  -1.315   1.315
#       v1.EM  0.587  -0.143   0.143
#        v2.T 12.494  -0.308   0.308
#       v2.EM  1.339  -0.214   0.214
#        v3.T 42.179  -1.899   1.899
#       v3.EM  6.682  -0.335   0.335

# %% [markdown]
# # Model D
# ## 2002

# %%
ui.set_source('2002_emos1', ui.xsphabs.abs1*(ui.xsvapec.v1 + ui.xsvapec.v2) + ui.xsphabs.abs2*(ui.xsvapec.v3))
ui.set_source('2002_emos2', abs1*(v1 + v2) + abs2*(v3))

# %%
# Reset Links
ui.reset()
for v in (v1, v2, v3):
    for p in v.pars[1:-1]:
        p.link = None

# %%
abs1.nH = 0.5
abs2.nH = 0.25
v1.kT = 0.5
v2.kT = 1.0
v3.kT = 4.0
v1.norm = 0.0001
v2.norm = 0.0001
v3.norm = 0.0001
 
v1.O  = 1.0
v1.Ne = 1.0
v1.Fe = 1.0

# Unlock/Lock parameters
abs1.nH.frozen = 0
abs2.nH.frozen = 0
v1.norm.frozen = 0
v2.norm.frozen = 0
v1.kT.frozen = 0
v2.kT.frozen = 0

v1.O.frozen  = 0
v1.Ne.frozen = 0
v1.Fe.frozen = 0

# Links
v1.Al = v1.Fe
v1.Ca = v1.Fe
v1.Mg = v1.Fe
v1.Si = v1.Fe
v1.Ni = v1.Fe

v1.C = v1.O
v1.N = v1.O
v1.S = v1.O

for v in (v2, v3):
    for p in v.pars[1:-1]:
        p.link = getattr(v1, p.name)

# %%
ui.fit('2002_emos1', '2002_emos2')
# Out:
# Datasets              = '2002_emos1', '2002_emos2'
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 8587.15
# Final fit statistic   = 245.291 at function evaluation 330
# Data points           = 342
# Degrees of freedom    = 331
# Probability [Q-value] = 0.999866
# Reduced statistic     = 0.74106
# Change in statistic   = 8341.86
#    abs1.nH        0.588119     +/- 0.107903
#    v1.kT          0.704222     +/- 0.0437078
#    v1.O           0.643558     +/- 0.305844
#    v1.Ne          3.60928      +/- 1.01582
#    v1.Fe          0.950373     +/- 0.141748
#    v1.norm        0.000552809  +/- 0.000132944
#    v2.kT          1.46247      +/- 0.365829
#    v2.norm        0.000696927  +/- 0.000596719
#    abs2.nH        0.285108     +/- 0.06031
#    v3.kT          3.72281      +/- 0.756432
#    v3.norm        0.00189591   +/- 0.000557534

# %%
# Plot
el = ['He','C','N','O','Ne','Mg','Fe', 'Al','Si']
caption = "".join(['%s = %.3f \n' %(e, ui.get_par('v1.'+e).val) for e in el])

plt.figure(figsize=(12,4))
ui.plot_fit('2002_emos1')
ui.plot_fit('2002_emos2', overplot=True)
g = plt.gcf().axes
g[0].lines[1].set_label('EMOS 1')
g[0].lines[1].set_markersize(10)
g[0].lines[1].set_markeredgecolor('k')
g[0].lines[5].set_label('EMOS 2')
g[0].lines[5].set_markersize(10)
g[0].lines[5].set_markeredgecolor('k')
plt.xlim(0.2, 20)
plt.vlines([12.135, 10.239],         0, 0.05, 'k','--', label='Ne')  
plt.vlines([8.4245, 7.1069, 9.1688], 0, 0.05, 'k','-.', label='Mg')
plt.vlines([6.18, 5.21],             0, 0.05, 'k',':', label='Si')
plt.vlines([4.7273, 4.7327],         0, 0.05, 'k',(0,(5,3,1,3,1,3)), label='S')
plt.vlines([3.7311, 3.15],           0, 0.05, 'k',(0,(1,5)), label='Ar')
plt.vlines([1.778, 1.5024],          0, 0.05, 'k',(0,(6,2)), label='Fe')
plt.vlines([16.006],                 0, 0.05, 'k',(0,(5,2,1,2,5,2)), label='O')
# plt.text(0.95, 0.35, caption, transform=g[0].transAxes, horizontalalignment='right')
plt.xlabel('Wavelength (Angstroms)')
plt.title('2002 EMOS Flare')
plt.legend(loc=(1.01, 0.2))
plt.show()

# %%
ui.covar('2002_emos1','2002_emos2')
cov = ui.get_covar_results()
# Out:
# Datasets              = '2002_emos1', '2002_emos2'
# Confidence Method     = covariance
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# covariance 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    abs1.nH          0.588119   -0.0133819    0.0133819
#    v1.kT            0.704222  -0.00639554   0.00639554
#    v1.O             0.643558    -0.287047     0.287047
#    v1.Ne             3.60928    -0.878783     0.878783
#    v1.Fe            0.950373    -0.127641     0.127641
#    v1.norm       0.000552809 -4.35506e-05  4.35506e-05
#    v2.kT             1.46247    -0.148205     0.148205
#    v2.norm       0.000696927 -0.000244677  0.000244677
#    abs2.nH          0.285108   -0.0337732    0.0337732
#    v3.kT             3.72281     -0.26014      0.26014
#    v3.norm        0.00189591 -0.000180014  0.000180014

# %%
# Write out
# Create table
output_2002 = Table(names=('Parameter', 'Value','e_lower','e_upper'), dtype=('str','float','float','float'))

# Get error dictionaries
cov_min = dict(zip(list(cov.parnames), list(cov.parmins)))
cov_max = dict(zip(list(cov.parnames), list(cov.parmaxes)))

for a in (abs1, abs2): 
    for p in a.pars:
        parname = str(a.name[-4:]) + '.' + str(p.name)
        if parname in cov_min.keys():
            e_lower = cov_min[parname]
            e_upper = cov_max[parname]
            output_2002.add_row([parname, float(p.val), e_lower, e_upper])
        else:
            output_2002.add_row([parname, float(p.val), float('inf'), float('inf')])

i = 0
for v in (v1, v2, v3):
    for p in v.pars:
        parname = str(v.name[-2:]) + '.' + str(p.name)
        if p.name in ['He','C','N','O','Ne','Mg','Al','Si','S','Ar','Ca','Fe','Ni'] and i > 0:
            continue
        if parname in cov_min.keys():
            e_lower = cov_min[parname]
            e_upper = cov_max[parname]
            output_2002.add_row([parname, float(p.val), e_lower, e_upper])
        else:
            output_2002.add_row([parname, float(p.val), float('inf'), float('inf')])
    i += 1

output_2002['Value'].format= '.3f'
output_2002['e_lower'].format= '.3f'
output_2002['e_upper'].format= '.3f'

# norm = 1e-14* EM /(4*pi*d^2)
# EM = 4*pi*d^2 * norm / 1 e-14
d = 1000/6.3700 * u.pc  # parallax is 6.37 mas (Gaia DR3)
d = d.to(u.cm)

for row in output_2002:
    if 'norm' in row['Parameter']:
        v = row['Parameter'][:2] + '.EM'
        # norm = EM * 10**-14/(4*np.pi*d**2)
        em = row['Value']/(10**-14)*(4*np.pi*d**2)
        e_plus = row['e_upper']/(10**-14)*(4*np.pi*d**2)
        e_minus = row['e_lower']/(10**-14)*(4*np.pi*d**2)
        output_2002.add_row([v, em/1e53, e_minus/1e53, e_plus/1e53])
    elif 'kT' in row['Parameter']:
        v = row['Parameter'][:2] + '.T'
        # kT = k_B * T
        T = (row['Value'] / c.k_B.to('keV/K')).value
        t_minus = (row['e_lower'] / c.k_B.to('keV/K')).value
        t_plus = (row['e_upper'] / c.k_B.to('keV/K')).value
        output_2002.add_row([v, T/1e6, t_minus/1e6, t_plus/1e6])

output_2002.pprint_all()

output_2002.write('/Users/woodml/Documents/X-Ray/TaleofTwoStars/SU_Aur/2002_flare_fit_D_results.txt', format='latex', overwrite=True)
# Out:
#  Parameter  Value  e_lower e_upper
# ----------- ------ ------- -------
#     abs1.nH  0.588  -0.013   0.013
#     abs2.nH  0.285  -0.034   0.034
#       v1.kT  0.704  -0.006   0.006
#       v1.He  1.000     inf     inf
#        v1.C  0.644     inf     inf
#        v1.N  0.644     inf     inf
#        v1.O  0.644  -0.287   0.287
#       v1.Ne  3.609  -0.879   0.879
#       v1.Mg  0.950     inf     inf
#       v1.Al  0.950     inf     inf
#       v1.Si  0.950     inf     inf
#        v1.S  0.644     inf     inf
#       v1.Ar  1.000     inf     inf
#       v1.Ca  0.950     inf     inf
#       v1.Fe  0.950  -0.128   0.128
#       v1.Ni  0.950     inf     inf
# v1.redshift  0.000     inf     inf
#     v1.norm  0.001  -0.000   0.000
#       v2.kT  1.462  -0.148   0.148
# v2.redshift  0.000     inf     inf
#     v2.norm  0.001  -0.000   0.000
#       v3.kT  3.723  -0.260   0.260
# v3.redshift  0.000     inf     inf
#     v3.norm  0.002  -0.000   0.000
#        v1.T  8.172  -0.074   0.074
#       v1.EM  1.630  -0.128   0.128
#        v2.T 16.971  -1.720   1.720
#       v2.EM  2.055  -0.721   0.721
#        v3.T 43.201  -3.019   3.019
#       v3.EM  5.590  -0.531   0.531

# %% [markdown]
# ## 2012

# %%
ui.set_source('2012_emos1', ui.xsphabs.abs1*(ui.xsvapec.v1 + ui.xsvapec.v2) + ui.xsphabs.abs2*(ui.xsvapec.v3))
ui.set_source('2012_emos2', abs1*(v1 + v2)  + abs2*(v3))
ui.set_source('2012_epn', abs1*(v1 + v2)  + abs2*(v3))

# %%
# Reset Links
ui.reset()
for v in (v1, v2, v3):
    for p in v.pars[1:-1]:
        p.link = None

# %%
abs1.nH = 0.5
abs2.nH = 0.25
v1.kT = 0.5
v2.kT = 1.0
v3.kT = 4.0
v1.norm = 0.0001
v2.norm = 0.0001
v3.norm = 0.0001
 
v1.O  = 1.0
v1.Ne = 1.0
v1.Fe = 1.0

# Unlock/Lock parameters
abs1.nH.frozen = 0
abs2.nH.frozen = 0
v1.norm.frozen = 0
v2.norm.frozen = 0
v3.norm.frozen = 0
v1.kT.frozen = 0
v2.kT.frozen = 0
v3.kT.frozen = 0

v1.O.frozen  = 0
v1.Ne.frozen = 0
v1.Fe.frozen = 0

# Links
v1.Al = v1.Fe
v1.Ca = v1.Fe
v1.Mg = v1.Fe
v1.Si = v1.Fe
v1.Ni = v1.Fe

v1.C = v1.O
v1.N = v1.O
v1.S = v1.O

for v in (v2, v3):
    for p in v.pars[1:-1]:
        p.link = getattr(v1, p.name)

# %%
ui.fit('2012_emos1', '2012_emos2', '2012_epn')
# Out:
# Datasets              = '2012_emos1', '2012_emos2', '2012_epn'
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 6882.49
# Final fit statistic   = 441.019 at function evaluation 171
# Data points           = 630
# Degrees of freedom    = 619
# Probability [Q-value] = 1
# Reduced statistic     = 0.71247
# Change in statistic   = 6441.47
#    abs1.nH        0.870231     +/- 0.103725
#    v1.kT          1.01628      +/- 0.0595201
#    v1.O           1.37253      +/- 0.579774
#    v1.Ne          1.0706       +/- 1.10799
#    v1.Fe          1.49465      +/- 0.215332
#    v1.norm        0.000619786  +/- 0.000136415
#    v2.kT          0.435638     +/- 0.137932
#    v2.norm        0.000547182  +/- 0.000295748
#    abs2.nH        0.338076     +/- 0.0418427
#    v3.kT          4.20592      +/- 0.307173
#    v3.norm        0.00183206   +/- 0.000155101

# %%
# Plot
el = ['He','C','N','O','Ne','Mg','Fe', 'Al','Si']
caption = "".join(['%s = %.3f \n' %(e, ui.get_par('v1.'+e).val) for e in el])

plt.figure(figsize=(10,3.5))
ui.plot_fit('2012_emos1')
ui.plot_fit('2012_emos2', overplot=True)
g = plt.gcf().axes
g[0].lines[1].set_label('EMOS 1')
g[0].lines[1].set_markersize(10)
g[0].lines[1].set_markeredgecolor('k')
g[0].lines[5].set_label('EMOS 2')
g[0].lines[5].set_markersize(10)
g[0].lines[5].set_markeredgecolor('k')
plt.xlim(0.2, 20)
plt.vlines([12.135, 10.239],         0, 0.05, 'k','--', label='Ne')  
plt.vlines([8.4245, 7.1069, 9.1688], 0, 0.05, 'k','-.', label='Mg')
plt.vlines([6.18, 5.21],             0, 0.05, 'k',':', label='Si')
plt.vlines([4.7273, 4.7327],         0, 0.05, 'k',(0,(5,3,1,3,1,3)), label='S')
plt.vlines([3.7311, 3.15],           0, 0.05, 'k',(0,(1,5)), label='Ar')
plt.vlines([1.778, 1.5024],          0, 0.05, 'k',(0,(6,2)), label='Fe')
plt.vlines([16.006],                 0, 0.05, 'k',(0,(5,2,1,2,5,2)), label='O')
plt.xlabel('Wavelength (Angstroms)')
plt.title('2012 EMOS')
plt.legend(loc=(1.01, 0.2))
plt.show()

plt.figure(figsize=(10,3.5))
ui.plot_fit('2012_epn')
g = plt.gcf().axes
g[0].lines[1].set_markersize(10)
g[0].lines[1].set_markeredgecolor('k')
plt.xlim(0.2, 20)
plt.vlines([12.135, 10.239],         0, 0.15, 'k','--', label='Ne')  
plt.vlines([8.4245, 7.1069, 9.1688], 0, 0.15, 'k','-.', label='Mg')
plt.vlines([6.18, 5.21],             0, 0.15, 'k',':', label='Si')
plt.vlines([4.7273, 4.7327],         0, 0.15, 'k',(0,(5,3,1,3,1,3)), label='S')
plt.vlines([3.7311, 3.15],           0, 0.15, 'k',(0,(1,5)), label='Ar')
plt.vlines([1.78, 1.50],             0, 0.15, 'k',(0,(6,2)), label='Fe')
plt.vlines([16.006],                 0, 0.15, 'k',(0,(5,2,1,2,5,2)), label='O')
plt.xlabel('Wavelength (Angstroms)')
plt.title('2012 EPN')
plt.legend(loc=(1.01, 0.2))
plt.show()

# %%
ui.covar('2012_emos1','2012_emos2', '2012_epn')
cov = ui.get_covar_results()
# Out:
# WARNING: hard minimum hit for parameter v1.Ne
# Datasets              = '2012_emos1', '2012_emos2', '2012_epn'
# Confidence Method     = covariance
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# covariance 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    abs1.nH          0.870231   -0.0825353    0.0825353
#    v1.kT             1.01628   -0.0623794    0.0623794
#    v1.O              1.37253    -0.572642     0.572642
#    v1.Ne              1.0706        -----      1.12006
#    v1.Fe             1.49465    -0.206386     0.206386
#    v1.norm       0.000619786 -0.000136716  0.000136716
#    v2.kT            0.435638    -0.149106     0.149106
#    v2.norm       0.000547182 -0.000278814  0.000278814
#    abs2.nH          0.338076   -0.0475156    0.0475156
#    v3.kT             4.20592    -0.369942     0.369942
#    v3.norm        0.00183206 -0.000158469  0.000158469

# %%
## Write out
# Create table
output = Table(names=('Parameter', 'Value','e_lower','e_upper'), dtype=('str','float','float','float'))

# Get error dictionaries
cov_min = dict(zip(list(cov.parnames), list(cov.parmins)))
cov_max = dict(zip(list(cov.parnames), list(cov.parmaxes)))

for a in (abs1, abs2): 
    for p in a.pars:
        parname = str(a.name[-4:]) + '.' + str(p.name)
        if parname in cov_min.keys():
            e_lower = cov_min[parname]
            e_upper = cov_max[parname]
            output.add_row([parname, float(p.val), e_lower, e_upper])
        else:
            output.add_row([parname, float(p.val), float('inf'), float('inf')])

i = 0
for v in (v1, v2, v3):
    for p in v.pars:
        parname = str(v.name[-2:]) + '.' + str(p.name)
        if p.name in ['He','C','N','O','Ne','Mg','Al','Si','S','Ar','Ca','Fe','Ni'] and i > 0:
            continue
        if parname in cov_min.keys():
            e_lower = cov_min[parname]
            e_upper = cov_max[parname]
            output.add_row([parname, float(p.val), e_lower, e_upper])
        else:
            output.add_row([parname, float(p.val), float('inf'), float('inf')])
    i += 1

output['Value'].format= '.3f'
output['e_lower'].format= '.3f'
output['e_upper'].format= '.3f'

# norm = 1e-14* EM /(4*pi*d^2)
# EM = 4*pi*d^2 * norm / 1 e-14
d = 1000/6.3700 * u.pc  # parallax is 6.37 mas (Gaia DR3)
d = d.to(u.cm)

for row in output:
    if 'norm' in row['Parameter']:
        v = row['Parameter'][:2] + '.EM'
        # norm = EM * 10**-14/(4*np.pi*d**2)
        em = row['Value']/(10**-14)*(4*np.pi*d**2)
        e_plus = row['e_upper']/(10**-14)*(4*np.pi*d**2)
        e_minus = row['e_lower']/(10**-14)*(4*np.pi*d**2)
        output.add_row([v, em/1e53, e_minus/1e53, e_plus/1e53])
    elif 'kT' in row['Parameter']:
        v = row['Parameter'][:2] + '.T'
        # kT = k_B * T
        T = (row['Value'] / c.k_B.to('keV/K')).value
        t_minus = (row['e_lower'] / c.k_B.to('keV/K')).value
        t_plus = (row['e_upper'] / c.k_B.to('keV/K')).value
        output.add_row([v, T/1e6, t_minus/1e6, t_plus/1e6])

output.pprint_all()

output.write('/Users/woodml/Documents/X-Ray/TaleofTwoStars/SU_Aur/2012_flare_fit_D_results.txt', format='latex', overwrite=True)
# Out:
#  Parameter  Value  e_lower e_upper
# ----------- ------ ------- -------
#     abs1.nH  0.870  -0.083   0.083
#     abs2.nH  0.338  -0.048   0.048
#       v1.kT  1.016  -0.062   0.062
#       v1.He  1.000     inf     inf
#        v1.C  1.373     inf     inf
#        v1.N  1.373     inf     inf
#        v1.O  1.373  -0.573   0.573
#       v1.Ne  1.071     nan   1.120
#       v1.Mg  1.495     inf     inf
#       v1.Al  1.495     inf     inf
#       v1.Si  1.495     inf     inf
#        v1.S  1.373     inf     inf
#       v1.Ar  1.000     inf     inf
#       v1.Ca  1.495     inf     inf
#       v1.Fe  1.495  -0.206   0.206
#       v1.Ni  1.495     inf     inf
# v1.redshift  0.000     inf     inf
#     v1.norm  0.001  -0.000   0.000
#       v2.kT  0.436  -0.149   0.149
# v2.redshift  0.000     inf     inf
#     v2.norm  0.001  -0.000   0.000
#       v3.kT  4.206  -0.370   0.370
# v3.redshift  0.000     inf     inf
#     v3.norm  0.002  -0.000   0.000
#        v1.T 11.793  -0.724   0.724
#       v1.EM  1.828  -0.403   0.403
#        v2.T  5.055  -1.730   1.730
#       v2.EM  1.613  -0.822   0.822
#        v3.T 48.808  -4.293   4.293
#       v3.EM  5.402  -0.467   0.467
