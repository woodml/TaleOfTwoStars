# %% [markdown]
# Environment: ciao-4.15

# %%
from sherpa.astro import ui

import numpy as np
import astropy.units as u
import astropy.constants as c
from astropy.io import fits
from astropy.table import Table
from copy import deepcopy

import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Georgia']
rcParams['font.weight'] = 'bold'
rcParams['axes.labelweight'] = 'bold'
rcParams['axes.linewidth'] = 1

# %% [markdown]
# # Load 2002 (quiescent) Data

# %%
# Loading the quiescent spectrum
ui.load_data('2002_emos1', '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_spec_quiet_final.fits')

ui.load_data('2002_emos2', '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_spec_quiet_final.fits')

ui.set_analysis('wave')  # set analysis to give wavelength instead of channel, needs a loaded rmf

ui.ignore_id('2002_emos1', 25, None)
ui.ignore_id('2002_emos2', 25, None)

ui.group_counts('2002_emos1', 20)  ## CHANGE to 20 cts/s bins
ui.group_counts('2002_emos2', 20)
# Out:
# read ARF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_qiuet.anc
# read RMF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_quiet.rmf
# read background file /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_bkg_spec_quiet.fits
# read ARF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_qiuet.anc
# read RMF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_quiet.rmf
# /Users/woodml/anaconda3/envs/ciao-4.15/lib/python3.10/site-packages/sherpa/astro/data.py:990: UserWarning: The minimum ENERG_LO in the ARF '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_qiuet.anc' was 0 and has been replaced by 1e-10
#   warnings.warn(wmsg)
# /Users/woodml/anaconda3/envs/ciao-4.15/lib/python3.10/site-packages/sherpa/astro/data.py:990: UserWarning: The minimum ENERG_LO in the RMF '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS1_quiet.rmf' was 0 and has been replaced by 1e-10
#   warnings.warn(wmsg)
# /Users/woodml/anaconda3/envs/ciao-4.15/lib/python3.10/site-packages/sherpa/astro/data.py:990: UserWarning: The minimum ENERG_LO in the ARF '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_qiuet.anc' was 0 and has been replaced by 1e-10
#   warnings.warn(wmsg)
# /Users/woodml/anaconda3/envs/ciao-4.15/lib/python3.10/site-packages/sherpa/astro/data.py:990: UserWarning: The minimum ENERG_LO in the RMF '/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_quiet.rmf' was 0 and has been replaced by 1e-10
#   warnings.warn(wmsg)
# read background file /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/EMOS2_bkg_spec_quiet.fits
# dataset 2002_emos1: 1.0332:inf -> 1.0332:22.96 Wavelength (Angstrom)
# dataset 2002_emos2: 1.0332:inf -> 1.0332:22.96 Wavelength (Angstrom)

# %%
plt.figure(figsize=(8, 3))
ui.plot_data('2002_emos1')
ui.plot_data('2002_emos2', overplot=True)
plt.title('SU Aur - EMOS 1 & 2')
g = plt.gcf().axes
g[0].lines[1].set_label('EMOS 1 - 2002')
g[0].lines[3].set_label('EMOS 2 - 2002')
plt.legend()
plt.show()

# %%
ui.subtract('2002_emos1')
ui.subtract('2002_emos2')

# %% [markdown]
# # Load 2012 (quiescent) Data

# %%
ui.load_data('2012_emos1', '/Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS1_spec_quiet_final.fits')

ui.load_data('2012_emos2', '/Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS2_spec_quiet_final.fits')

ui.set_analysis('wave')  # set analysis to give wavelength instead of channel, needs a loaded rmf

ui.ignore_id('2012_emos1', 25, None)
ui.ignore_id('2012_emos2', 25, None)

ui.group_counts('2012_emos1', 20)
ui.group_counts('2012_emos2', 20)
# Out:
# read ARF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS1_quiet.anc
# read RMF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS1_quiet.rmf
# read background file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS1_bkg_spec_quiet.fits
# read ARF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS2_quiet.anc
# read RMF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS2_quiet.rmf
# read background file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS2_bkg_spec_quiet.fits
# dataset 2012_emos1: 1.0332:inf -> 1.0332:22.96 Wavelength (Angstrom)
# dataset 2012_emos2: 1.0332:inf -> 1.0332:22.96 Wavelength (Angstrom)
# /Users/woodml/anaconda3/envs/ciao-4.15/lib/python3.10/site-packages/sherpa/astro/data.py:990: UserWarning: The minimum ENERG_LO in the ARF '/Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS1_quiet.anc' was 0 and has been replaced by 1e-10
#   warnings.warn(wmsg)
# /Users/woodml/anaconda3/envs/ciao-4.15/lib/python3.10/site-packages/sherpa/astro/data.py:990: UserWarning: The minimum ENERG_LO in the RMF '/Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS1_quiet.rmf' was 0 and has been replaced by 1e-10
#   warnings.warn(wmsg)
# /Users/woodml/anaconda3/envs/ciao-4.15/lib/python3.10/site-packages/sherpa/astro/data.py:990: UserWarning: The minimum ENERG_LO in the ARF '/Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS2_quiet.anc' was 0 and has been replaced by 1e-10
#   warnings.warn(wmsg)
# /Users/woodml/anaconda3/envs/ciao-4.15/lib/python3.10/site-packages/sherpa/astro/data.py:990: UserWarning: The minimum ENERG_LO in the RMF '/Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EMOS2_quiet.rmf' was 0 and has been replaced by 1e-10
#   warnings.warn(wmsg)

# %%
ui.load_data('2012_epn', '/Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EPN_spec_quiet_final.fits')

ui.set_analysis('wave')  # set analysis to give wavelength instead of channel, needs a loaded rmf

ui.ignore_id('2012_epn', 25, None)  # wave

ui.group_counts('2012_epn', 20)
# Out:
# read ARF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EPN_quiet.anc
# read RMF file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EPN_quiet.rmf
# read background file /Users/woodml/Observing/XMM-Newton/SU_Aur/0671960101/EPN_bkg_spec_quiet.fits
# dataset 2012_epn: 0.605392:inf -> 0.605392:24.0746 Wavelength (Angstrom)

# %%
plt.figure(figsize=(10,3))
ui.plot_data('2002_emos1')
ui.plot_data('2002_emos2', overplot=True)
ui.plot_data('2012_emos1', overplot=True)
ui.plot_data('2012_emos2', overplot=True)
plt.title('SU Aur - EMOS 1 & 2')
g = plt.gcf().axes
g[0].lines[1].set_label('EMOS 1 - 2002')
g[0].lines[3].set_label('EMOS 2 - 2002')
g[0].lines[5].set_label('EMOS 1 - 2012')
g[0].lines[7].set_label('EMOS 2 - 2012')
plt.legend()
plt.show()

# %%
ui.subtract('2012_emos1')
ui.subtract('2012_emos2')
ui.subtract('2012_epn')

# %% [markdown]
# # Set Fitting Parameters

# %%
ui.set_xsabund('aspl')
ui.set_method('levmar')
ui.set_stat('chi2gehrels')
# Out:
#  Solar Abundance Vector set to aspl:  Asplund M., Grevesse N., Sauval A.J. & Scott P., ARAA, 47, 481 (2009)

# %%
def energy(wave):
    return ((c.h*c.c)/(wave*u.angstrom)).to('keV')

# %% [markdown]
# # Model B
#
# ## 2002

# %%
ui.set_source('2002_emos1', ui.xsphabs.abs1*(ui.xsvapec.v1 + ui.xsvapec.v2 + ui.xsvapec.v3))
ui.set_source('2002_emos2', abs1*(v1 + v2 + v3))

ui.reset()
for v in (v1, v2, v3):
    for p in v.pars[1:-1]:
        p.link = None

# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - 
# Set initial guesses
abs1.nH = 0.423472 
v1.kT = 0.730428
v2.kT = 1.39134
v3.kT = 4.31877
v1.norm = 0.00115392
v2.norm = 0.000994111
v3.norm = 0.000391594

v1.O =  0.404937
v1.Ne = 3.23681
v1.Fe = 0.722314

# freeze/thaw
abs1.nH.frozen = 0
v1.norm.frozen = 0
v2.norm.frozen = 0
v3.norm.frozen = 0
v1.kT.frozen = 0
v2.kT.frozen = 0
v3.kT.frozen = 0

v1.O.frozen  = 0
v1.Fe.frozen = 0
v1.Ne.frozen = 0

# Tie abundances
v1.Al = v1.Fe
v1.Ca = v1.Fe
v1.Mg = v1.Fe
v1.Si = v1.Fe
v1.Ni = v1.Fe

v1.C = v1.O
v1.N = v1.O
v1.S = v1.O

for v in (v2, v3):
    for p in v.pars[1:-1]:
        p.link = getattr(v1, p.name)

# %% [markdown]
#    abs1.nH        0.423472     +/- 0.0276018
#    v1.kT          1.39134      +/- 0.0967231
#    v1.O           0.387464     +/- 0.119878
#    v1.Ne          1.19452      +/- 0.377287
#    v1.Fe          0.477232     +/- 0.0665026
#    v1.norm        0.000994111  +/- 0.000179267
#    v2.kT          4.31877      +/- 1.53528
#    v2.norm        0.000397777  +/- 0.00015562
#    v3.kT          0.730428     +/- 0.0291956
#    v3.norm        0.000566894  +/- 8.83489e-05

# %%
ui.fit('2002_emos1', '2002_emos2')
# Out:
# Reading APEC data from 3.0.9
#
# Datasets              = '2002_emos1', '2002_emos2'
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 11704.6
# Final fit statistic   = 263.113 at function evaluation 141
# Data points           = 339
# Degrees of freedom    = 329
# Probability [Q-value] = 0.996899
# Reduced statistic     = 0.799737
# Change in statistic   = 11441.5
#    abs1.nH        0.423461     +/- 0.0276174
#    v1.kT          0.730503     +/- 0.0292465
#    v1.O           0.387213     +/- 0.119759
#    v1.Ne          1.19482      +/- 0.377514
#    v1.Fe          0.477037     +/- 0.0669967
#    v1.norm        0.000567144  +/- 8.93593e-05
#    v2.kT          1.39165      +/- 0.0976136
#    v2.norm        0.000994585  +/- 0.000185688
#    v3.kT          4.31829      +/- 1.57192
#    v3.norm        0.000397436  +/- 0.000162341

# %%
el = ['He','C','N','O','Ne','Mg','Fe','Si']
caption = "".join(['%s = %.3f \n' %(e, ui.get_par('v1.'+e).val) for e in el])

plt.figure(figsize=(10,3.5))
ui.plot_fit('2002_emos1')
ui.plot_fit('2002_emos2', overplot=True)
g = plt.gcf().axes
g[0].lines[1].set_label('EMOS 1')
g[0].lines[1].set_markersize(10)
g[0].lines[1].set_markeredgecolor('k')
g[0].lines[5].set_label('EMOS 2')
g[0].lines[5].set_markersize(10)
g[0].lines[5].set_markeredgecolor('k')
plt.xlim(0.2, 20)
plt.ylim(-0.001, 0.025)
plt.vlines([12.135, 10.239],         -.1, 0.03, 'k','--', label='Ne')  
plt.vlines([8.4245, 7.1069, 9.1688], -.1, 0.03, 'k','-.', label='Mg')
plt.vlines([6.18, 5.21],             -.1, 0.03, 'k',':', label='Si')
plt.vlines([4.7273, 4.7327],         -.1, 0.03, 'k',(0,(5,3,1,3,1,3)), label='S')
plt.vlines([3.7311, 3.15],           -.1, 0.03, 'k',(0,(1,5)), label='Ar')
plt.vlines([1.778, 1.5024],          -.1, 0.03, 'k',(0,(8,2)), label='Fe')
plt.vlines([16.006], 0, 0.03, 'k',(0,(5,2,1,2,5,2)), label='O')
plt.text(0.98, 0.42, caption, transform=g[0].transAxes, horizontalalignment='right')
plt.xlabel('Wavelength (Angstroms)')
plt.title('2002 EMOS - Asplund 3T')
plt.legend(loc=(1.01, 0.2))
plt.show()

# %%
ui.covar('2002_emos1', '2002_emos2')
cov = ui.get_covar_results()
# Out:
# WARNING: hard minimum hit for parameter abs1.nH
# WARNING: hard maximum hit for parameter abs1.nH
# WARNING: hard minimum hit for parameter v1.kT
# WARNING: hard maximum hit for parameter v1.kT
# Datasets              = '2002_emos1', '2002_emos2'
# Confidence Method     = covariance
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# covariance 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    abs1.nH          0.423461        -----        -----
#    v1.kT            0.730503        -----        -----
#    v1.O             0.387213    -0.112483     0.112483
#    v1.Ne             1.19482    -0.369124     0.369124
#    v1.Fe            0.477037   -0.0662785    0.0662785
#    v1.norm       0.000567144 -6.27999e-05  6.27999e-05
#    v2.kT             1.39165   -0.0642897    0.0642897
#    v2.norm       0.000994585 -0.000121886  0.000121886
#    v3.kT             4.31829    -0.550161     0.550161
#    v3.norm       0.000397436 -5.40923e-05  5.40923e-05

# %%
# Write out
# Create table
output_2002 = Table(names=('Parameter', 'Value','e_lower','e_upper'), dtype=('str','float','float','float'))

# Get error dictionaries
cov_min = dict(zip(list(cov.parnames), list(cov.parmins)))
cov_max = dict(zip(list(cov.parnames), list(cov.parmaxes)))

for p in abs1.pars:
    parname = str(abs1.name[-4:]) + '.' + str(p.name)
    if parname in cov_min.keys():
        e_lower = cov_min[parname]
        e_upper = cov_max[parname]
        output_2002.add_row([parname, float(p.val), e_lower, e_upper])
    else:
        output_2002.add_row([parname, float(p.val), float('inf'), float('inf')])

i = 0
for v in (v1, v2, v3):
    for p in v.pars:
        parname = str(v.name[-2:]) + '.' + str(p.name)
        if p.name in ['He','C','N','O','Ne','Mg','Al','Si','S','Ar','Ca','Fe','Ni'] and i > 0:
            continue
        if parname in cov_min.keys():
            e_lower = cov_min[parname]
            e_upper = cov_max[parname]
            output_2002.add_row([parname, float(p.val), e_lower, e_upper])
        else:
            output_2002.add_row([parname, float(p.val), float('inf'), float('inf')])
    i += 1

output_2002['Value'].format= '.3f'
output_2002['e_lower'].format= '.3f'
output_2002['e_upper'].format= '.3f'

# norm = 1e-14* EM /(4*pi*d^2)
# EM = 4*pi*d^2 * norm / 1 e-14
d = 1000/6.3700 * u.pc  # parallax is 6.37 mas (Gaia DR3)
d = d.to(u.cm)

for row in output_2002:
    if 'norm' in row['Parameter']:
        v = row['Parameter'][:2] + '.EM'
        # norm = EM * 10**-14/(4*np.pi*d**2)
        em = row['Value']/(10**-14)*(4*np.pi*d**2)
        e_plus = row['e_upper']/(10**-14)*(4*np.pi*d**2)
        e_minus = row['e_lower']/(10**-14)*(4*np.pi*d**2)
        output_2002.add_row([v, em/1e53, e_minus/1e53, e_plus/1e53])
    elif 'kT' in row['Parameter']:
        v = row['Parameter'][:2] + '.T'
        # kT = k_B * T
        T = (row['Value'] / c.k_B.to('keV/K')).value
        t_minus = (row['e_lower'] / c.k_B.to('keV/K')).value
        t_plus = (row['e_upper'] / c.k_B.to('keV/K')).value
        output_2002.add_row([v, T/1e6, t_minus/1e6, t_plus/1e6])

output_2002.pprint_all()

output_2002.write('/Users/woodml/Documents/X-Ray/TaleofTwoStars/SU_Aur/2002_quiet_fit_results.txt', format='latex', overwrite=True)
# Out:
#  Parameter  Value  e_lower e_upper
# ----------- ------ ------- -------
#     abs1.nH  0.423     nan     nan
#       v1.kT  0.731     nan     nan
#       v1.He  1.000     inf     inf
#        v1.C  0.387     inf     inf
#        v1.N  0.387     inf     inf
#        v1.O  0.387  -0.112   0.112
#       v1.Ne  1.195  -0.369   0.369
#       v1.Mg  0.477     inf     inf
#       v1.Al  0.477     inf     inf
#       v1.Si  0.477     inf     inf
#        v1.S  0.387     inf     inf
#       v1.Ar  1.000     inf     inf
#       v1.Ca  0.477     inf     inf
#       v1.Fe  0.477  -0.066   0.066
#       v1.Ni  0.477     inf     inf
# v1.redshift  0.000     inf     inf
#     v1.norm  0.001  -0.000   0.000
#       v2.kT  1.392  -0.064   0.064
# v2.redshift  0.000     inf     inf
#     v2.norm  0.001  -0.000   0.000
#       v3.kT  4.318  -0.550   0.550
# v3.redshift  0.000     inf     inf
#     v3.norm  0.000  -0.000   0.000
#        v1.T  8.477     nan     nan
#       v1.EM  1.672  -0.185   0.185
#        v2.T 16.149  -0.746   0.746
#       v2.EM  2.933  -0.359   0.359
#        v3.T 50.112  -6.384   6.384
#       v3.EM  1.172  -0.160   0.160

# %% [markdown]
# ## 2012

# %%
# Set initial values to results of previous run
abs1.nH = 0.114334
v1.kT = 0.64033
v2.kT = 0.926543
v3.kT = 2.80344 
v1.norm = 6.55452e-05
v2.norm = 0.000128049
v3.norm = 0.000604946

v1.O =  2.83129 
v1.Ne = 3.09538
v1.Mg = 2.25373
v1.Si = 1.27542
v1.Fe = 1.01905

# Unlock/Lock parameters
abs1.nH.frozen = 0
v1.norm.frozen = 0
v2.norm.frozen = 0
v3.norm.frozen = 0
v1.kT.frozen = 0
v2.kT.frozen = 0
v3.kT.frozen = 0

v1.O.frozen  = 0
v1.Fe.frozen = 0
v1.Mg.frozen = 0
v1.Ne.frozen = 0
v1.Si.frozen = 0

# Links
v1.Al = v1.Fe
v1.Ca = v1.Fe

v1.Ni = v1.Mg

v1.C = v1.O
v1.N = v1.O

for v in (v2, v3):
    for p in v.pars[1:-1]:
        p.link = getattr(v1, p.name)

# %%
ui.set_method('moncar')
ui.set_stat('chi2gehrels')
ui.fit('2012_emos1', '2012_emos2', '2012_epn')
# Out:
# Datasets              = '2012_emos1', '2012_emos2', '2012_epn'
# Method                = moncar
# Statistic             = chi2gehrels
# Initial fit statistic = 584.582
# Final fit statistic   = 556.693 at function evaluation 23095
# Data points           = 368
# Degrees of freedom    = 356
# Probability [Q-value] = 4.95034e-11
# Reduced statistic     = 1.56374
# Change in statistic   = 27.8887
#    abs1.nH        0.124446
#    v1.kT          0.61747
#    v1.O           2.80011
#    v1.Ne          2.26742
#    v1.Mg          1.99713
#    v1.Si          1.19118
#    v1.Fe          0.978373
#    v1.norm        8.21838e-05
#    v2.kT          0.991698
#    v2.norm        0.000160517
#    v3.kT          2.87275
#    v3.norm        0.00059032

# %%
# Plot
el = ['He','C','N','O','Ne','Mg','Fe','Si']
caption = "".join(['%s = %.3f \n' %(e, ui.get_par('v1.'+e).val) for e in el])

plt.figure(figsize=(10,6))
ui.plot_fit('2012_emos1')
ui.plot_fit('2012_emos2', overplot=True)
g = plt.gcf().axes
print(type(g[0]))
g[0].lines[1].set_label('EMOS 1')
g[0].lines[1].set_markersize(10)
g[0].lines[1].set_markeredgecolor('k')
g[0].lines[5].set_label('EMOS 2')
g[0].lines[5].set_markersize(10)
g[0].lines[5].set_markeredgecolor('k')
plt.xlim(0.2, 20)
plt.vlines([12.135, 10.239],         0, 0.03, 'k','--', label='Ne')  
plt.vlines([8.4245, 7.1069, 9.1688], 0, 0.03, 'k','-.', label='Mg')
plt.vlines([6.18, 5.21],             0, 0.03, 'k',':', label='Si')
plt.vlines([4.7273, 4.7327],         0, 0.03, 'k',(0,(5,3,1,3,1,3)), label='S')
plt.vlines([3.7311, 3.15],           0, 0.03, 'k',(0,(1,5)), label='Ar')
plt.vlines([1.778, 1.5024],          0, 0.03, 'k',(0,(8,2)), label='Fe')
plt.vlines([16.006], 0, 0.03, 'k',(0,(5,2,1,2,5,2)), label='O')
plt.text(0.95, 0.65, caption, transform=g[0].transAxes, horizontalalignment='right')
plt.xlabel('Wavelength (Angstroms)')
plt.title('SU Aur')
plt.legend(loc=(1.01, 0.2))
plt.show()

plt.figure(figsize=(10,6))
ui.plot_fit('2012_epn')
g = plt.gcf().axes
g[0].lines[1].set_label('2012 EPN')
g[0].lines[1].set_markersize(10)
g[0].lines[1].set_markeredgecolor('k')
plt.xlim(0.2, 20)
plt.vlines([12.135, 10.239],         0, 0.05, 'k','--', label='Ne')  
plt.vlines([8.4245, 7.1069, 9.1688], 0, 0.05, 'k','-.', label='Mg')
plt.vlines([6.18, 5.21],             0, 0.05, 'k',':', label='Si')
plt.vlines([4.7273, 4.7327],         0, 0.05, 'k',(0,(5,3,1,3,1,3)), label='S')
plt.vlines([3.7311, 3.15],           0, 0.05, 'k',(0,(1,5)), label='Ar')
plt.vlines([1.78, 1.50],             0, 0.05, 'k',(0,(8,2)), label='Fe')
plt.vlines([16.006],                 0, 0.05, 'k',(0,(5,2,1,2,5,2)), label='O')
plt.xlabel('Wavelength (Angstroms)')
plt.title('SU Aur')
plt.legend(loc=(1.01, 0.2))
plt.show()
# Out:
# <class 'matplotlib.axes._axes.Axes'>

# %%
ui.covar('2012_emos1', '2012_emos2', '2012_epn')
# Out:
# Datasets              = '2012_emos1', '2012_emos2', '2012_epn'
# Confidence Method     = covariance
# Iterative Fit Method  = None
# Fitting Method        = moncar
# Statistic             = chi2gehrels
# covariance 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    abs1.nH          0.124446  -0.00884523   0.00884523
#    v1.kT             0.61747   -0.0449981    0.0449981
#    v1.O              2.80011     -1.26676      1.26676
#    v1.Ne             2.26742    -0.822856     0.822856
#    v1.Mg             1.99713    -0.460043     0.460043
#    v1.Si             1.19118    -0.267568     0.267568
#    v1.Fe            0.978373    -0.294811     0.294811
#    v1.norm       8.21838e-05 -3.61716e-05  3.61716e-05
#    v2.kT            0.991698   -0.0614663    0.0614663
#    v2.norm       0.000160517 -3.08837e-05  3.08837e-05
#    v3.kT             2.87275    -0.155723     0.155723
#    v3.norm        0.00059032  -0.00011218   0.00011218

# %%
ui.set_source('2012_emos1', ui.xsphabs.abs1*(ui.xsvapec.v1 + ui.xsvapec.v2 + ui.xsvapec.v3))
ui.set_source('2012_emos2', abs1*(v1 + v2 + v3))
ui.set_source('2012_epn',   abs1*(v1 + v2 + v3))

# %%
ui.reset()
for v in (v1, v2, v3):
    for p in v.pars[1:-1]:
        p.link = None

# %%
# Set initial values to results of previous run
abs1.nH = 0.4
v1.kT = 0.575949 
v2.kT = 2.70114
v3.kT = 4.0
v1.norm = 0.0001
v2.norm = 0.0002
v3.norm = 0.001

v1.O =  1.0
v1.Ne = 1.195
v1.Fe = 1.0

# Unlock/Lock parameters
abs1.nH.frozen = 0
v1.norm.frozen = 0
v2.norm.frozen = 0
v3.norm.frozen = 0
v1.kT.frozen = 0
v2.kT.frozen = 0
v3.kT.frozen = 0

v1.O.frozen  = 0
v1.Fe.frozen = 0
v1.Ne.frozen = 0

# Links
v1.Al = v1.Fe
v1.Ca = v1.Fe
v1.Mg = v1.Fe
v1.Si = v1.Fe
v1.Ni = v1.Fe

v1.C = v1.O
v1.N = v1.O
v1.S = v1.O

for v in (v2, v3):
    for p in v.pars[1:-1]:
        p.link = getattr(v1, p.name)

# %%
# - - - - - - - - - - - - - - - - - - - - - - - - 
ui.fit('2012_emos1', '2012_emos2', '2012_epn')
# Out:
# Datasets              = '2012_emos1', '2012_emos2', '2012_epn'
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 6505.42
# Final fit statistic   = 1442.92 at function evaluation 272
# Data points           = 1715
# Degrees of freedom    = 1705
# Probability [Q-value] = 0.999999
# Reduced statistic     = 0.846286
# Change in statistic   = 5062.51
#    abs1.nH        0.442757     +/- 0.0149539
#    v1.kT          1.1914       +/- 0.0370406
#    v1.O           0.231599     +/- 0.0600856
#    v1.Ne          0.263069     +/- 0.163326
#    v1.Fe          0.225679     +/- 0.0226569
#    v1.norm        0.00133191   +/- 0.000150625
#    v2.kT          0.680069     +/- 0.0440477
#    v2.norm        0.000546253  +/- 8.2211e-05
#    v3.kT          4.04785      +/- 0.405579
#    v3.norm        0.000797779  +/- 9.11336e-05

# %%
# ui.set_method('moncar')
ui.covar('2012_emos1', '2012_emos2', '2012_epn')
cov = ui.get_covar_results()
# ui.set_method('levmar')
# Out:
# WARNING: hard minimum hit for parameter abs1.nH
# WARNING: hard maximum hit for parameter abs1.nH
# WARNING: hard minimum hit for parameter v1.Ne
# WARNING: hard maximum hit for parameter v1.Ne
# WARNING: hard minimum hit for parameter v1.Fe
# WARNING: hard maximum hit for parameter v1.Fe
# WARNING: hard minimum hit for parameter v1.norm
# WARNING: hard maximum hit for parameter v1.norm
# WARNING: hard minimum hit for parameter v2.kT
# WARNING: hard maximum hit for parameter v2.kT
# WARNING: hard minimum hit for parameter v3.kT
# WARNING: hard maximum hit for parameter v3.kT
# WARNING: hard minimum hit for parameter v3.norm
# WARNING: hard maximum hit for parameter v3.norm
# Datasets              = '2012_emos1', '2012_emos2', '2012_epn'
# Confidence Method     = covariance
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# covariance 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    abs1.nH          0.442757        -----        -----
#    v1.kT              1.1914   -0.0177937    0.0177937
#    v1.O             0.231599   -0.0474068    0.0474068
#    v1.Ne            0.263069        -----        -----
#    v1.Fe            0.225679        -----        -----
#    v1.norm        0.00133191        -----        -----
#    v2.kT            0.680069        -----        -----
#    v2.norm       0.000546253 -3.87731e-05  3.87731e-05
#    v3.kT             4.04785        -----        -----
#    v3.norm       0.000797779        -----        -----

# %%
# Write out
# Create table
output_2012 = Table(names=('Parameter', 'Value','e_lower','e_upper'), dtype=('str','float','float','float'))

# Get error dictionaries
cov_min = dict(zip(list(cov.parnames), list(cov.parmins)))
cov_max = dict(zip(list(cov.parnames), list(cov.parmaxes)))

for a in (abs1): 
    for p in a.pars:
        parname = str(a.name[-4:]) + '.' + str(p.name)
        if parname in cov_min.keys():
            e_lower = cov_min[parname]
            e_upper = cov_max[parname]
            output_2012.add_row([parname, float(p.val), e_lower, e_upper])
        else:
            output_2012.add_row([parname, float(p.val), float('inf'), float('inf')])

i = 0
for v in (v1, v2, v3):
    for p in v.pars:
        parname = str(v.name[-2:]) + '.' + str(p.name)
        if p.name in ['He','C','N','O','Ne','Mg','Al','Si','S','Ar','Ca','Fe','Ni'] and i > 0:
            continue
        if parname in cov_min.keys():
            e_lower = cov_min[parname]
            e_upper = cov_max[parname]
            output_2012.add_row([parname, float(p.val), e_lower, e_upper])
        else:
            output_2012.add_row([parname, float(p.val), float('inf'), float('inf')])
    i += 1

output_2012['Value'].format= '.3f'
output_2012['e_lower'].format= '.3f'
output_2012['e_upper'].format= '.3f'

# norm = 1e-14* EM /(4*pi*d^2)
# EM = 4*pi*d^2 * norm / 1 e-14
d = 1000/6.3700 * u.pc  # parallax is 6.37 mas (Gaia DR3)
d = d.to(u.cm)

for row in output_2012:
    if 'norm' in row['Parameter']:
        v = row['Parameter'][:2] + '.EM'
        # norm = EM * 10**-14/(4*np.pi*d**2)
        em = row['Value']/(10**-14)*(4*np.pi*d**2)
        e_plus = row['e_upper']/(10**-14)*(4*np.pi*d**2)
        e_minus = row['e_lower']/(10**-14)*(4*np.pi*d**2)
        output_2012.add_row([v, em/1e53, e_minus/1e53, e_plus/1e53])
    elif 'kT' in row['Parameter']:
        v = row['Parameter'][:2] + '.T'
        # kT = k_B * T
        T = (row['Value'] / c.k_B.to('keV/K')).value
        t_minus = (row['e_lower'] / c.k_B.to('keV/K')).value
        t_plus = (row['e_upper'] / c.k_B.to('keV/K')).value
        output_2012.add_row([v, T/1e6, t_minus/1e6, t_plus/1e6])

output_2012.pprint_all()

output_2012.write('/Users/woodml/Documents/X-Ray/TaleofTwoStars/SU_Aur/2012_quiet_fit_results.txt', format='latex', overwrite=True)
# Out:
#  Parameter  Value  e_lower e_upper
# ----------- ------ ------- -------
#     abs1.nH  0.443     nan     nan
#       v1.kT  1.191  -0.018   0.018
#       v1.He  1.000     inf     inf
#        v1.C  0.232     inf     inf
#        v1.N  0.232     inf     inf
#        v1.O  0.232  -0.047   0.047
#       v1.Ne  0.263     nan     nan
#       v1.Mg  0.226     inf     inf
#       v1.Al  0.226     inf     inf
#       v1.Si  0.226     inf     inf
#        v1.S  0.232     inf     inf
#       v1.Ar  1.000     inf     inf
#       v1.Ca  0.226     inf     inf
#       v1.Fe  0.226     nan     nan
#       v1.Ni  0.226     inf     inf
# v1.redshift  0.000     inf     inf
#     v1.norm  0.001     nan     nan
#       v2.kT  0.680     nan     nan
# v2.redshift  0.000     inf     inf
#     v2.norm  0.001  -0.000   0.000
#       v3.kT  4.048     nan     nan
# v3.redshift  0.000     inf     inf
#     v3.norm  0.001     nan     nan
#        v1.T 13.826  -0.206   0.206
#       v1.EM  3.927     nan     nan
#        v2.T  7.892     nan     nan
#       v2.EM  1.611  -0.114   0.114
#        v3.T 46.973     nan     nan
#       v3.EM  2.352     nan     nan

# %% [markdown]
# ## Plot Both

# %%
ui.set_analysis('energy')
ui.fit('2002_emos1', '2002_emos2')

fit = ui.get_fit_plot('2002_emos1')
fit1 = deepcopy(fit)
data1 = fit1.dataplot
model1 = fit1.modelplot

fit = ui.get_fit_plot('2002_emos2')
fit2 = deepcopy(fit)
data2 = fit2.dataplot
model2 = fit2.modelplot

# 2012
ui.fit('2012_emos1', '2012_emos2', '2012_epn')

fit12 = ui.get_fit_plot('2012_emos1')
fit112 = deepcopy(fit12)
data112 = fit112.dataplot
model112 = fit112.modelplot

fit12 = ui.get_fit_plot('2012_emos2')
fit212 = deepcopy(fit12)
data212 = fit212.dataplot
model212 = fit212.modelplot
# Out:
# Datasets              = '2002_emos1', '2002_emos2'
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 711.67
# Final fit statistic   = 263.113 at function evaluation 142
# Data points           = 339
# Degrees of freedom    = 329
# Probability [Q-value] = 0.996899
# Reduced statistic     = 0.799736
# Change in statistic   = 448.557
#    abs1.nH        0.423443     +/- 0.0276031
#    v1.kT          1.39139      +/- 0.0965352
#    v1.O           0.387403     +/- 0.119891
#    v1.Ne          1.19485      +/- 0.377295
#    v1.Fe          0.477229     +/- 0.0664009
#    v1.norm        0.000993999  +/- 0.000178026
#    v2.kT          0.730456     +/- 0.0291788
#    v2.norm        0.000566879  +/- 8.81611e-05
#    v3.kT          4.31885      +/- 1.52762
#    v3.norm        0.000397825  +/- 0.000154327
# Datasets              = '2012_emos1', '2012_emos2', '2012_epn'
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 2747.5
# Final fit statistic   = 1442.91 at function evaluation 78
# Data points           = 1715
# Degrees of freedom    = 1705
# Probability [Q-value] = 0.999999
# Reduced statistic     = 0.846283
# Change in statistic   = 1304.59
#    abs1.nH        0.441489     +/- 0.014619
#    v1.kT          1.19919      +/- 0.0441548
#    v1.O           0.231292     +/- 0.0599499
#    v1.Ne          0.281517     +/- 0.16695
#    v1.Fe          0.224958     +/- 0.0225079
#    v1.norm        0.00131963   +/- 0.000157932
#    v2.kT          0.690892     +/- 0.0502136
#    v2.norm        0.00055877   +/- 9.94312e-05
#    v3.kT          4.074        +/- 0.417356
#    v3.norm        0.000790354  +/- 9.29011e-05

# %%
colors = ['#f5f298','#e1dd5f','#16db93','#10a46e','#cf2626','#811818','#239ab3','#03687e']
colors = ['#fecd91','darkorange','#88efc9','#2cbf89','#fe7373','#cf2626','lightblue','steelblue']

# _, ax = plt.subplots(nrows=2, ncols=1, sharex='col', figsize=(12,6.5), gridspec_kw={'hspace':0.05})
_, ax = plt.subplots(figsize=(12,4.5))

plt.errorbar(np.mean([data1.xlo, data1.xhi], axis=0), data1.y, yerr=data1.yerr, ls='none', c=colors[0], ms=5, marker='o', markeredgecolor='k', markeredgewidth=0.75, alpha=1, capsize=0, label='2002 EMOS 1')
plt.errorbar(np.mean([data2.xlo, data2.xhi], axis=0), data2.y, yerr=data2.yerr, ls='none', c=colors[2], ms=5, marker='o', markeredgecolor='k', markeredgewidth=0.75, alpha=1, capsize=0, label='2002 EMOS 2')

plt.step(np.mean([model1.xlo, model1.xhi], axis=0), model1.y, c=colors[1], lw=2, zorder=4)
plt.step(np.mean([model2.xlo, model2.xhi], axis=0), model2.y, c=colors[3], lw=2, zorder=4)

# 2012 data

plt.errorbar(np.mean([data112.xlo, data112.xhi], axis=0), data112.y, yerr=data112.yerr, c=colors[4], ls='none', ms=5, marker='s', markeredgecolor='k', markeredgewidth=0.75, alpha=1, capsize=0, label='2012 EMOS 1')
plt.errorbar(np.mean([data212.xlo, data212.xhi], axis=0), data212.y, yerr=data212.yerr, c=colors[6], ls='none', ms=5, marker='s', markeredgecolor='k', markeredgewidth=0.75, alpha=1, capsize=0, label='2012 EMOS 2')

plt.step(np.mean([model112.xlo, model112.xhi], axis=0), model112.y, c=colors[5], lw=2, zorder=4)
plt.step(np.mean([model212.xlo, model212.xhi], axis=0), model212.y, c=colors[7], lw=2, zorder=4)

# Abundance lines
plt.vlines(energy([12.135, 10.239]),         -1, 0.3, 'k','--', label='Ne')  
plt.vlines(energy([8.4245, 7.1069, 9.1688]), -1, 0.3, 'k','-.', label='Mg')
plt.vlines(energy([6.18]),             -1, 0.3, 'k',':', label='Si')
# plt.vlines(energy([4.7273, 4.7327]),         0, 0.3, 'k',(0,(5,3,1,3,1,3)), label='S')
# plt.vlines(energy([3.7311, 3.15]),           0, 0.1, 'k',(0,(1,5)), label='Ar')
plt.vlines(energy([1.778, 1.85]),    -1, 0.11, 'k',(0,(8,2)), label='Fe')
# plt.vlines(energy([16.006]), 0, 0.3, 'k',(0,(5,2,1,2,5,2)), label='O')

plt.legend(loc=(1.01, 0.2))
plt.grid('major','both',c='lightgray',ls='--', zorder=0)

plt.xlim(0.5, 13)
plt.ylim(-0.005, 0.25)
plt.xscale('log')

plt.xlabel(r'Energy (keV)', fontsize=14)
plt.ylabel('Counts/s/Angstrom', fontsize=14)
plt.xticks([0.6, 0.8, 1, 2, 4,6, 8,10], ['0.6','0.8','1','2','4','6','8','10'])

# Inset Axis
x1, x2, y1, y2 = 5, 8, 1e-4, 1e-2  # subregion of the original image
axins = ax.inset_axes([0.57, 0.55, 0.41, 0.42], xlim=(x1, x2), ylim=(y1, y2))
axins.errorbar(np.mean([data112.xlo, data112.xhi], axis=0), data112.y, yerr=data112.yerr, c=colors[4], ls='none', ms=5, marker='s', markeredgecolor='k', markeredgewidth=0.75, alpha=1, capsize=0, label='2012 EMOS 1')
axins.errorbar(np.mean([data212.xlo, data212.xhi], axis=0), data212.y, yerr=data212.yerr, c=colors[6], ls='none', ms=5, marker='s', markeredgecolor='k', markeredgewidth=0.75, alpha=1, capsize=0, label='2012 EMOS 2')

axins.step(np.mean([model112.xlo, model112.xhi], axis=0), model112.y, c=colors[5], lw=2, zorder=4)
axins.step(np.mean([model212.xlo, model212.xhi], axis=0), model212.y, c=colors[7], lw=2, zorder=4)

axins.vlines(energy([1.778, 1.5024, 1.85]),    0, 0.1, 'k',(0,(8,2)), label='Fe')

axins.set_yscale('log')
ax.indicate_inset_zoom(axins, edgecolor='k', alpha=0.7)

plt.savefig('/Users/woodml/Documents/X-Ray/TaleofTwoStars/SU_Aur/figure_global_fit.pdf', format='pdf', bbox_inches='tight', pad_inches=0.1, transparent=True)

plt.show()

# %% [markdown]
# # Model D
#
# ## 2002

# %%
ui.set_source('2002_emos1', ui.xsphabs.abs1*(ui.xsvapec.v1 + ui.xsvapec.v2) + ui.xsphabs.abs2*(ui.xsvapec.v3))
ui.set_source('2002_emos2', abs1*(v1 + v2)  + abs2*v3)

# %%
# Reset Links
ui.reset()
for v in (v1, v2, v3):
    for p in v.pars[1:-1]:
        p.link = None

# %%
# Set initial values to results of previous run
abs1.nH = 0.58
abs2.nH = 0.28
v1.kT = 0.64
v2.kT = 1.1
v3.kT = 2.7
v1.norm = 0.0004
v2.norm = 0.0004
v3.norm = 0.0008

v1.O =  0.39
v1.Ne = 1.8
v1.Fe = 0.75

# Unlock/Lock parameters
abs1.nH.frozen = 0
abs2.nH.frozen = 0
v1.norm.frozen = 0
v2.norm.frozen = 0
v3.norm.frozen = 0
v1.kT.frozen = 0
v2.kT.frozen = 0
v3.kT.frozen = 0

v1.O.frozen  = 0
v1.Ne.frozen = 0
v1.Fe.frozen = 0

# Links
v1.Al = v1.Fe
v1.Ca = v1.Fe
v1.Mg = v1.Fe
v1.Si = v1.Fe
v1.Ni = v1.Fe

v1.C = v1.O
v1.N = v1.O
v1.S = v1.O

for v in (v2, v3):
    for p in v.pars[1:-1]:
        p.link = getattr(v1, p.name)

# %%
ui.fit('2002_emos1', '2002_emos2')
# Out:
# Datasets              = '2002_emos1', '2002_emos2'
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 254.841
# Final fit statistic   = 254.841 at function evaluation 25
# Data points           = 339
# Degrees of freedom    = 328
# Probability [Q-value] = 0.998948
# Reduced statistic     = 0.776953
# Change in statistic   = 9.61221e-07
#    abs1.nH        0.600147     +/- 0.0574022
#    v1.kT          0.627        +/- 0.0648224
#    v1.O           0.63169      +/- 0.201464
#    v1.Ne          1.96289      +/- 0.517869
#    v1.Fe          0.824175     +/- 0.116813
#    v1.norm        0.00041045   +/- 0.000100409
#    v2.kT          1.05936      +/- 0.101447
#    v2.norm        0.00041471   +/- 8.56604e-05
#    abs2.nH        0.274744     +/- 0.046776
#    v3.kT          2.66971      +/- 0.223686
#    v3.norm        0.000806086  +/- 9.69281e-05

# %%
# Plot
el = ['Ne','Mg','Fe','Si']
caption = "".join(['%s = %.3f \n' %(e, ui.get_par('v1.'+e).val) for e in el])

plt.figure(figsize=(10,4))
ui.plot_fit('2002_emos1')
ui.plot_fit('2002_emos2', overplot=True)
g = plt.gcf().axes
g[0].lines[1].set_label('EMOS 1')
g[0].lines[1].set_markersize(10)
g[0].lines[1].set_markeredgecolor('k')
g[0].lines[5].set_label('EMOS 2')
g[0].lines[5].set_markersize(10)
g[0].lines[5].set_markeredgecolor('k')
plt.xlim(0.2, 20)
plt.vlines([12.135, 10.239],         0, 0.03, 'k','--', label='Ne')  
plt.vlines([8.4245, 7.1069, 9.1688], 0, 0.03, 'k','-.', label='Mg')
plt.vlines([6.18, 5.21],             0, 0.03, 'k',':', label='Si')
plt.vlines([4.7273, 4.7327],         0, 0.03, 'k',(0,(5,3,1,3,1,3)), label='S')
plt.vlines([3.7311, 3.15],           0, 0.03, 'k',(0,(1,5)), label='Ar')
plt.vlines([1.778, 1.5024],          0, 0.03, 'k',(0,(8,2)), label='Fe')
plt.vlines([16.006], 0, 0.03, 'k',(0,(5,2,1,2,5,2)), label='O')
# plt.vlines([7.4], 0, 0.03, 'r','--', alpha=0.9)

# plt.text(0.975, 0.7, caption, transform=g[0].transAxes, horizontalalignment='right')
plt.xlabel('Wavelength (Angstroms)')
plt.title('SU Aur')
plt.legend(loc=(1.01, 0.2))
plt.show()

# %%
ui.covar('2002_emos1', '2002_emos2')
cov = ui.get_covar_results()
# Out:
# WARNING: hard minimum hit for parameter abs1.nH
# WARNING: hard maximum hit for parameter abs1.nH
# WARNING: hard minimum hit for parameter v1.kT
# WARNING: hard maximum hit for parameter v1.kT
# WARNING: hard minimum hit for parameter v1.Ne
# WARNING: hard maximum hit for parameter v1.Ne
# WARNING: hard minimum hit for parameter v1.Fe
# WARNING: hard maximum hit for parameter v1.Fe
# WARNING: hard minimum hit for parameter v2.kT
# WARNING: hard maximum hit for parameter v2.kT
# WARNING: hard minimum hit for parameter v2.norm
# WARNING: hard maximum hit for parameter v2.norm
# WARNING: hard minimum hit for parameter abs2.nH
# WARNING: hard maximum hit for parameter abs2.nH
# WARNING: hard minimum hit for parameter v3.kT
# WARNING: hard maximum hit for parameter v3.kT
# WARNING: hard minimum hit for parameter v3.norm
# WARNING: hard maximum hit for parameter v3.norm
# Datasets              = '2002_emos1', '2002_emos2'
# Confidence Method     = covariance
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# covariance 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    abs1.nH          0.600147        -----        -----
#    v1.kT               0.627        -----        -----
#    v1.O              0.63169   -0.0637562    0.0637562
#    v1.Ne             1.96289        -----        -----
#    v1.Fe            0.824175        -----        -----
#    v1.norm        0.00041045 -6.79726e-05  6.79726e-05
#    v2.kT             1.05936        -----        -----
#    v2.norm        0.00041471        -----        -----
#    abs2.nH          0.274744        -----        -----
#    v3.kT             2.66971        -----        -----
#    v3.norm       0.000806086        -----        -----

# %%
# Write out
# Create table
output_2002 = Table(names=('Parameter', 'Value','e_lower','e_upper'), dtype=('str','float','float','float'))

# Get error dictionaries
cov_min = dict(zip(list(cov.parnames), list(cov.parmins)))
cov_max = dict(zip(list(cov.parnames), list(cov.parmaxes)))

for a in (abs1, abs2): 
    for p in a.pars:
        parname = str(a.name[-4:]) + '.' + str(p.name)
        if parname in cov_min.keys():
            e_lower = cov_min[parname]
            e_upper = cov_max[parname]
            output_2002.add_row([parname, float(p.val), e_lower, e_upper])
        else:
            output_2002.add_row([parname, float(p.val), float('inf'), float('inf')])

i = 0
for v in (v1, v2, v3):
    for p in v.pars:
        parname = str(v.name[-2:]) + '.' + str(p.name)
        if p.name in ['He','C','N','O','Ne','Mg','Al','Si','S','Ar','Ca','Fe','Ni'] and i > 0:
            continue
        if parname in cov_min.keys():
            e_lower = cov_min[parname]
            e_upper = cov_max[parname]
            output_2002.add_row([parname, float(p.val), e_lower, e_upper])
        else:
            output_2002.add_row([parname, float(p.val), float('inf'), float('inf')])
    i += 1

output_2002['Value'].format= '.3f'
output_2002['e_lower'].format= '.3f'
output_2002['e_upper'].format= '.3f'

# norm = 1e-14* EM /(4*pi*d^2)
# EM = 4*pi*d^2 * norm / 1 e-14
d = 1000/6.3700 * u.pc  # parallax is 6.37 mas (Gaia DR3)
d = d.to(u.cm)

for row in output_2002:
    if 'norm' in row['Parameter']:
        v = row['Parameter'][:2] + '.EM'
        # norm = EM * 10**-14/(4*np.pi*d**2)
        em = row['Value']/(10**-14)*(4*np.pi*d**2)
        e_plus = row['e_upper']/(10**-14)*(4*np.pi*d**2)
        e_minus = row['e_lower']/(10**-14)*(4*np.pi*d**2)
        output_2002.add_row([v, em/1e53, e_minus/1e53, e_plus/1e53])
    elif 'kT' in row['Parameter']:
        v = row['Parameter'][:2] + '.T'
        # kT = k_B * T
        T = (row['Value'] / c.k_B.to('keV/K')).value
        t_minus = (row['e_lower'] / c.k_B.to('keV/K')).value
        t_plus = (row['e_upper'] / c.k_B.to('keV/K')).value
        output_2002.add_row([v, T/1e6, t_minus/1e6, t_plus/1e6])

output_2002.pprint_all()

output_2002.write('/Users/woodml/Documents/X-Ray/TaleofTwoStars/SU_Aur/2002_quiet_fit_D_results.txt', format='latex', overwrite=True)
# Out:
#  Parameter  Value  e_lower e_upper
# ----------- ------ ------- -------
#     abs1.nH  0.600     nan     nan
#     abs2.nH  0.275     nan     nan
#       v1.kT  0.627     nan     nan
#       v1.He  1.000     inf     inf
#        v1.C  0.632     inf     inf
#        v1.N  0.632     inf     inf
#        v1.O  0.632  -0.064   0.064
#       v1.Ne  1.963     nan     nan
#       v1.Mg  0.824     inf     inf
#       v1.Al  0.824     inf     inf
#       v1.Si  0.824     inf     inf
#        v1.S  0.632     inf     inf
#       v1.Ar  1.000     inf     inf
#       v1.Ca  0.824     inf     inf
#       v1.Fe  0.824     nan     nan
#       v1.Ni  0.824     inf     inf
# v1.redshift  0.000     inf     inf
#     v1.norm  0.000  -0.000   0.000
#       v2.kT  1.059     nan     nan
# v2.redshift  0.000     inf     inf
#     v2.norm  0.000     nan     nan
#       v3.kT  2.670     nan     nan
# v3.redshift  0.000     inf     inf
#     v3.norm  0.001     nan     nan
#        v1.T  7.276     nan     nan
#       v1.EM  1.210  -0.200   0.200
#        v2.T 12.293     nan     nan
#       v2.EM  1.223     nan     nan
#        v3.T 30.981     nan     nan
#       v3.EM  2.377     nan     nan

# %% [markdown]
# ## 2012

# %%
ui.set_source('2012_emos1', ui.xsphabs.abs1*(ui.xsvapec.v1 + ui.xsvapec.v2) + ui.xsphabs.abs2*(ui.xsvapec.v3))
ui.set_source('2012_emos2', abs1*(v1 + v2)  + abs2*v3)
ui.set_source('2012_epn', abs1*(v1 + v2)  + abs2*v3)

# %%
# Reset Links
for v in (v1, v2, v3):
    for p in v.pars[1:-1]:
        p.link = None

# %%
abs1.nH = 0.75
abs2.nH = 0.35
v1.kT = 0.699465  # 0.5
v2.kT = 0.966824  # 1.0
v3.kT = 2.92844  # 3.0
v1.norm = 0.00025
v2.norm = 0.00023
v3.norm = 0.00102
 
v1.O  = 1.0  # 2002 abundances
v1.Ne = 5.0805
v1.Fe = 1.0

# Unlock/Lock parameters
abs1.nH.frozen = 0
abs2.nH.frozen = 0
v1.norm.frozen = 0
v2.norm.frozen = 0
v3.norm.frozen = 0
v1.kT.frozen = 0
v2.kT.frozen = 0
v3.kT.frozen = 0

v1.O.frozen  = 0
v1.Ne.frozen = 0
v1.Fe.frozen = 0

# Links
v1.Al = v1.Fe
v1.Ca = v1.Fe
v1.Mg = v1.Fe
v1.Si = v1.Fe
v1.Ni = v1.Fe

v1.C = v1.O
v1.N = v1.O
v1.S = v1.O

for v in (v2, v3):
    for p in v.pars[1:-1]:
        p.link = getattr(v1, p.name)

# %%
ui.fit('2012_emos1', '2012_emos2', '2012_epn')
# Out:
# Datasets              = '2012_emos1', '2012_emos2', '2012_epn'
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 1811.74
# Final fit statistic   = 1423.32 at function evaluation 183
# Data points           = 1715
# Degrees of freedom    = 1704
# Probability [Q-value] = 1
# Reduced statistic     = 0.835284
# Change in statistic   = 388.419
#    abs1.nH        0.757456     +/- 0.0618851
#    v1.kT          0.353118     +/- 0.0364025
#    v1.O           0.399589     +/- 0.0966578
#    v1.Ne          0.682989     +/- 0.176802
#    v1.Fe          0.444272     +/- 0.0413504
#    v1.norm        0.000991706  +/- 0.000384169
#    v2.kT          0.992926     +/- 0.0241824
#    v2.norm        0.000903395  +/- 0.000105865
#    abs2.nH        0.317682     +/- 0.0217967
#    v3.kT          3.09475      +/- 0.127922
#    v3.norm        0.00109954   +/- 5.66116e-05

# %%
# Plot
el = ['Ne','Mg','Fe', 'Al','Si']
caption = "".join(['%s = %.3f \n' %(e, ui.get_par('v1.'+e).val) for e in el])

plt.figure(figsize=(10,4))
ui.plot_fit('2012_emos1')
ui.plot_fit('2012_emos2', overplot=True)
g = plt.gcf().axes
print(type(g[0]))
g[0].lines[1].set_label('EMOS 1')
g[0].lines[1].set_markersize(10)
g[0].lines[1].set_markeredgecolor('k')
g[0].lines[5].set_label('EMOS 2')
g[0].lines[5].set_markersize(10)
g[0].lines[5].set_markeredgecolor('k')
plt.xlim(0.2, 20)
plt.ylim(-0.001, 0.026)
plt.vlines([12.135, 10.239],         0, 0.025, 'k','--', label='Ne')  
plt.vlines([8.4245, 7.1069, 9.1688], 0, 0.025, 'k','-.', label='Mg')
plt.vlines([6.18, 5.21],             0, 0.025, 'k',':', label='Si')
plt.vlines([4.7273, 4.7327],         0, 0.025, 'k',(0,(5,3,1,3,1,3)), label='S')
plt.vlines([3.7311, 3.15],           0, 0.025, 'k',(0,(1,5)), label='Ar')
plt.vlines([1.778, 1.5024],          0, 0.025, 'k',(0,(8,2)), label='Fe')
plt.vlines([16.006], 0, 0.03, 'k',(0,(5,2,1,2,5,2)), label='O')
# plt.text(0.95, 0.7, caption, transform=g[0].transAxes, horizontalalignment='right')
plt.xlabel('Wavelength (Angstroms)')
plt.title('2012 EMOS')
plt.legend(loc=(1.01, 0.2))
plt.show()

plt.figure(figsize=(8,4))
ui.plot_fit('2012_epn')
g = plt.gcf().axes
g[0].lines[1].set_markersize(10)
g[0].lines[1].set_markeredgecolor('k')
plt.xlim(0.2, 20)
plt.vlines([12.135, 10.239],         0, 0.05, 'k','--', label='Ne')  
plt.vlines([8.4245, 7.1069, 9.1688], 0, 0.05, 'k','-.', label='Mg')
plt.vlines([6.18, 5.21],             0, 0.05, 'k',':', label='Si')
plt.vlines([4.7273, 4.7327],         0, 0.05, 'k',(0,(5,3,1,3,1,3)), label='S')
plt.vlines([3.7311, 3.15],           0, 0.05, 'k',(0,(1,5)), label='Ar')
plt.vlines([1.78, 1.50],             0, 0.05, 'k',(0,(8,2)), label='Fe')
plt.vlines([16.006],                 0, 0.05, 'k',(0,(5,2,1,2,5,2)), label='O')
plt.xlabel('Wavelength (Angstroms)')
plt.title('2012 EPN')
plt.legend(loc=(1.01, 0.2))
plt.show()
# Out:
# <class 'matplotlib.axes._axes.Axes'>

# %%
ui.covar('2012_emos1','2012_emos2', '2012_epn')
cov = ui.get_covar_results()
# Out:
# Datasets              = '2012_emos1', '2012_emos2', '2012_epn'
# Confidence Method     = covariance
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# covariance 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    abs1.nH          0.757456    -0.113578     0.113578
#    v1.kT            0.353118   -0.0560569    0.0560569
#    v1.O             0.399589   -0.0973447    0.0973447
#    v1.Ne            0.682989    -0.174172     0.174172
#    v1.Fe            0.444272   -0.0423128    0.0423128
#    v1.norm       0.000991706 -0.000719166  0.000719166
#    v2.kT            0.992926     -0.03064      0.03064
#    v2.norm       0.000903395 -0.000160184  0.000160184
#    abs2.nH          0.317682   -0.0232427    0.0232427
#    v3.kT             3.09475    -0.223686     0.223686
#    v3.norm        0.00109954 -0.000104402  0.000104402

# %%
# Write out
# Create table
output_2012 = Table(names=('Parameter', 'Value','e_lower','e_upper'), dtype=('str','float','float','float'))

# Get error dictionaries
cov_min = dict(zip(list(cov.parnames), list(cov.parmins)))
cov_max = dict(zip(list(cov.parnames), list(cov.parmaxes)))

for a in (abs1, abs2): 
    for p in a.pars:
        parname = str(a.name[-4:]) + '.' + str(p.name)
        if parname in cov_min.keys():
            e_lower = cov_min[parname]
            e_upper = cov_max[parname]
            output_2012.add_row([parname, float(p.val), e_lower, e_upper])
        else:
            output_2012.add_row([parname, float(p.val), float('inf'), float('inf')])

i = 0
for v in (v1, v2, v3):
    for p in v.pars:
        parname = str(v.name[-2:]) + '.' + str(p.name)
        if p.name in ['He','C','N','O','Ne','Mg','Al','Si','S','Ar','Ca','Fe','Ni'] and i > 0:
            continue
        if parname in cov_min.keys():
            e_lower = cov_min[parname]
            e_upper = cov_max[parname]
            output_2012.add_row([parname, float(p.val), e_lower, e_upper])
        else:
            output_2012.add_row([parname, float(p.val), float('inf'), float('inf')])
    i += 1

output_2012['Value'].format= '.3f'
output_2012['e_lower'].format= '.3f'
output_2012['e_upper'].format= '.3f'

# norm = 1e-14* EM /(4*pi*d^2)
# EM = 4*pi*d^2 * norm / 1 e-14
d = 1000/6.3700 * u.pc  # parallax is 6.37 mas (Gaia DR3)
d = d.to(u.cm)

for row in output_2012:
    if 'norm' in row['Parameter']:
        v = row['Parameter'][:2] + '.EM'
        # norm = EM * 10**-14/(4*np.pi*d**2)
        em = row['Value']/(10**-14)*(4*np.pi*d**2)
        e_plus = row['e_upper']/(10**-14)*(4*np.pi*d**2)
        e_minus = row['e_lower']/(10**-14)*(4*np.pi*d**2)
        output_2012.add_row([v, em/1e53, e_minus/1e53, e_plus/1e53])
    elif 'kT' in row['Parameter']:
        v = row['Parameter'][:2] + '.T'
        # kT = k_B * T
        T = (row['Value'] / c.k_B.to('keV/K')).value
        t_minus = (row['e_lower'] / c.k_B.to('keV/K')).value
        t_plus = (row['e_upper'] / c.k_B.to('keV/K')).value
        output_2012.add_row([v, T/1e6, t_minus/1e6, t_plus/1e6])

output_2012.pprint_all()

output_2012.write('/Users/woodml/Documents/X-Ray/TaleofTwoStars/SU_Aur/2012_quiet_fit_D_results.txt', format='latex', overwrite=True)
# Out:
#  Parameter  Value  e_lower e_upper
# ----------- ------ ------- -------
#     abs1.nH  0.757  -0.114   0.114
#     abs2.nH  0.318  -0.023   0.023
#       v1.kT  0.353  -0.056   0.056
#       v1.He  1.000     inf     inf
#        v1.C  0.400     inf     inf
#        v1.N  0.400     inf     inf
#        v1.O  0.400  -0.097   0.097
#       v1.Ne  0.683  -0.174   0.174
#       v1.Mg  0.444     inf     inf
#       v1.Al  0.444     inf     inf
#       v1.Si  0.444     inf     inf
#        v1.S  0.400     inf     inf
#       v1.Ar  1.000     inf     inf
#       v1.Ca  0.444     inf     inf
#       v1.Fe  0.444  -0.042   0.042
#       v1.Ni  0.444     inf     inf
# v1.redshift  0.000     inf     inf
#     v1.norm  0.001  -0.001   0.001
#       v2.kT  0.993  -0.031   0.031
# v2.redshift  0.000     inf     inf
#     v2.norm  0.001  -0.000   0.000
#       v3.kT  3.095  -0.224   0.224
# v3.redshift  0.000     inf     inf
#     v3.norm  0.001  -0.000   0.000
#        v1.T  4.098  -0.651   0.651
#       v1.EM  2.924  -2.121   2.121
#        v2.T 11.522  -0.356   0.356
#       v2.EM  2.664  -0.472   0.472
#        v3.T 35.913  -2.596   2.596
#       v3.EM  3.242  -0.308   0.308

# %%
_, ax = plt.subplots(nrows=2, ncols=1, sharex='col', figsize=(12,6.5), gridspec_kw={'hspace':0.05})

ui.fit('2002_emos1', '2002_emos2')

ui.plot_fit('2002_emos1')
ui.plot_fit('2002_emos2', overplot=True)
g = plt.gcf().axes
# data 1
g[0].lines[1].set_label('2002 EMOS 1')
g[0].lines[1].set_markersize(11)
g[0].lines[1].set_markeredgecolor('k')
g[0].lines[1].set_zorder(5)
# fit 1
g[0].lines[2].set_color('#1f77b4')
g[0].lines[2].set_zorder(10)
# data 2
g[0].lines[5].set_label('2002 EMOS 2')
g[0].lines[5].set_markersize(11)
g[0].lines[5].set_markeredgecolor('k')
g[0].lines[5].set_zorder(5)
g[0].lines[5].set_alpha(0.7)
# fit 2
g[0].lines[6].set_color('#2ca02c')
g[0].lines[6].set_zorder(10)


ui.fit('2012_emos1', '2012_emos2', '2012_epn')

# 2012 Fit
ui.plot_fit('2012_emos1', overplot=True)
ui.plot_fit('2012_emos2', overplot=True)
g = plt.gcf().axes
# data 1
g[0].lines[9].set_label('2012 EMOS 1')
g[0].lines[9].set_marker('s')
g[0].lines[9].set_markersize(5.3)
g[0].lines[9].set_markeredgecolor('k')
g[0].lines[9].set_alpha(0.7)
# fit 1
g[0].lines[10].set_color('#9467bd')
g[0].lines[10].set_zorder(10)
# # data 2
g[0].lines[13].set_label('2012 EMOS 2')
g[0].lines[13].set_marker('s')
g[0].lines[13].set_markersize(5.3)
g[0].lines[13].set_markeredgecolor('k')
g[0].lines[13].set_alpha(1.)
g[0].lines[13].set_zorder(5)
# # fit 2
g[0].lines[14].set_color('#e377c2')
g[0].lines[14].set_alpha(1.)
# g[0].lines[14].set_linewidth(2.2)
g[0].lines[14].set_zorder(10)

# Abundance lines
plt.vlines([12.135, 10.239],         0, 0.03, 'k','--', label='Ne')  
plt.vlines([8.4245, 7.1069, 9.1688], 0, 0.03, 'k','-.', label='Mg')
plt.vlines([6.18, 5.21],             0, 0.03, 'k',':', label='Si')
plt.vlines([4.7273, 4.7327],         0, 0.03, 'k',(0,(5,3,1,3,1,3)), label='S')
plt.vlines([3.7311, 3.15],           0, 0.03, 'k',(0,(1,5)), label='Ar')
plt.vlines([1.778, 1.5024],          0, 0.03, 'k',(0,(8,2)), label='Fe')
plt.vlines([16.006], 0, 0.03, 'k',(0,(5,2,1,2,5,2)), label='O')

plt.xlim(0.2, 20)
plt.xlabel('Wavelength (Angstroms)', fontsize=14)
plt.ylabel('Counts/sec/Angstrom', fontsize=14)
plt.title('')
plt.legend(loc=(0.833, 0.3))
# plt.savefig('/Users/woodml/Documents/X-Ray/SU Aur/figure_global_fit.pdf', format='pdf', bbox_inches='tight', pad_inches=0.1, transparent=True)
plt.show()
# Out:
# Datasets              = '2002_emos1', '2002_emos2'
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 1354.28
# Final fit statistic   = 374.094 at function evaluation 71
# Data points           = 472
# Degrees of freedom    = 459
# Probability [Q-value] = 0.998531
# Reduced statistic     = 0.81502
# Change in statistic   = 980.182
#    abs1.nH        0.655904     +/- 0.0550074
#    v1.kT          0.643812     +/- 0.0546414
#    v1.O           1.49418      +/- 0.643838
#    v1.Ne          2.68905      +/- 0.532974
#    v1.Mg          1.21469      +/- 0.171916
#    v1.Si          0.844367     +/- 0.117435
#    v1.Fe          1.01602      +/- 0.0950627
#    v1.norm        0.000374822  +/- 9.58119e-05
#    v2.kT          1.00455      +/- 0.0730947
#    v2.norm        0.000366396  +/- 7.62941e-05
#    abs2.nH        0.272605     +/- 0.0326932
#    v3.kT          3.00281      +/- 0.158158
#    v3.norm        0.000921325  +/- 6.73366e-05
# Datasets              = '2012_emos1', '2012_emos2', '2012_epn'
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 3539.48
# Final fit statistic   = 1396.11 at function evaluation 85
# Data points           = 1717
# Degrees of freedom    = 1704
# Probability [Q-value] = 1
# Reduced statistic     = 0.819314
# Change in statistic   = 2143.37
#    abs1.nH        0.65603      +/- 0.0624097
#    v1.kT          0.45377      +/- 0.0566826
#    v1.O           1.61791      +/- 0.472958
#    v1.Ne          1.77938      +/- 0.394966
#    v1.Mg          0.936477     +/- 0.136533
#    v1.Si          0.687455     +/- 0.0917262
#    v1.Fe          0.604804     +/- 0.0516178
#    v1.norm        0.000305663  +/- 0.000108368
#    v2.kT          0.916367     +/- 0.0318007
#    v2.norm        0.000494143  +/- 7.59253e-05
#    abs2.nH        0.358623     +/- 0.0285438
#    v3.kT          2.90067      +/- 0.107202
#    v3.norm        0.00104652   +/- 5.57553e-05
