# %% [markdown]
# ## Procedure
#
# - Where in my system is the SAS software?
# > /Users/woodml/Code/XMM_SAS
# - Where in my system are the Calibration files?
# > /Users/woodml/Observing/XMM-Newton/Calibration
# - Where is the XMM-Newton Observation data that I want to process?
# > /Users/woodml/Observing/XMM-Newton/0101440801
# - Which directory am I going to use to work with SAS?
# > /Users/woodml/Observing/XMM-Newton/0101440801

# %% [markdown]
# ## Initialization
#
# Make sure you have run the script \Users\woodml\Observing\XMM-Newton\initialize_sas.bash

# %%
import sys, os
module_path = '/Users/woodml/Code/XMM_SAS/xmmsas_20230412_1735/lib/python' # or the path to your source code
sys.path.insert(0, module_path)
# %env SAS_PATH=/Users/woodml/Code/XMM_SAS/xmmsas_20230412_1735

from pysas.wrapper import Wrapper as wrap
# Out:
# env: SAS_PATH=/Users/woodml/Code/XMM_SAS/xmmsas_20230412_1735

# %%
wrap('sasver', []).run()
# Out:
#     XMM-Newton SAS - release and build information
#
#     SAS release: xmmsas_20230412_1735-21.0.0
#     Compiled on: Sun Apr 16 21:00:41 CEST 2023
#     Compiled by: sasbuild@xmmm23.iuser.lan
#     Platform   : macOS-12.6
#
#     SAS-related environment variables set:
#
#
# SAS_DIR        = /Users/woodml/Code/XMM_SAS/xmmsas_20230412_1735
# SAS_PATH       = /Users/woodml/Code/XMM_SAS/xmmsas_20230412_1735
# SAS_CCFPATH    = /Users/woodml/Observing/XMM-Newton/Calibration

# %% [markdown]
# <h3><tt>starsas</tt> parameters</h3>
# &nbsp;
# <p style="text-align: justify;">As mentioned above, <a href="https://xmm-tools.cosmos.esa.int/external/sas/current/doc/startsas/index.html"><tt>startsas</tt></a>, is aimed at providing these three steps just described in an easy way. To start with, we can get a list of the parameters available for this task by means of the options <tt>-h</tt> or <tt>-p</tt>.</p>

# %%
inargs=['-h']

# %%
wrap('startsas', inargs).run()
# Out:
#         Usage: startsas [Options] param0=value0 [param1=value1] ...
#
#         Options:
#         -a | --ccfpath <dir1>:<dir2>...   Sets SAS_CCFPATH to <dir1>:<dir2>...
#         -c | --noclobber                  Set SAS_CLOBBER=0
#         -d | --dialog                     Launchs task GUI
#         -f | --ccffiles <f1> <f2> ...     CCF files
#         -h | --help                       Shows this message, display param file contents and exits
#         -i | --ccf <cif>                  Sets SAS_CCF=<cif> (ccf.cif)
#         -m | --manpage                    Opens web browser with task documentation
#         -o | --odf <sumfile>              Sets SAS_ODF to SAS summary file
#         -p | --param                      List of all available task parameters with default values
#         -t | --trace                      Trace task execution
#         -V | --verbosity <level>          Sets verbosity level and sets SAS_VERBOSITY
#         -v | --version                    Shows task name and version, and exits
#         -w | --warning [code|n]           Set warning code to [code|n]
#
#         Parameters:
#         param0=value0                     A mandatory parameter. If not present, exits.
#         [param1=value1]                   An optional parameter. If not present, it might have a default value
#         ...
#
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                       name                       |   mandatory   |   type   |           default            |                   description                    |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                      odfid                       |      no       |  string  |                              |            ODF identification number             |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                     workdir                      |      no       |  string  |             pwd              | Allows to set the working directory different to |
# |                                                  |               |          |                              |                  start directory                 |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                     sasfiles                     |      no       |   bool   |              no              |   Allow to set sas_ccf and sas_odf parameters    |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                     sas_ccf                      |      yes      |  string  |                              |   Full path to an existent CIF file (ccf.cif)    |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                     sas_odf                      |      yes      |  string  |                              | Full path to an existent SAS summary file (*SUM. |
# |                                                  |               |          |                              |                       SAS)                       |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                      level                       |      no       |  string  |             ODF              | Level of products to be downloaded using astroqu |
# |                                                  |               |          |                              |                 ery: ODF or PPS.                 |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                  cifbuild_opts                   |      no       |  string  |                              |   Optional parameters to be passed to cifbuild   |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# |                  odfingest_opts                  |      no       |  string  |                              |  Optional parameters to be passed to odfingest   |
# +--------------------------------------------------+---------------+----------+------------------------------+--------------------------------------------------+
# /Users/woodml/anaconda3/envs/Observing/lib/python3.10/site-packages/beautifultable/utils.py:125: FutureWarning: 'BeautifulTable.column_headers' has been deprecated in 'v1.0.0' and will be removed in 'v1.2.0'. Use 'BTColumnCollection.header' instead.
#   warnings.warn(message, FutureWarning)
# /Users/woodml/anaconda3/envs/Observing/lib/python3.10/site-packages/beautifultable/utils.py:125: FutureWarning: 'BeautifulTable.column_widths' has been deprecated in 'v1.0.0' and will be removed in 'v1.2.0'. Use 'BTColumnCollection.width' instead.
#   warnings.warn(message, FutureWarning)
# /Users/woodml/anaconda3/envs/Observing/lib/python3.10/site-packages/beautifultable/utils.py:125: FutureWarning: 'BeautifulTable.max_table_width' has been deprecated in 'v1.0.0' and will be removed in 'v1.2.0'. Use 'BeautifulTable.maxwidth' instead.
#   warnings.warn(message, FutureWarning)
# /Users/woodml/anaconda3/envs/Observing/lib/python3.10/site-packages/beautifultable/utils.py:125: FutureWarning: 'BeautifulTable.append_row' has been deprecated in 'v1.0.0' and will be removed in 'v1.2.0'. Use 'BTRowCollection.append' instead.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# <p style="text-align: justify;">Column <tt>name</tt> lists the parameter names, column <tt>mandatory</tt> shows whether the parameter is optional or mandatory, column <tt>type</tt> shows the type of the parameter (boolean, integer, real, etc), column <tt>default</tt> shows whether the parameter has a default value or not, and finally, column <tt>description</tt> provides a short description of the parameter.</p>

# %% [markdown]
# <h3>Executing startsas</h3>
# &nbsp;
#
# <p style="text-align: justify;">We will show three modes of execution of <a href="https://xmm-tools.cosmos.esa.int/external/sas/current/doc/startsas/index.html"><tt>startsas</tt></a>:</p>
#
# <ol>
# <li>Using the parameter <tt>odfid</tt></li>
# <li>Using the parameters <tt>sas_ccf</tt> and <tt>sas_odf</tt></li>
# <li>Using the parameter <tt>odfid</tt> with <tt>level=PPS</tt></li>
# </ol>

# %% [markdown]
# <h4>With parameter <tt>odfid</tt></h4>
# &nbsp;
#
# <p style="text-align: justify;">The first mode is possibly the most general usage of the task, where <a href="https://xmm-tools.cosmos.esa.int/external/sas/current/doc/startsas/index.html"><tt>startsas</tt></a> is asked to download the ODF identified by <tt>odfid</tt>, into the <tt>Working directory</tt>, identified by <tt>workdir</tt>. Once downloaded, the task unpacks the file into a subdirectory with the name of the ODF identifier and runs immediately after, the tasks <a href="https://xmm-tools.cosmos.esa.int/external/sas/current/doc/cifbuild/index.html"><tt>cifbuild</tt></a> and <a href="https://xmm-tools.cosmos.esa.int/external/sas/current/doc/odfingest/index.html"><tt>odfingest</tt></a> (without parameters). This will provide the CIF file (<tt>ccf.cif</tt>) and the Summary file (<tt>*SUM.SAS</tt>), both in the <tt>Working directory</tt>. Besides this, the environment variables <tt>SAS_CCF</tt> and <tt>SAS_ODF</tt> are set to point to those files, respectively.</p>
#
# <p style="text-align: justify;">Assuming that we want to work on ODF <tt>0104860501</tt>, let us define the input parameters for <a href="https://xmm-tools.cosmos.esa.int/external/sas/current/doc/startsas/index.html"><tt>startsas</tt></a> as,</p>
# <br>
# <i><u>Note:</u> <tt>work_dir</tt> should be the absolute path to the <tt>Working directory</tt> and finished with '/'.</i>

# %%
work_dir = '/Users/woodml/Observing/XMM-Newton/AB_Aur/'

# %%
inargs = [f'odfid=0101440801', 'level=ODF',f'workdir={work_dir}']

# %% [markdown]
# <p style="text-align: justify;">Now, we execute <a href="https://xmm-tools.cosmos.esa.int/external/sas/current/doc/startsas/index.html"><tt>startsas</tt></a> as described earlier. Any log information produced by the SAS tasks will appear in the terminal used to <i>initialize</i> SAS and start this notebook.</p>

# %%
wrap('startsas', inargs).run()
# Out:
# startsas - WARNING - Executing /Users/woodml/Code/XMM_SAS/xmmsas_20230412_1735/lib/python/pysas/startsas/startsas.py {'odfid': '0101440801', 'workdir': '/Users/woodml/Observing/XMM-Newton/AB_Aur/', 'sasfiles': 'no', 'sas_ccf': '', 'sas_odf': '', 'level': 'ODF', 'cifbuild_opts': '', 'odfingest_opts': ''}
#         Starting SAS session
#
#         Working directory = /Users/woodml/Observing/XMM-Newton/AB_Aur/
#
#
# Requesting odfid  = 0101440801 to XMM-Newton Science Archive
#
#
# Downloading 0101440801, level ODF. Please wait ...
# 0327_0101440801_SCX00000RAS.ASC: truncated gzip inputstartsas - ERROR - tar file extraction failed
# INFO: Found cached file 0101440801.tar.gz. [astroquery.query]
#
#
# Removing existing directory 0101440801 ...
#
# Creating directory 0101440801 ...
#
# Unpacking 0101440801.tar.gz ...
# tar: Error exit delayed from previous errors.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 wrap('startsas', inargs).run()
#
# File ~/Code/XMM_SAS/xmmsas_20230412_1735/lib/python/pysas/wrapper.py:49, in Wrapper.run(self)
#      47 t.readparfile()
#      48 t.processargs()
# ---> 49 t.runtask()
#
# File ~/Code/XMM_SAS/xmmsas_20230412_1735/lib/python/pysas/sastask.py:329, in MyTask.runtask(self)
#     327     return self.Exit
#     328 r = RunTask(self.taskname, self.iparsdic,self.logFile)
# --> 329 r.run()
#
# File ~/Code/XMM_SAS/xmmsas_20230412_1735/lib/python/pysas/runtask.py:94, in RunTask.run(self)
#      90 if self.taskname in pysaspkgs:
#      92     m = import_module('pysas.' + self.taskname + '.' + self.taskname)
# ---> 94     m.run(self.iparsdic)
#      96 else:
#      97     cmd = ''
#
# File ~/Code/XMM_SAS/xmmsas_20230412_1735/lib/python/pysas/startsas/startsas.py:241, in run(iparsdic)
#     239 if rc.returncode != 0:
#     240     logger.log('error', 'tar file extraction failed')
# --> 241     raise Exception('tar file extraction failed')
#     242 else:
#     243     logger.log('info', f'{tarfile} extracted successfully!')
#
# Exception: tar file extraction failed

# %% [markdown]
# <p style="text-align: justify;"><b>The process ends with both variables, <tt>SAS_CCF</tt> and <tt>SAS_ODF</tt> defined, both respectively pointing to the <tt>CIF</tt> and Summary Files.</b></p>
#
# <p style="text-align: justify;"><b>From that point onwards we can start running specific SAS commands to obtain the observation event files.</b></p>

# %% [markdown]
# <p style="text-align: justify;">This process has downloaded the ODF into the <tt>Working directory</tt> as defined by the input parameter <tt>workdir</tt> and has run <a href="https://xmm-tools.cosmos.esa.int/external/sas/current/doc/cifbuild/index.html" target="_parent"><tt>cifbuild</tt></a> and <a href="https://xmm-tools.cosmos.esa.int/external/sas/current/doc/odfingest/index.html" target="_parent"><tt>odfingest</tt></a>. <tt>workdir</tt> has to be defined with an absolute path in the call to <a href="https://xmm-tools.cosmos.esa.int/external/sas/current/doc/startsas/index.html" target="_parent"><tt>startsas</tt></a>. In the <tt>Working directory</tt> a new directory with the identifier of the ODF will be created, and all the ODF constituents will be contained inside. The outputs of running <a href="https://xmm-tools.cosmos.esa.int/external/sas/current/doc/cifbuild/index.html" target="_parent"><tt>cifbuild</tt></a> and <a href="https://xmm-tools.cosmos.esa.int/external/sas/current/doc/odfingest/index.html" target="_parent"><tt>odfingest</tt></a> will be placed directly under the <tt>Working directory</tt>.</p>

# %% [markdown]
# <h2>How to continue from here?</h2>
# &nbsp;
#
# <p style="text-align: justify;">This depends on the type of products you have requested.</p>
#
# <p style="text-align: justify;">If you requested the Pipeline products (<tt>level=PPS</tt>), your may begin exploring these products directly. Among them, you will find the Observation Event Files for the different instruments and a lot of information ready to be used.</p>
#
# <p style="text-align: justify;">If you simply requested the ODF (<tt>level=ODF</tt>), the first step is to run the proper SAS tasks to get the Observation Event Files for each instrument. Then, you may have alook to other Threads to get familiar with specific processing tasks for each instrument.</p>
#
# <p style="text-align: justify;">In the next cells we show how to run from here four typical SAS tasks, three `procs` and one `chain` to process exposures taken with the EPIC PN and MOS instruments, RGS and OM.</p>
#
# <p style="text-align: justify;">Given that the execution of these tasks produces a lot of output, we have not run them within the notebook.</p>
#
# <p style="text-align: justify;">We leave this up to you!</p>

# %%
# %env SAS_ODF = /Users/woodml/Observing/XMM-Newton/AB_Aur/0101440801/0327_0101440801_SCX00000SUM.SAS
# %env SAS_CCF = /Users/woodml/Observing/XMM-Newton/AB_Aur/0101440801/ccf.cif
work_dir = '/Users/woodml/Observing/XMM-Newton/AB_Aur/0101440801'
# Out:
# env: SAS_ODF=/Users/woodml/Observing/XMM-Newton/AB_Aur/0101440801/0327_0101440801_SCX00000SUM.SAS
# env: SAS_CCF=/Users/woodml/Observing/XMM-Newton/AB_Aur/0101440801/ccf.cif

# %% [markdown]
# # Process EPIC-PN

# %% [markdown]
# This dataset has no image from EPIC-PN, so I am skipping this step.

# %% [markdown]
# # Process EPIC MOS

# %%
# SAS Command
cmd    = 'emproc'  # SAS task to be executed

# Arguments of SAS Command
inargs = []        # comma separated arguments for SAS task

print("   SAS command to be executed: "+cmd+", with arguments; \n")
inargs
# Out:
#    SAS command to be executed: emproc, with arguments;
# []

# %%
wrap(cmd,inargs).run()      # <<<<< Execute SAS task
exists = 0 
m1evt_list = []
m2evt_list = []
for root, dirs, files in os.walk("."):  
    for filename in files:
        if (filename.find('EMOS1') != -1) and filename.endswith('ImagingEvts.ds'):
            m1evt_list.append(filename)
            exists = 1 
        if (filename.find('EMOS2') != -1) and filename.endswith('ImagingEvts.ds'):
            m2evt_list.append(filename)
            exists = 1            
if exists:    
    print(" > " + str(len(m1evt_list)) + " EPIC-MOS1 event list found. Not running emproc again.\n")
    for x in m1evt_list:
        print("    " + x + "\n")
    print(" > " + str(len(m2evt_list)) + " EPIC-MOS2 event list found. Not running emproc again.\n")
    for x in m2evt_list:
        print("    " + x + "\n")
    print("..... OK")
else:
    print("Something has gone wrong with emproc. I cant find any event list file. \n")
# Out:
# Executing:
# emproc selectinstruments='no' emos1='no' emos2='no' removetemporaries='yes' removeintermediategtis='yes' removeintermediateeventlists='yes' withinstexpids='no' instexpids='M1S001 M2S001' selectccds='no' ccd1='no' ccd2='no' ccd3='no' ccd4='no' ccd5='no' ccd6='no' ccd7='no' selectmodes='yes' imaging='yes' rimaging='yes' timing='yes' ctiming='no' withgtiset='no' gtiset='gti.ds' runhkgtigen='yes' runatthkgen='yes' referencepointing='median' ra='0' dec='0' posangle='0' filterevents='yes' filterexpression='(FLAG & 0x762aa000) == 0' flagfilteredevents='no' rungtimerge='no' applygti='yes' runevlistcomb='yes' searchforbadpixels='yes' badpixfindalgo='embadpixfind' searchforbadcolumns='yes' withbadpixgti='no' badpixgti='bapixgti.ds' thresholdlabel='rate' lothresh='0' hithresh='0.005' columnsearchlabel='median' locolthresh='0' hicolthresh='0.002' flickertimesteps='1' flickerksthresh='0.55' flickerchisqthresh='15' backgroundrate='-1' narrowerthanpsf='3' threshabovebackground='no' loenergythresh='0' hienergythresh='30' useccfdarkframe='no' randomizeenergy='yes' correctgain='yes' correctcti='yes' ontimepha='no' keepsifluor='no' randomizeposition='yes' rejectrows='yes' maxeventsperrow='4' randomizetime='yes' withsrccoords='no' srcra='0' srcdec='0' withparameters='no' parameters='' except='no' withoverrideparameters='no' overrideparameters='' analyzingSciSimdata='no' findlowener='yes' timebin='52.0'
# emproc:- Executing (routine): emproc selectinstruments=no emos1=no emos2=no removetemporaries=yes removeintermediategtis=yes removeintermediateeventlists=yes withinstexpids=no instexpids='M1S001 M2S001' selectccds=no ccd1=no ccd2=no ccd3=no ccd4=no ccd5=no ccd6=no ccd7=no selectmodes=yes imaging=yes rimaging=yes timing=yes ctiming=no withgtiset=no gtiset=gti.ds runhkgtigen=yes runatthkgen=yes referencepointing=median ra=0 dec=0 posangle=0 filterevents=yes filterexpression='(FLAG & 0x762aa000) == 0' flagfilteredevents=no rungtimerge=no applygti=yes runevlistcomb=yes searchforbadpixels=yes badpixfindalgo=embadpixfind searchforbadcolumns=yes withbadpixgti=no badpixgti=bapixgti.ds thresholdlabel=rate lothresh=0 hithresh=0.005 columnsearchlabel=median locolthresh=0 hicolthresh=0.002 flickertimesteps=1 flickerksthresh=0.55 flickerchisqthresh=15 backgroundrate=-1 narrowerthanpsf=3 threshabovebackground=no loenergythresh=0 hienergythresh=30 useccfdarkframe=no randomizeenergy=yes correctgain=yes correctcti=yes ontimepha=no keepsifluor=no randomizeposition=yes rejectrows=yes maxeventsperrow=4 randomizetime=yes withsrccoords=no srcra=0 srcdec=0 withparameters=no parameters='' except=no withoverrideparameters=no overrideparameters='' analyzingSciSimdata=no findlowener=yes timebin=52  -w 1 -V 4
# emproc:- emproc (epicproc-2.25.3)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:17.000
# emproc:- Processing data for instrument 4 [EMOS1]
# emproc:- Selected data mode: 0 [Imaging]
# emproc:- Selected data mode: 2 [ReducedImaging]
# emproc:- Selected data mode: 1 [Timing]
# emproc:- Selected CCD: 1
# emproc:- Selected CCD: 2
# emproc:- Selected CCD: 3
# emproc:- Selected CCD: 4
# emproc:- Selected CCD: 5
# emproc:- Selected CCD: 6
# emproc:- Selected CCD: 7
# emproc:- 0 [Imaging] -> 1
# emproc:- 2 [ReducedImaging] -> 0
# emproc:- 1 [Timing] -> 0
# emproc:- Considering one of the 1 exposures for mode 0 [Imaging]
# emproc:- Considering exposure M1S001[index=0]
# emproc:- Considering one of the 0 exposures for mode 2 [ReducedImaging]
# emproc:- Considering one of the 0 exposures for mode 1 [Timing]
# emproc:- Selected exposure: 1 mode 0 [Imaging]
# emproc:- Executing (invoked): atthkgen atthkset=.//0327_0101440801_AttHk.ds timestep=1 timebegin=0 timeend=0 withtimeranges=no withpreqgti=no preqgtifile=pointings.fit  -w 1 -V 4
# emproc:- atthkgen (atthkgen-1.22.1)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:17.000
# emproc::atthkgen:- Executing (routine): atthkgen atthkset=.//0327_0101440801_AttHk.ds timestep=1 timebegin=0 timeend=0 withtimeranges=no withpreqgti=no preqgtifile=pointings.fit  -w 1 -V 4
# emproc::atthkgen:- atthkgen (atthkgen-1.22.1)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:18.000
# emproc::atthkgen:-            20 % completed of 1st run (AHF/OM)
# emproc::atthkgen:-            40 % completed of 1st run (AHF/OM)
# emproc::atthkgen:-            60 % completed of 1st run (AHF/OM)
# emproc::atthkgen:-            80 % completed of 1st run (AHF/OM)
# emproc::atthkgen:-          100 % completed of 1st run (AHF/OM)
# emproc::atthkgen:-            20 % completed of 2nd run (PNT)
# emproc::atthkgen:-            40 % completed of 2nd run (PNT)
# emproc::atthkgen:-            60 % completed of 2nd run (PNT)
# emproc::atthkgen:-            80 % completed of 2nd run (PNT)
# emproc::atthkgen:-          100 % completed of 2nd run (PNT)
# emproc::atthkgen:- atthkgen (atthkgen-1.22.1)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:20.000
# emproc:- atthkgen (atthkgen-1.22.1)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:20.000
# emproc:- Executing (invoked): hkgtigen instrument=emos1 gtiset=.//0327_0101440801_EMOS1_HkGti.ds diagfile=STDOUT plotgtis=no diagnosticmode=no withgtiset=yes parameters='' withparameters=no except=no overrideparameters='' overrideparametervalues='' withoverrideparameters=no timecolumn=TIME prefraction=0.5 postfraction=0.5  -w 1 -V 4
# emproc:- hkgtigen (hkgtigen-1.15)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:20.000
# emproc::hkgtigen:- Executing (routine): hkgtigen instrument=emos1 gtiset=.//0327_0101440801_EMOS1_HkGti.ds diagfile=STDOUT plotgtis=no diagnosticmode=no withgtiset=yes parameters='' withparameters=no except=no overrideparameters='' overrideparametervalues='' withoverrideparameters=no timecolumn=TIME prefraction=0.5 postfraction=0.5  -w 1 -V 4
# emproc::hkgtigen:- hkgtigen (hkgtigen-1.15)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:20.000
# emproc::hkgtigen:- hkgtigen (hkgtigen-1.15)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:21.000
# emproc:- hkgtigen (hkgtigen-1.15)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:21.000
# emproc:- Processing S001
# emproc:- Processing data set: /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_M1S00110IME.FIT
# emproc:- Executing (invoked): emframes auxiliaryset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_M1S00100AUX.FIT frameset=.//0327_0101440801_EMOS1_S001_01_FramesTemp.ds newframeset=yes countingset='' withcountingset=no srcra=0 srcdec=0 withsrccoords=no checkframes=yes ingtiset=.//0327_0101440801_EMOS1_HkGti.ds flagbadtimes=yes flagfifooverflow=yes outgtiset=.//0327_0101440801_EMOS1_S001_01_FrmGti.ds writegtiset=yes setgatti=yes odfeventset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_M1S00110IME.FIT outeventset=.//0327_0101440801_EMOS1_S001_01_EvtsFramesTemp.ds neweventset=yes checknvalid=yes setdeadtime=yes withodfeventset=yes  -w 1 -V 4
# emproc:- emframes (emframes-5.11)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:21.000
# emproc::emframes:- Executing (routine): emframes auxiliaryset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_M1S00100AUX.FIT frameset=.//0327_0101440801_EMOS1_S001_01_FramesTemp.ds newframeset=yes countingset='' withcountingset=no srcra=0 srcdec=0 withsrccoords=no checkframes=yes ingtiset=.//0327_0101440801_EMOS1_HkGti.ds flagbadtimes=yes flagfifooverflow=yes outgtiset=.//0327_0101440801_EMOS1_S001_01_FrmGti.ds writegtiset=yes setgatti=yes odfeventset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_M1S00110IME.FIT outeventset=.//0327_0101440801_EMOS1_S001_01_EvtsFramesTemp.ds neweventset=yes checknvalid=yes setdeadtime=yes withodfeventset=yes  -w 1 -V 4
# emproc::emframes:- emframes (emframes-5.11)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:21.000
# emproc::emframes:-  Event file .//0327_0101440801_EMOS1_S001_01_EvtsFramesTemp.ds modified
# emproc::emframes:-          468  missing frames in FRAMES
# emproc::emframes:-          104  extended frames in FRAMES
# emproc::emframes:-  Create .//0327_0101440801_EMOS1_S001_01_FramesTemp.ds with       49724  rows
# emproc::emframes:-  Observing mode was PrimeFullWindow
# emproc::emframes:-  Approximate start time =   117423315.13613188
# emproc::emframes:-  Approximate   end time =   117552869.39439762
# emproc::emframes:-            0  frames rejected by VALID
# emproc::emframes:-           32  frames rejected by FIFO
# emproc::emframes:-  Area of window within field of view is   117.505104      arcmin2
# emproc::emframes:-  Fraction of window within field of view is  0.969705582
# emproc::emframes:-            0  frames rejected by FLAG_HK
# emproc::emframes:-  Fraction of good time :   0.98298141517124149
# emproc::emframes:-  Writing extension STDGTI01
# emproc::emframes:-  Create .//0327_0101440801_EMOS1_S001_01_FrmGti.ds with          45  rows
# emproc::emframes:- emframes (emframes-5.11)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:22.000
# emproc:- emframes (emframes-5.11)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:22.000
# emproc:- Executing (invoked): emevents odfeventset=.//0327_0101440801_EMOS1_S001_01_EvtsFramesTemp.ds eventset=.//0327_0101440801_EMOS1_S001_01_EvtsForBadpixfindTemp.ds newoutput=yes frameset=.//0327_0101440801_EMOS1_S001_01_FramesTemp.ds flagbadtimes=yes gattispecset=gattispec.out writegattispecset=no flagtruncatede1=yes othereventset='' otherframeset='' withothernode=no withframeset=yes offvarsets='' withoffvarsets=no analysepatterns=no flagbadpixels=no keepsifluor=no splitdiagonals=no randomizeposition=no setcoordinates=yes maxeventsperrow=4 widthnexttorow=10 rejectrows=yes detectbadoffsets=yes rejectbade3=yes tolfxy='5 2 2' rejectflickering=yes randomizetime=no settimes=yes blocksize=10000  -w 1 -V 4
# emproc:- emevents (emevents-8.8)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:22.000
# emproc::emevents:- Executing (routine): emevents odfeventset=.//0327_0101440801_EMOS1_S001_01_EvtsFramesTemp.ds eventset=.//0327_0101440801_EMOS1_S001_01_EvtsForBadpixfindTemp.ds newoutput=yes frameset=.//0327_0101440801_EMOS1_S001_01_FramesTemp.ds flagbadtimes=yes gattispecset=gattispec.out writegattispecset=no flagtruncatede1=yes othereventset='' otherframeset='' withothernode=no withframeset=yes offvarsets='' withoffvarsets=no analysepatterns=no flagbadpixels=no keepsifluor=no splitdiagonals=no randomizeposition=no setcoordinates=yes maxeventsperrow=4 widthnexttorow=10 rejectrows=yes detectbadoffsets=yes rejectbade3=yes tolfxy='5 2 2' rejectflickering=yes randomizetime=no settimes=yes blocksize=10000  -w 1 -V 4
# emproc::emevents:- emevents (emevents-8.8)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:22.000
# emproc::emevents:-       366274  events in input
# emproc::emevents:- Getting the offsets from the CAL
# emproc::emevents:-            0  events below the EMDH lower threshold
# emproc::emevents:-            0  events above the EMDH upper threshold
# emproc::emevents:-       366274  events in output
# emproc::emevents:-         7707  events outside good frames
# emproc::emevents:-        80249  cosmic-ray events
# emproc::emevents:-         2872  events outside window
# emproc::emevents:-  maximum number of expected events per row  0.31240606085225658
# emproc::emevents:-       139360  events in rows with more than           4  events above expected.
# emproc::emevents:-         2099  flagged events next to bad rows
# ** emproc::emevents: warning (rejectRows12),  Fraction of rejected frames   1.41771948E-02  exceeds 1% at some rows           3  in .//0327_0101440801_EMOS1_S001_01_EvtsForBadpixfindTemp.ds:EVENTS
# emproc::emevents:-            0  events on row/column with wrong offset
# emproc::emevents:-        71152  events with E3 <         -29  + local median
# emproc::emevents:-  maximum number of expected events per bin  0.341273934
# emproc::emevents:-          139  events detected as flickering at tolerances           5           2           2
# emproc::emevents:-        16884  events with truncated E1
# emproc::emevents:-  Fraction of good events :   0.305459857
# emproc::emevents:- emevents (emevents-8.8)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:23.000
# emproc:- emevents (emevents-8.8)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:23.000
# emproc:- Executing (invoked): emenergy ineventset=.//0327_0101440801_EMOS1_S001_01_EvtsForBadpixfindTemp.ds outeventset=events.out newoutput=no flagevents=yes correctcti=no minenergy=100 maxperipix=0 fillminnumber=10 fillccdbkg=yes backgroundset=bkgccd.map timebin=100 writebackgroundset=no getccdbkg=yes useccfdarkframe=no maskedccdset='' withmaskedccdset=no rejectbade3e4=yes randomizeenergy=no makepha=yes correctgain=no ontimepha=no  -w 1 -V 4
# emproc:- emenergy (emenergy-8.9)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:23.000
# emproc::emenergy:- Executing (routine): emenergy ineventset=.//0327_0101440801_EMOS1_S001_01_EvtsForBadpixfindTemp.ds outeventset=events.out newoutput=no flagevents=yes correctcti=no minenergy=100 maxperipix=0 fillminnumber=10 fillccdbkg=yes backgroundset=bkgccd.map timebin=100 writebackgroundset=no getccdbkg=yes useccfdarkframe=no maskedccdset='' withmaskedccdset=no rejectbade3e4=yes randomizeenergy=no makepha=yes correctgain=no ontimepha=no  -w 1 -V 4
# emproc::emenergy:- emenergy (emenergy-8.9)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:23.000
# emproc::emenergy:-  Input file : .//0327_0101440801_EMOS1_S001_01_EvtsForBadpixfindTemp.ds
# emproc::emenergy:- The input file will be overwritten
# emproc::emenergy:-       366274  events in file
# emproc::emenergy:- EVFLAG will be applied
# emproc::emenergy:-  Bad offsets will be taken from the OFFSETS extension.
# emproc::emenergy:- Energies will be corrected using E4 information
# emproc::emenergy:-  Events with ENERGYE1 >=         100  will be used to build the background map.
# emproc::emenergy:-  Events with PERIPIX <=           0  will be used to build the background map.
# emproc::emenergy:-  Background data will be filled by row and column averaging when less than           10  events around.
# emproc::emenergy:-  no BADPIX extension in input event file. Assume no bad pixel in EVFLAG.
# emproc::emenergy:-        24093  events outside field of view
# emproc::emenergy:-       141434  events outside the ellipse in E3/E1, E4/E1
# emproc::emenergy:-         1751  events rejected by   3.00000000      sigma clipping on E4 for CCDBKG
# emproc::emenergy:-       142424  events outside the ellipse in E3/E1, E4/E1
# emproc::emenergy:-        19373  events with PHA out of range          25  -        4095
# emproc::emenergy:- emenergy (emenergy-8.9)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:24.000
# emproc:- emenergy (emenergy-8.9)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:24.000
# emproc:- Executing (invoked): evselect table=.//0327_0101440801_EMOS1_S001_01_EvtsForBadpixfindTemp.ds:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=yes flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(FLAG & 0x762aa000) == 0' filtertype=expression cleandss=no updateexposure=no filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PHA zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum.fits spectralbinsize=5 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=no rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# emproc:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:24.000
# emproc::evselect:- Executing (routine): evselect table=.//0327_0101440801_EMOS1_S001_01_EvtsForBadpixfindTemp.ds:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=yes flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(FLAG & 0x762aa000) == 0' filtertype=expression cleandss=no updateexposure=no filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PHA zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum.fits spectralbinsize=5 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=no rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# emproc::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:24.000
# ** emproc::evselect: warning (NoCCDcolumn), Event list does not have a CCDNR column. Cannot update exposure information.
# emproc::evselect:- selected 94586 rows from the input table.
# emproc::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:24.000
# emproc:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:24.000
# emproc:- Executing (invoked): emeventsproj eventset=.//0327_0101440801_EMOS1_S001_01_EvtsForBadpixfindTemp.ds evimageset=.//0327_0101440801_EMOS1_S001_EvtsForEmeventsprojTemp.ds rejectbadevents=yes projectenergy=no ccdnr=1 mergedeventlist=no  -w 1 -V 4
# emproc:- emeventsproj (emeventsproj-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:24.000
# emproc::emeventsproj:- Executing (routine): emeventsproj eventset=.//0327_0101440801_EMOS1_S001_01_EvtsForBadpixfindTemp.ds evimageset=.//0327_0101440801_EMOS1_S001_EvtsForEmeventsprojTemp.ds rejectbadevents=yes projectenergy=no ccdnr=1 mergedeventlist=no  -w 1 -V 4
# emproc::emeventsproj:- emeventsproj (emeventsproj-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:25.000
# emproc::emeventsproj:-  Opening input event file : .//0327_0101440801_EMOS1_S001_01_EvtsForBadpixfindTemp.ds
# emproc::emeventsproj:- The counts will be projected.
# emproc::emeventsproj:- Events flagged for rejection will not be projected.
# emproc::emeventsproj:-  Opening output image file : .//0327_0101440801_EMOS1_S001_EvtsForEmeventsprojTemp.ds
# emproc::emeventsproj:-  Number of good events in input file:        94586
# emproc::emeventsproj:- emeventsproj (emeventsproj-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:25.000
# emproc:- emeventsproj (emeventsproj-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:25.000
# emproc:- Executing (invoked): embadpixfind evimageset=.//0327_0101440801_EMOS1_S001_EvtsForEmeventsprojTemp.ds badpixset=.//0327_0101440801_EMOS1_S001_01_Badpixels.ds incremental=no halfwidth2d=2 probathreshold=1e-06 halfwidth1d=3 findbadsegments=yes minratio=1.5 findbright=yes maxratio=0.5 finddead=yes niter=10 includedeadpixels=yes ignoreccfbright=no usecal=yes  -w 1 -V 4
# emproc:- embadpixfind (embadpixfind-2.6.1)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:25.000
# emproc::embadpixfind:- Executing (routine): embadpixfind evimageset=.//0327_0101440801_EMOS1_S001_EvtsForEmeventsprojTemp.ds badpixset=.//0327_0101440801_EMOS1_S001_01_Badpixels.ds incremental=no halfwidth2d=2 probathreshold=1e-06 halfwidth1d=3 findbadsegments=yes minratio=1.5 findbright=yes maxratio=0.5 finddead=yes niter=10 includedeadpixels=yes ignoreccfbright=no usecal=yes  -w 1 -V 4
# emproc::embadpixfind:- embadpixfind (embadpixfind-2.6.1)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:25.000
# emproc::embadpixfind:-  Opening image file : .//0327_0101440801_EMOS1_S001_EvtsForEmeventsprojTemp.ds
# emproc::embadpixfind:-  Half width for 2D searches:           2
# emproc::embadpixfind:-  False detection probability:   9.99999997E-07  per pixel
# emproc::embadpixfind:- The task will also look for bad segments in rows or columns
# emproc::embadpixfind:-  Half width for 1D searches:           3
# emproc::embadpixfind:- The task will look for bright pixels
# emproc::embadpixfind:-  The task will look for bright pixels more than   1.50000000      relative to their neighbours
# emproc::embadpixfind:- The task will look for dark pixels
# emproc::embadpixfind:-  The task will look for dark pixels less than  0.500000000      relative to their neighbours
# emproc::embadpixfind:-  Bad pixels will be written to .//0327_0101440801_EMOS1_S001_01_Badpixels.ds
# emproc::embadpixfind:- Dead pixels from the CAL will be included in the bad pixels list
# ** emproc::embadpixfind: warning (getCalBadpix10),  Bright pixel at         436         436  is declared uplinked in the CCF but is present in the data.
# emproc::embadpixfind:-
# emproc::embadpixfind:-  Iteration           1
# emproc::embadpixfind:-           81  bright pixels found in image
# emproc::embadpixfind:-            0  dark and           3  bright columns found in image
# emproc::embadpixfind:-            0  dark and           2  bright rows found in image
# emproc::embadpixfind:-            0  dark pixels found in image
# emproc::embadpixfind:-
# emproc::embadpixfind:-  Iteration           2
# emproc::embadpixfind:-            0  bright pixels found in image
# emproc::embadpixfind:-            0  dark and           0  bright columns found in image
# emproc::embadpixfind:-            0  dark and           0  bright rows found in image
# emproc::embadpixfind:-            0  dark pixels found in image
# emproc::embadpixfind:-  Writing         700  rows to .//0327_0101440801_EMOS1_S001_01_Badpixels.ds:BADPIX
# emproc::embadpixfind:- embadpixfind (embadpixfind-2.6.1)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:25.000
# ** emproc::embadpixfind: warning (SummaryOfWarnings),
#    warning getCalBadpix10 silently occurred 3 times
# emproc:- embadpixfind (embadpixfind-2.6.1)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:25.000
# emproc:- Processing data set: /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_M1S00120IME.FIT
# emproc:- Executing (invoked): emframes auxiliaryset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_M1S00100AUX.FIT frameset=.//0327_0101440801_EMOS1_S001_02_FramesTemp.ds newframeset=yes countingset='' withcountingset=no srcra=0 srcdec=0 withsrccoords=no checkframes=yes ingtiset=.//0327_0101440801_EMOS1_HkGti.ds flagbadtimes=yes flagfifooverflow=yes outgtiset=.//0327_0101440801_EMOS1_S001_02_FrmGti.ds writegtiset=yes setgatti=yes odfeventset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_M1S00120IME.FIT outeventset=.//0327_0101440801_EMOS1_S001_02_EvtsFramesTemp.ds neweventset=yes checknvalid=yes setdeadtime=yes withodfeventset=yes  -w 1 -V 4
# emproc:- emframes (emframes-5.11)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:25.000
# emproc::emframes:- Executing (routine): emframes auxiliaryset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_M1S00100AUX.FIT frameset=.//0327_0101440801_EMOS1_S001_02_FramesTemp.ds newframeset=yes countingset='' withcountingset=no srcra=0 srcdec=0 withsrccoords=no checkframes=yes ingtiset=.//0327_0101440801_EMOS1_HkGti.ds flagbadtimes=yes flagfifooverflow=yes outgtiset=.//0327_0101440801_EMOS1_S001_02_FrmGti.ds writegtiset=yes setgatti=yes odfeventset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_M1S00120IME.FIT outeventset=.//0327_0101440801_EMOS1_S001_02_EvtsFramesTemp.ds neweventset=yes checknvalid=yes setdeadtime=yes withodfeventset=yes  -w 1 -V 4
# emproc::emframes:- emframes (emframes-5.11)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:26.000
# emproc::emframes:-  Event file .//0327_0101440801_EMOS1_S001_02_EvtsFramesTemp.ds modified
# emproc::emframes:-          490  missing frames in FRAMES
# emproc::emframes:-          367  extended frames in FRAMES
# emproc::emframes:-  Create .//0327_0101440801_EMOS1_S001_02_FramesTemp.ds with       49460  rows
# emproc::emframes:-  Observing mode was PrimeFullWindow
# emproc::emframes:-  Approximate start time =   117423315.14528964
# emproc::emframes:-  Approximate   end time =   117552869.40355539
# emproc::emframes:-            0  frames rejected by VALID
# emproc::emframes:-            0  frames rejected by FIFO
# emproc::emframes:-  Area of window within field of view is   76.9555511      arcmin2
# emproc::emframes:-  Fraction of window within field of view is  0.635072231
# emproc::emframes:-            0  frames rejected by FLAG_HK
# emproc::emframes:-  Fraction of good time :   0.98372703481661872
# emproc::emframes:-  Writing extension STDGTI02
# emproc::emframes:-  Create .//0327_0101440801_EMOS1_S001_02_FrmGti.ds with          16  rows
# emproc::emframes:- emframes (emframes-5.11)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:26.000
# emproc:- emframes (emframes-5.11)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:26.000
# emproc:- Executing (invoked): emevents odfeventset=.//0327_0101440801_EMOS1_S001_02_EvtsFramesTemp.ds eventset=.//0327_0101440801_EMOS1_S001_02_EvtsForBadpixfindTemp.ds newoutput=yes frameset=.//0327_0101440801_EMOS1_S001_02_FramesTemp.ds flagbadtimes=yes gattispecset=gattispec.out writegattispecset=no flagtruncatede1=yes othereventset='' otherframeset='' withothernode=no withframeset=yes offvarsets='' withoffvarsets=no analysepatterns=no flagbadpixels=no keepsifluor=no splitdiagonals=no randomizeposition=no setcoordinates=yes maxeventsperrow=4 widthnexttorow=10 rejectrows=yes detectbadoffsets=yes rejectbade3=yes tolfxy='5 2 2' rejectflickering=yes randomizetime=no settimes=yes blocksize=10000  -w 1 -V 4
# emproc:- emevents (emevents-8.8)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:26.000
# emproc::emevents:- Executing (routine): emevents odfeventset=.//0327_0101440801_EMOS1_S001_02_EvtsFramesTemp.ds eventset=.//0327_0101440801_EMOS1_S001_02_EvtsForBadpixfindTemp.ds newoutput=yes frameset=.//0327_0101440801_EMOS1_S001_02_FramesTemp.ds flagbadtimes=yes gattispecset=gattispec.out writegattispecset=no flagtruncatede1=yes othereventset='' otherframeset='' withothernode=no withframeset=yes offvarsets='' withoffvarsets=no analysepatterns=no flagbadpixels=no keepsifluor=no splitdiagonals=no randomizeposition=no setcoordinates=yes maxeventsperrow=4 widthnexttorow=10 rejectrows=yes detectbadoffsets=yes rejectbade3=yes tolfxy='5 2 2' rejectflickering=yes randomizetime=no settimes=yes blocksize=10000  -w 1 -V 4
# emproc::emevents:- emevents (emevents-8.8)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:27.000
# emproc::emevents:-       164528  events in input
# emproc::emevents:- Getting the offsets from the CAL
# emproc::emevents:-            0  events below the EMDH lower threshold
# emproc::emevents:-            0  events above the EMDH upper threshold
# emproc::emevents:-       164528  events in output
# emproc::emevents:-           15  events outside good frames
# emproc::emevents:-        70582  cosmic-ray events
# emproc::emevents:-         2472  events outside window
# emproc::emevents:-  maximum number of expected events per row   3.2542566657139359E-002
# emproc::emevents:-         2995  events in rows with more than           4  events above expected.
# emproc::emevents:-          255  flagged events next to bad rows
# emproc::emevents:-            0  events on row/column with wrong offset
# emproc::emevents:-          288  events with E3 <         -68  + local median
# emproc::emevents:-  maximum number of expected events per bin   2.89428774E-02
# emproc::emevents:-         6261  events detected as flickering at tolerances           5           2           2
# emproc::emevents:-        18235  events with truncated E1
# emproc::emevents:-  Fraction of good events :   0.387709081
# emproc::emevents:- emevents (emevents-8.8)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:27.000
# emproc:- emevents (emevents-8.8)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:28.000
# emproc:- Executing (invoked): emenergy ineventset=.//0327_0101440801_EMOS1_S001_02_EvtsForBadpixfindTemp.ds outeventset=events.out newoutput=no flagevents=yes correctcti=no minenergy=100 maxperipix=0 fillminnumber=10 fillccdbkg=yes backgroundset=bkgccd.map timebin=100 writebackgroundset=no getccdbkg=yes useccfdarkframe=no maskedccdset='' withmaskedccdset=no rejectbade3e4=yes randomizeenergy=no makepha=yes correctgain=no ontimepha=no  -w 1 -V 4
# emproc:- emenergy (emenergy-8.9)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:28.000
# emproc::emenergy:- Executing (routine): emenergy ineventset=.//0327_0101440801_EMOS1_S001_02_EvtsForBadpixfindTemp.ds outeventset=events.out newoutput=no flagevents=yes correctcti=no minenergy=100 maxperipix=0 fillminnumber=10 fillccdbkg=yes backgroundset=bkgccd.map timebin=100 writebackgroundset=no getccdbkg=yes useccfdarkframe=no maskedccdset='' withmaskedccdset=no rejectbade3e4=yes randomizeenergy=no makepha=yes correctgain=no ontimepha=no  -w 1 -V 4
# emproc::emenergy:- emenergy (emenergy-8.9)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:28.000
# emproc::emenergy:-  Input file : .//0327_0101440801_EMOS1_S001_02_EvtsForBadpixfindTemp.ds
# emproc::emenergy:- The input file will be overwritten
# emproc::emenergy:-       164528  events in file
# emproc::emenergy:- EVFLAG will be applied
# emproc::emenergy:-  Bad offsets will be taken from the OFFSETS extension.
# emproc::emenergy:- Energies will be corrected using E4 information
# emproc::emenergy:-  Events with ENERGYE1 >=         100  will be used to build the background map.
# emproc::emenergy:-  Events with PERIPIX <=           0  will be used to build the background map.
# emproc::emenergy:-  Background data will be filled by row and column averaging when less than           10  events around.
# emproc::emenergy:-  no BADPIX extension in input event file. Assume no bad pixel in EVFLAG.
# emproc::emenergy:-        54773  events outside field of view
# emproc::emenergy:-        34197  events outside the ellipse in E3/E1, E4/E1
# emproc::emenergy:-          816  events rejected by   3.00000000      sigma clipping on E4 for CCDBKG
# emproc::emenergy:-        34129  events outside the ellipse in E3/E1, E4/E1
# emproc::emenergy:-        13018  events with PHA out of range          25  -        4095
# emproc::emenergy:- emenergy (emenergy-8.9)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:28.000
# emproc:- emenergy (emenergy-8.9)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:28.000
# emproc:- Executing (invoked): evselect table=.//0327_0101440801_EMOS1_S001_02_EvtsForBadpixfindTemp.ds:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=yes flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(FLAG & 0x762aa000) == 0' filtertype=expression cleandss=no updateexposure=no filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PHA zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum.fits spectralbinsize=5 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=no rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# emproc:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:28.000
# emproc::evselect:- Executing (routine): evselect table=.//0327_0101440801_EMOS1_S001_02_EvtsForBadpixfindTemp.ds:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=yes flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(FLAG & 0x762aa000) == 0' filtertype=expression cleandss=no updateexposure=no filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PHA zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum.fits spectralbinsize=5 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=no rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# emproc::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:28.000
# ** emproc::evselect: warning (NoCCDcolumn), Event list does not have a CCDNR column. Cannot update exposure information.
# emproc::evselect:- selected 57094 rows from the input table.
# emproc::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:29.000
# emproc:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:29.000
# emproc:- Executing (invoked): emeventsproj eventset=.//0327_0101440801_EMOS1_S001_02_EvtsForBadpixfindTemp.ds evimageset=.//0327_0101440801_EMOS1_S001_EvtsForEmeventsprojTemp.ds rejectbadevents=yes projectenergy=no ccdnr=1 mergedeventlist=no  -w 1 -V 4
# emproc:- emeventsproj (emeventsproj-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:29.000
# emproc::emeventsproj:- Executing (routine): emeventsproj eventset=.//0327_0101440801_EMOS1_S001_02_EvtsForBadpixfindTemp.ds evimageset=.//0327_0101440801_EMOS1_S001_EvtsForEmeventsprojTemp.ds rejectbadevents=yes projectenergy=no ccdnr=1 mergedeventlist=no  -w 1 -V 4
# emproc::emeventsproj:- emeventsproj (emeventsproj-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:29.000
# emproc::emeventsproj:-  Opening input event file : .//0327_0101440801_EMOS1_S001_02_EvtsForBadpixfindTemp.ds
# emproc::emeventsproj:- The counts will be projected.
# emproc::emeventsproj:- Events flagged for rejection will not be projected.
# emproc::emeventsproj:-  Opening output image file : .//0327_0101440801_EMOS1_S001_EvtsForEmeventsprojTemp.ds
# emproc::emeventsproj:-  Number of good events in input file:        57094
# emproc::emeventsproj:- emeventsproj (emeventsproj-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:29.000
# emproc:- emeventsproj (emeventsproj-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:29.000
# emproc:- Executing (invoked): embadpixfind evimageset=.//0327_0101440801_EMOS1_S001_EvtsForEmeventsprojTemp.ds badpixset=.//0327_0101440801_EMOS1_S001_02_Badpixels.ds incremental=no halfwidth2d=2 probathreshold=1e-06 halfwidth1d=3 findbadsegments=yes minratio=1.5 findbright=yes maxratio=0.5 finddead=yes niter=10 includedeadpixels=yes ignoreccfbright=no usecal=yes  -w 1 -V 4
# emproc:- embadpixfind (embadpixfind-2.6.1)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:29.000
# emproc::embadpixfind:- Executing (routine): embadpixfind evimageset=.//0327_0101440801_EMOS1_S001_EvtsForEmeventsprojTemp.ds badpixset=.//0327_0101440801_EMOS1_S001_02_Badpixels.ds incremental=no halfwidth2d=2 probathreshold=1e-06 halfwidth1d=3 findbadsegments=yes minratio=1.5 findbright=yes maxratio=0.5 finddead=yes niter=10 includedeadpixels=yes ignoreccfbright=no usecal=yes  -w 1 -V 4
# emproc::embadpixfind:- embadpixfind (embadpixfind-2.6.1)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:29.000
# emproc::embadpixfind:-  Opening image file : .//0327_0101440801_EMOS1_S001_EvtsForEmeventsprojTemp.ds
# emproc::embadpixfind:-  Half width for 2D searches:           2
# emproc::embadpixfind:-  False detection probability:   9.99999997E-07  per pixel
# emproc::embadpixfind:- The task will also look for bad segments in rows or columns
# emproc::embadpixfind:-  Half width for 1D searches:           3
# emproc::embadpixfind:- The task will look for bright pixels
# emproc::embadpixfind:-  The task will look for bright pixels more than   1.50000000      relative to their neighbours
# emproc::embadpixfind:- The task will look for dark pixels
# emproc::embadpixfind:-  The task will look for dark pixels less than  0.500000000      relative to their neighbours
# emproc::embadpixfind:-  Bad pixels will be written to .//0327_0101440801_EMOS1_S001_02_Badpixels.ds
# emproc::embadpixfind:- Dead pixels from the CAL will be included in the bad pixels list
# emproc::embadpixfind:-
# emproc::embadpixfind:-  Iteration           1
# emproc::embadpixfind:-           81  bright pixels found in image
# emproc::embadpixfind:-            0  dark and           3  bright columns found in image
# emproc::embadpixfind:-            0  dark and           2  bright rows found in image
# emproc::embadpixfind:-            0  dark pixels found in image
# emproc::embadpixfind:-
# emproc::embadpixfind:-  Iteration           2
# emproc::embadpixfind:-            1  bright pixels found in image
# emproc::embadpixfind:-            0  dark and           0  bright columns found in image
# emproc::embadpixfind:-            0  dark and           0  bright rows found in image
# emproc::embadpixfind:-            0  dark pixels found in image
# emproc::embadpixfind:-  Writing         681  rows to .//0327_0101440801_EMOS1_S001_02_Badpixels.ds:BADPIX
# emproc::embadpixfind:- embadpixfind (embadpixfind-2.6.1)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:30.000
# emproc:- embadpixfind (embadpixfind-2.6.1)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:30.000
# emproc:- Processing data set: /Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_M1S00130IME.FIT
# emproc:- Executing (invoked): emframes auxiliaryset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_M1S00100AUX.FIT frameset=.//0327_0101440801_EMOS1_S001_03_FramesTemp.ds newframeset=yes countingset='' withcountingset=no srcra=0 srcdec=0 withsrccoords=no checkframes=yes ingtiset=.//0327_0101440801_EMOS1_HkGti.ds flagbadtimes=yes flagfifooverflow=yes outgtiset=.//0327_0101440801_EMOS1_S001_03_FrmGti.ds writegtiset=yes setgatti=yes odfeventset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_M1S00130IME.FIT outeventset=.//0327_0101440801_EMOS1_S001_03_EvtsFramesTemp.ds neweventset=yes checknvalid=yes setdeadtime=yes withodfeventset=yes  -w 1 -V 4
# emproc:- emframes (emframes-5.11)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:30.000
# emproc::emframes:- Executing (routine): emframes auxiliaryset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_M1S00100AUX.FIT frameset=.//0327_0101440801_EMOS1_S001_03_FramesTemp.ds newframeset=yes countingset='' withcountingset=no srcra=0 srcdec=0 withsrccoords=no checkframes=yes ingtiset=.//0327_0101440801_EMOS1_HkGti.ds flagbadtimes=yes flagfifooverflow=yes outgtiset=.//0327_0101440801_EMOS1_S001_03_FrmGti.ds writegtiset=yes setgatti=yes odfeventset=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_M1S00130IME.FIT outeventset=.//0327_0101440801_EMOS1_S001_03_EvtsFramesTemp.ds neweventset=yes checknvalid=yes setdeadtime=yes withodfeventset=yes  -w 1 -V 4
# emproc::emframes:- emframes (emframes-5.11)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:30.000
# emproc::emframes:-  Event file .//0327_0101440801_EMOS1_S001_03_EvtsFramesTemp.ds modified
# emproc::emframes:-          500  missing frames in FRAMES
# emproc::emframes:-           29  extended frames in FRAMES
# emproc::emframes:-  Create .//0327_0101440801_EMOS1_S001_03_FramesTemp.ds with       49796  rows
# emproc::emframes:-  Observing mode was PrimeFullWindow
# emproc::emframes:-  Approximate start time =   117423315.16364518
# emproc::emframes:-  Approximate   end time =   117552861.62189692
# emproc::emframes:-            0  frames rejected by VALID
# emproc::emframes:-            0  frames rejected by FIFO
# emproc::emframes:-  Area of window within field of view is   92.8787613      arcmin2
# emproc::emframes:-  Fraction of window within field of view is  0.766477764
# emproc::emframes:-            0  frames rejected by FLAG_HK
# emproc::emframes:-  Fraction of good time :   0.98383095552679423
# emproc::emframes:-  Writing extension STDGTI03
# emproc::emframes:-  Create .//0327_0101440801_EMOS1_S001_03_FrmGti.ds with          16  rows
# emproc::emframes:- emframes (emframes-5.11)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:31.000
# emproc:- emframes (emframes-5.11)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:31.000
# emproc:- Executing (invoked): emevents odfeventset=.//0327_0101440801_EMOS1_S001_03_EvtsFramesTemp.ds eventset=.//0327_0101440801_EMOS1_S001_03_EvtsForBadpixfindTemp.ds newoutput=yes frameset=.//0327_0101440801_EMOS1_S001_03_FramesTemp.ds flagbadtimes=yes gattispecset=gattispec.out writegattispecset=no flagtruncatede1=yes othereventset='' otherframeset='' withothernode=no withframeset=yes offvarsets='' withoffvarsets=no analysepatterns=no flagbadpixels=no keepsifluor=no splitdiagonals=no randomizeposition=no setcoordinates=yes maxeventsperrow=4 widthnexttorow=10 rejectrows=yes detectbadoffsets=yes rejectbade3=yes tolfxy='5 2 2' rejectflickering=yes randomizetime=no settimes=yes blocksize=10000  -w 1 -V 4
# emproc:- emevents (emevents-8.8)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:31.000
# emproc::emevents:- Executing (routine): emevents odfeventset=.//0327_0101440801_EMOS1_S001_03_EvtsFramesTemp.ds eventset=.//0327_0101440801_EMOS1_S001_03_EvtsForBadpixfindTemp.ds newoutput=yes frameset=.//0327_0101440801_EMOS1_S001_03_FramesTemp.ds flagbadtimes=yes gattispecset=gattispec.out writegattispecset=no flagtruncatede1=yes othereventset='' otherframeset='' withothernode=no withframeset=yes offvarsets='' withoffvarsets=no analysepatterns=no flagbadpixels=no keepsifluor=no splitdiagonals=no randomizeposition=no setcoordinates=yes maxeventsperrow=4 widthnexttorow=10 rejectrows=yes detectbadoffsets=yes rejectbade3=yes tolfxy='5 2 2' rejectflickering=yes randomizetime=no settimes=yes blocksize=10000  -w 1 -V 4
# emproc::emevents:- emevents (emevents-8.8)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:31.000
# emproc::emevents:-       214944  events in input
# emproc::emevents:- Getting the offsets from the CAL
# emproc::emevents:-            0  events below the EMDH lower threshold
# emproc::emevents:-            0  events above the EMDH upper threshold
# emproc::emevents:-       214944  events in output
# emproc::emevents:-           16  events outside good frames
# emproc::emevents:-        73165  cosmic-ray events
# emproc::emevents:-         2259  events outside window
# emproc::emevents:-  maximum number of expected events per row  0.99182688407560637
# emproc::emevents:-           53  events in rows with more than           4  events above expected.
# emproc::emevents:-           12  flagged events next to bad rows
# emproc::emevents:-            0  events on row/column with wrong offset
# emproc::emevents:-          157  events with E3 <         -40  + local median
# emproc::emevents:-  maximum number of expected events per bin   3.92369914
# emproc::emevents:-           78  events detected as flickering at tolerances           5           2           2
# emproc::emevents:-        17285  events with truncated E1
# emproc::emevents:-  Fraction of good events :   0.567357063
# emproc::emevents:- emevents (emevents-8.8)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:32.000
# emproc:- emevents (emevents-8.8)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:32.000
# emproc:- Executing (invoked): emenergy ineventset=.//0327_0101440801_EMOS1_S001_03_EvtsForBadpixfindTemp.ds outeventset=events.out newoutput=no flagevents=yes correctcti=no minenergy=100 maxperipix=0 fillminnumber=10 fillccdbkg=yes backgroundset=bkgccd.map timebin=100 writebackgroundset=no getccdbkg=yes useccfdarkframe=no maskedccdset='' withmaskedccdset=no rejectbade3e4=yes randomizeenergy=no makepha=yes correctgain=no ontimepha=no  -w 1 -V 4
# emproc:- emenergy (emenergy-8.9)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:32.000
# emproc::emenergy:- Executing (routine): emenergy ineventset=.//0327_0101440801_EMOS1_S001_03_EvtsForBadpixfindTemp.ds outeventset=events.out newoutput=no flagevents=yes correctcti=no minenergy=100 maxperipix=0 fillminnumber=10 fillccdbkg=yes backgroundset=bkgccd.map timebin=100 writebackgroundset=no getccdbkg=yes useccfdarkframe=no maskedccdset='' withmaskedccdset=no rejectbade3e4=yes randomizeenergy=no makepha=yes correctgain=no ontimepha=no  -w 1 -V 4
# emproc::emenergy:- emenergy (emenergy-8.9)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:12:32.000
# emproc::emenergy:-  Input file : .//0327_0101440801_EMOS1_S001_03_EvtsForBadpixfindTemp.ds
# emproc::emenergy:- The input file will be overwritten
# emproc::emenergy:-       214944  events in file
# emproc::emenergy:- EVFLAG will be applied
# emproc::emenergy:-  Bad offsets will be taken from the OFFSETS extension.
# emproc::emenergy:- Energies will be corrected using E4 information
# emproc::emenergy:-  Events with ENERGYE1 >=         100  will be used to build the background map.
# emproc::emenergy:-  Events with PERIPIX <=           0  will be used to build the background map.
# emproc::emenergy:-  Background data will be filled by row and column averaging when less than           10  events around.
# emproc::emenergy:-  no BADPIX extension in input event file. Assume no bad pixel in EVFLAG.
# emproc::emenergy:-        20592  events outside field of view
# emproc::emenergy:-        21764  events outside the ellipse in E3/E1, E4/E1
# emproc::emenergy:-         1073  events rejected by   3.00000000      sigma clipping on E4 for CCDBKG
# emproc::emenergy:-        20497  events outside the ellipse in E3/E1, E4/E1
# emproc::emenergy:-         9812  events with PHA out of range          25  -        4095
# emproc::emenergy:- emenergy (emenergy-8.9)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:33.000
# emproc:- emenergy (emenergy-8.9)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:12:33.000
# ...
# emproc:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2024-01-04T21:07:11.000
# emproc::evselect:- Executing (routine): evselect table=.//0327_0101441401_EMOS2_S004_07_Evts.ds:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=yes flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(FLAG & 0x762aa000) == 0' filtertype=expression cleandss=no updateexposure=no filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PHA zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum.fits spectralbinsize=5 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=no rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# emproc::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2024-01-04T21:07:11.000
# ** emproc::evselect: warning (NoCCDcolumn), Event list does not have a CCDNR column. Cannot update exposure information.
# emproc::evselect:- selected 99590 rows from the input table.
# emproc::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-01-04T21:07:11.000
# emproc:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-01-04T21:07:11.000
# emproc:- Executing (invoked): evlistcomb eventsets='.//0327_0101441401_EMOS2_S004_01_Evts.ds .//0327_0101441401_EMOS2_S004_02_Evts.ds .//0327_0101441401_EMOS2_S004_03_Evts.ds .//0327_0101441401_EMOS2_S004_04_Evts.ds .//0327_0101441401_EMOS2_S004_05_Evts.ds .//0327_0101441401_EMOS2_S004_06_Evts.ds .//0327_0101441401_EMOS2_S004_07_Evts.ds' imagingset=.//0327_0101441401_EMOS2_S004_ImagingEvts.ds timingset=.//0327_0101441401_EMOS2_S004_ImagingEvts.ds maintable='EVENTS OFFSETS' othertables='EXPOSURE BADPIX STDGTI' primarychecks='TELESCOP INSTRUME OBS_ID EXP_ID' primaryonly=ORIGIN extensionchecks='DET_SYST TIMEUNIT TIMESYS MJDREF TIMEREF TASSIGN TIMEZERO CLOCKAPP TCRPX TCTYP TCRVL TCDLT TCROT TCUNI' maxattributes='TSTOP TLMAX TDMAX' minattributes='TSTART TLMIN TDMIN' mainattributes='' emosdatamodes='IMAGING TIMING' emosimgcolnames='TIME RAWX RAWY DETX DETY X Y PHA PI FLAG PATTERN OFFSETX OFFSETY' emosimgcoltypes='double int16 int16 int16 int16 int32 int32 int16 int16 int32 int8 int16 int16' emostimcolnames='TIME RAWX PHA PI FLAG PATTERN OFFSETX' emostimcoltypes='double int16 int16 int16 int32 int8 int16' epndatamodes='IMAGING TIMING' epnimgcolnames='TIME RAWX RAWY DETX DETY X Y PHA PI FLAG PATTERN PAT_ID PAT_SEQ OFFSETX' epnimgcoltypes='double int16 int16 int16 int16 int32 int32 int16 int16 int32 int8 int16 int8 int16' epntimcolnames='TIME RAWX PHA PI FLAG PATTERN' epntimcoltypes='double int16 int16 int16 int32 int8' rgsdatamodes='SPECTROSCOPY HIGHTIMERESOLUTION' rgsimgcolnames='BETA_CORR XDSP_CORR TIME FLAG BETA XDSP CHIPX CHIPY PHA SHAPE GRADE BETA_CHANNEL XDSP_CHANNEL PI' rgsimgcoltypes='single single double int32 single single int16 int16 int16 int8 int8 int16 int16 int16' rgstimcolnames='BETA_CORR TIME FLAG BETA CHIPX PHA BETA_CHANNEL PI' rgstimcoltypes='single double int32 single int16 int16 int16 int16' instrument=emos  -w 1 -V 4
# emproc:- evlistcomb (evlistcomb-4.20)  [xmmsas_20230412_1735-21.0.0] started:  2024-01-04T21:07:11.000
# emproc::evlistcomb:- Executing (routine): evlistcomb eventsets='.//0327_0101441401_EMOS2_S004_01_Evts.ds .//0327_0101441401_EMOS2_S004_02_Evts.ds .//0327_0101441401_EMOS2_S004_03_Evts.ds .//0327_0101441401_EMOS2_S004_04_Evts.ds .//0327_0101441401_EMOS2_S004_05_Evts.ds .//0327_0101441401_EMOS2_S004_06_Evts.ds .//0327_0101441401_EMOS2_S004_07_Evts.ds' imagingset=.//0327_0101441401_EMOS2_S004_ImagingEvts.ds timingset=.//0327_0101441401_EMOS2_S004_ImagingEvts.ds maintable='EVENTS OFFSETS' othertables='EXPOSURE BADPIX STDGTI' primarychecks='TELESCOP INSTRUME OBS_ID EXP_ID' primaryonly=ORIGIN extensionchecks='DET_SYST TIMEUNIT TIMESYS MJDREF TIMEREF TASSIGN TIMEZERO CLOCKAPP TCRPX TCTYP TCRVL TCDLT TCROT TCUNI' maxattributes='TSTOP TLMAX TDMAX' minattributes='TSTART TLMIN TDMIN' mainattributes='' emosdatamodes='IMAGING TIMING' emosimgcolnames='TIME RAWX RAWY DETX DETY X Y PHA PI FLAG PATTERN OFFSETX OFFSETY' emosimgcoltypes='double int16 int16 int16 int16 int32 int32 int16 int16 int32 int8 int16 int16' emostimcolnames='TIME RAWX PHA PI FLAG PATTERN OFFSETX' emostimcoltypes='double int16 int16 int16 int32 int8 int16' epndatamodes='IMAGING TIMING' epnimgcolnames='TIME RAWX RAWY DETX DETY X Y PHA PI FLAG PATTERN PAT_ID PAT_SEQ OFFSETX' epnimgcoltypes='double int16 int16 int16 int16 int32 int32 int16 int16 int32 int8 int16 int8 int16' epntimcolnames='TIME RAWX PHA PI FLAG PATTERN' epntimcoltypes='double int16 int16 int16 int32 int8' rgsdatamodes='SPECTROSCOPY HIGHTIMERESOLUTION' rgsimgcolnames='BETA_CORR XDSP_CORR TIME FLAG BETA XDSP CHIPX CHIPY PHA SHAPE GRADE BETA_CHANNEL XDSP_CHANNEL PI' rgsimgcoltypes='single single double int32 single single int16 int16 int16 int8 int8 int16 int16 int16' rgstimcolnames='BETA_CORR TIME FLAG BETA CHIPX PHA BETA_CHANNEL PI' rgstimcoltypes='single double int32 single int16 int16 int16 int16' instrument=emos  -w 1 -V 4
# emproc::evlistcomb:- evlistcomb (evlistcomb-4.20)  [xmmsas_20230412_1735-21.0.0] started:  2024-01-04T21:07:11.000
# emproc::evlistcomb:-  Instrument name : emos
# emproc::evlistcomb:-            2  input names for parameter :emosdatamodes
# emproc::evlistcomb:-           13  input names for parameter :emosimgcolnames
# emproc::evlistcomb:-           13  input names for parameter :emosimgcoltypes
# emproc::evlistcomb:-            7  input names for parameter :emostimcolnames
# emproc::evlistcomb:-            7  input names for parameter :emostimcoltypes
# emproc::evlistcomb:-            2  input names for parameter :maintable
# emproc::evlistcomb:-  Main table name : EVENTS
# emproc::evlistcomb:-            0  input names for parameter :mainattributes
# emproc::evlistcomb:-            3  input names for parameter :minattributes
# emproc::evlistcomb:-            3  input names for parameter :maxattributes
# emproc::evlistcomb:-            3  input names for parameter :othertables
# emproc::evlistcomb:-            4  input names for parameter :primarychecks
# emproc::evlistcomb:-            1  input names for parameter :primaryonly
# emproc::evlistcomb:-           14  input names for parameter :extensionchecks
# emproc::evlistcomb:-            7  input event files
# emproc::evlistcomb:-  Entering mode IMAGING
# emproc::evlistcomb:-  Create .//0327_0101441401_EMOS2_S004_ImagingEvts.ds
# emproc::evlistcomb:-  .//0327_0101441401_EMOS2_S004_ImagingEvts.ds:EVENTS has     1031171  rows
# emproc::evlistcomb:-  .//0327_0101441401_EMOS2_S004_ImagingEvts.ds:OFFSETS has          56  rows
# emproc::evlistcomb:-  Writing extension EXPOSU01 from .//0327_0101441401_EMOS2_S004_01_Evts.ds:EXPOSURE
# emproc::evlistcomb:-  Writing extension BADPIX01 from .//0327_0101441401_EMOS2_S004_01_Evts.ds:BADPIX
# emproc::evlistcomb:-  extension STDGTI not found in .//0327_0101441401_EMOS2_S004_01_Evts.ds
# emproc::evlistcomb:-  Writing extension EXPOSU02 from .//0327_0101441401_EMOS2_S004_02_Evts.ds:EXPOSURE
# emproc::evlistcomb:-  Writing extension BADPIX02 from .//0327_0101441401_EMOS2_S004_02_Evts.ds:BADPIX
# emproc::evlistcomb:-  extension STDGTI not found in .//0327_0101441401_EMOS2_S004_02_Evts.ds
# emproc::evlistcomb:-  Writing extension EXPOSU03 from .//0327_0101441401_EMOS2_S004_03_Evts.ds:EXPOSURE
# emproc::evlistcomb:-  Writing extension BADPIX03 from .//0327_0101441401_EMOS2_S004_03_Evts.ds:BADPIX
# emproc::evlistcomb:-  extension STDGTI not found in .//0327_0101441401_EMOS2_S004_03_Evts.ds
# emproc::evlistcomb:-  Writing extension EXPOSU04 from .//0327_0101441401_EMOS2_S004_04_Evts.ds:EXPOSURE
# emproc::evlistcomb:-  Writing extension BADPIX04 from .//0327_0101441401_EMOS2_S004_04_Evts.ds:BADPIX
# emproc::evlistcomb:-  extension STDGTI not found in .//0327_0101441401_EMOS2_S004_04_Evts.ds
# emproc::evlistcomb:-  Writing extension EXPOSU05 from .//0327_0101441401_EMOS2_S004_05_Evts.ds:EXPOSURE
# emproc::evlistcomb:-  Writing extension BADPIX05 from .//0327_0101441401_EMOS2_S004_05_Evts.ds:BADPIX
# emproc::evlistcomb:-  extension STDGTI not found in .//0327_0101441401_EMOS2_S004_05_Evts.ds
# emproc::evlistcomb:-  Writing extension EXPOSU06 from .//0327_0101441401_EMOS2_S004_06_Evts.ds:EXPOSURE
# emproc::evlistcomb:-  Writing extension BADPIX06 from .//0327_0101441401_EMOS2_S004_06_Evts.ds:BADPIX
# emproc::evlistcomb:-  extension STDGTI not found in .//0327_0101441401_EMOS2_S004_06_Evts.ds
# emproc::evlistcomb:-  Writing extension EXPOSU07 from .//0327_0101441401_EMOS2_S004_07_Evts.ds:EXPOSURE
# emproc::evlistcomb:-  Writing extension BADPIX07 from .//0327_0101441401_EMOS2_S004_07_Evts.ds:BADPIX
# emproc::evlistcomb:-  extension STDGTI not found in .//0327_0101441401_EMOS2_S004_07_Evts.ds
# emproc::evlistcomb:-  Entering mode TIMING
# emproc::evlistcomb:-  No output for mode TIMING
# emproc::evlistcomb:- evlistcomb (evlistcomb-4.20)  [xmmsas_20230412_1735-21.0.0] ended:    2024-01-04T21:07:12.000
# emproc:- evlistcomb (evlistcomb-4.20)  [xmmsas_20230412_1735-21.0.0] ended:    2024-01-04T21:07:12.000
# emproc:- Executing (invoked): dscopyblock blocks=/Users/woodml/Observing/XMM-Newton/0101441401/ccf.cif:CALINDEX to=.//0327_0101441401_EMOS2_S004_ImagingEvts.ds  -w 1 -V 4
# emproc:- dscopyblock (daltools-1.11.1)  [xmmsas_20230412_1735-21.0.0] started:  2024-01-04T21:07:12.000
# emproc::dscopyblock:- Executing (routine): dscopyblock blocks=/Users/woodml/Observing/XMM-Newton/0101441401/ccf.cif:CALINDEX to=.//0327_0101441401_EMOS2_S004_ImagingEvts.ds  -w 1 -V 4
# emproc::dscopyblock:- dscopyblock (daltools-1.11.1)  [xmmsas_20230412_1735-21.0.0] started:  2024-01-04T21:07:12.000
# emproc::dscopyblock:- dscopyblock (daltools-1.11.1)  [xmmsas_20230412_1735-21.0.0] ended:    2024-01-04T21:07:13.000
# emproc:- dscopyblock (daltools-1.11.1)  [xmmsas_20230412_1735-21.0.0] ended:    2024-01-04T21:07:13.000
# emproc:- Executing (invoked): evselect table=.//0327_0101441401_EMOS2_S004_ImagingEvts.ds:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=yes flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(( CCDNR == 1 && TIME in gti(.//0327_0101441401_EMOS2_S004_01_FrmGti.ds:STDGTI01))||( CCDNR == 2 && TIME in gti(.//0327_0101441401_EMOS2_S004_02_FrmGti.ds:STDGTI02))||( CCDNR == 3 && TIME in gti(.//0327_0101441401_EMOS2_S004_03_FrmGti.ds:STDGTI03))||( CCDNR == 4 && TIME in gti(.//0327_0101441401_EMOS2_S004_04_FrmGti.ds:STDGTI04))||( CCDNR == 5 && TIME in gti(.//0327_0101441401_EMOS2_S004_05_FrmGti.ds:STDGTI05))||( CCDNR == 6 && TIME in gti(.//0327_0101441401_EMOS2_S004_06_FrmGti.ds:STDGTI06))||( CCDNR == 7 && TIME in gti(.//0327_0101441401_EMOS2_S004_07_FrmGti.ds:STDGTI07)))' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PHA zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum.fits spectralbinsize=5 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=no rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# emproc:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2024-01-04T21:07:13.000
# emproc::evselect:- Executing (routine): evselect table=.//0327_0101441401_EMOS2_S004_ImagingEvts.ds:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=yes flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(( CCDNR == 1 && TIME in gti(.//0327_0101441401_EMOS2_S004_01_FrmGti.ds:STDGTI01))||( CCDNR == 2 && TIME in gti(.//0327_0101441401_EMOS2_S004_02_FrmGti.ds:STDGTI02))||( CCDNR == 3 && TIME in gti(.//0327_0101441401_EMOS2_S004_03_FrmGti.ds:STDGTI03))||( CCDNR == 4 && TIME in gti(.//0327_0101441401_EMOS2_S004_04_FrmGti.ds:STDGTI04))||( CCDNR == 5 && TIME in gti(.//0327_0101441401_EMOS2_S004_05_FrmGti.ds:STDGTI05))||( CCDNR == 6 && TIME in gti(.//0327_0101441401_EMOS2_S004_06_FrmGti.ds:STDGTI06))||( CCDNR == 7 && TIME in gti(.//0327_0101441401_EMOS2_S004_07_FrmGti.ds:STDGTI07)))' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PHA zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum.fits spectralbinsize=5 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=no rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# emproc::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2024-01-04T21:07:13.000
# emproc::evselect:- selected 1031171 rows from the input table.
# emproc::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-01-04T21:07:13.000
# emproc:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-01-04T21:07:13.000
# emproc:- emproc (epicproc-2.25.3)  [xmmsas_20230412_1735-21.0.0] ended:    2024-01-04T21:07:13.000
# ** emproc: warning (SummaryOfWarnings),
#    warning GATTI flare screening silently occurred 1 times
#    warning SubTaskError silently occurred 2 times
#  > 4 EPIC-MOS1 event list found. Not running emproc again.
#
#     0327_0101441401_EMOS1_S003_ImagingEvts.ds
#
#     0327_0101441401_EMOS1_U002_ImagingEvts.ds
#
#     0327_0101440801_EMOS1_S001_ImagingEvts.ds
#
#     2232_0671960101_EMOS1_S001_ImagingEvts.ds
#
#  > 3 EPIC-MOS2 event list found. Not running emproc again.
#
#     0327_0101441401_EMOS2_S004_ImagingEvts.ds
#
#     0327_0101440801_EMOS2_S002_ImagingEvts.ds
#
#     2232_0671960101_EMOS2_S002_ImagingEvts.ds
#
# ..... OK

# %%
print("Running emproc ..... \n")

# Check if emproc has already run. If it has, do not run again 
exists = 0
m1evt_list = []
m2evt_list = []
for root, dirs, files in os.walk("."):  
    for filename in files:
        if (filename.find('EMOS1') != -1) and filename.endswith('ImagingEvts.ds'):
            m1evt_list.append(filename)
            exists = 1 
        if (filename.find('EMOS2') != -1) and filename.endswith('ImagingEvts.ds'):
            m2evt_list.append(filename)
            exists = 1            
if exists:    
    print(" > " + str(len(m1evt_list)) + " EPIC-MOS1 event list found. Not running emproc again.\n")
    for x in m1evt_list:
        print("    " + x + "\n")
    print(" > " + str(len(m2evt_list)) + " EPIC-MOS2 event list found. Not running emproc again.\n")
    for x in m2evt_list:
        print("    " + x + "\n")
    print("..... OK")
else:
    wrap(cmd,inargs).run()      # <<<<< Execute SAS task
    exists = 0 
    m1evt_list = []
    m2evt_list = []
    for root, dirs, files in os.walk("."):  
        for filename in files:
            if (filename.find('EMOS1') != -1) and filename.endswith('ImagingEvts.ds'):
                m1evt_list.append(filename)
                exists = 1 
            if (filename.find('EMOS2') != -1) and filename.endswith('ImagingEvts.ds'):
                m2evt_list.append(filename)
                exists = 1            
    if exists:    
        print(" > " + str(len(m1evt_list)) + " EPIC-MOS1 event list found. Not running emproc again.\n")
        for x in m1evt_list:
            print("    " + x + "\n")
        print(" > " + str(len(m2evt_list)) + " EPIC-MOS2 event list found. Not running emproc again.\n")
        for x in m2evt_list:
            print("    " + x + "\n")
        print("..... OK")
    else:
        print("Something has gone wrong with emproc. I cant find any event list file. \n")
# Out:
# Running emproc .....
#
#  > 1 EPIC-MOS1 event list found. Not running emproc again.
#
#     0327_0101440801_EMOS1_S001_ImagingEvts.ds
#
#  > 1 EPIC-MOS2 event list found. Not running emproc again.
#
#     0327_0101440801_EMOS2_S002_ImagingEvts.ds
#
# ..... OK

# %% [markdown]
# # Process RGS

# %%
# SAS Command
cmd        = "rgsproc" # SAS task to be executed                  

# Arguments of SAS Command
inargs = ['xpsfincl=75']           # do not provide any parameters 

# Execute the SAS task to obtain RGS products
wrap(cmd, inargs).run()
# Out:
# Executing:
# rgsproc entrystage='1:events' finalstage='6:lightcurve' withinstexpids='no' instexpids='' orders='1 2' expunge='events' spectrumbinning='lambda' withprefix='no' prefix='' timestep='1' driftlimit='5' onlylastatt='no' withepicset='no' epicset='' withsrc='no' srclabel='USER' srcrate='0' srcstyle='radec' srcra='-999' srcdec='-999' srcdisp='0' srcxdsp='0' attstyle='expmedian' attra='-999' attdec='-999' attapos='-999' includeinputfifofull='yes' calcoffsets='no' withoffsethistogram='no' withdiagoffset='yes' withgain='yes' withcti='yes' withadvisory='yes' badpixalgo='badpixalgo' embadpixalgo='no' withfoundhot='yes' keepcool='yes' pixnoiselimit='0' colnoiselimit='250' pixsharpness='5' colsharpness='8' detcoord='cam' withdetcoord='no' reconstruct='yes' betabinning='binSize' betabinref='0.03578524' betabinwidth='1.208e-05' nbetabins='3400' betamin='0.03' betamax='0.08' xdispbinning='binSize' xdispbinref='-0.0009126' xdispbinwidth='1.08e-05' nxdispbins='170' xdispmin='-0.001' xdispmax='0.001' withpointingcolumn='no' withmlambdacolumn='yes' withheliocentriccorr='yes' withsunanglecorr='yes' rejflags='BAD_SHAPE ON_NODE_INTERFACE ON_BADPIX NEXT_TO_BADPIX ON_WINDOW_BORDER BELOW_ACCEPTANCE' driftbinsize='1' withcombmap='yes' auxgtitables='' spatialres='5' orderres='3' xpsfincl='75' xpsfexcl='98' pdistincl='95' withpicutoff='no' picutoff='0' xdspregions='' xdspbackground='' procsrcsexpr='INDEX==#PRIMESRC' exclsrcsexpr='INDEX==#PRIMESRC' bkgcorrect='no' withbkgset='yes' withbackgroundmodel='no' edgechannels='2' rebin='1' withfracexp='no' exposed='0.1' badquality='1' witharffile='false' rmfbins='4000' fftdim='3' withmirrorpsf='yes' withangdist='no' angdistset='angdist.txt' mergeorders='no' flxformat='dal' flxmode='wavelength' flxmin='4' flxmax='40' flxbins='3600' flxquality='0' withflxnan='no' flxnan='0' withdyneffarea='yes' withrectification='no' witheffectiveareacorrection='yes' lambdabinref='4.005' lambdabinwidth='0.010' nlambdabins='3600' withheliocorr='no' timebinsize='1000' withbkgsubtraction='yes'
# rgsproc:- Executing (routine): rgsproc entrystage=1:events finalstage=6:lightcurve withinstexpids=no instexpids='' orders='1 2' expunge=events spectrumbinning=lambda withprefix=no prefix='' timestep=1 driftlimit=5 onlylastatt=no withepicset=no epicset='' withsrc=no srclabel=USER srcrate=0 srcstyle=radec srcra=-999 srcdec=-999 srcdisp=0 srcxdsp=0 attstyle=expmedian attra=-999 attdec=-999 attapos=-999 includeinputfifofull=yes calcoffsets=no withoffsethistogram=no withdiagoffset=yes withgain=yes withcti=yes withadvisory=yes embadpixalgo=no withfoundhot=yes badpixalgo=badpixalgo keepcool=yes pixnoiselimit=0 colnoiselimit=250 pixsharpness=5 colsharpness=8 detcoord=cam withdetcoord=no reconstruct=yes betabinning=binSize betabinref=0.03578524 betabinwidth=1.208e-05 nbetabins=3400 betamin=0.03 betamax=0.08 xdispbinning=binSize xdispbinref=-0.0009126 xdispbinwidth=1.08e-05 nxdispbins=170 xdispmin=-0.001 xdispmax=0.001 withpointingcolumn=no withmlambdacolumn=yes withheliocentriccorr=yes withsunanglecorr=yes rejflags='BAD_SHAPE ON_NODE_INTERFACE ON_BADPIX NEXT_TO_BADPIX ON_WINDOW_BORDER BELOW_ACCEPTANCE' driftbinsize=1 withcombmap=yes auxgtitables='' spatialres=5 orderres=3 xpsfincl=75 xpsfexcl=98 pdistincl=95 withpicutoff=no picutoff=0 xdspregions='' xdspbackground='' procsrcsexpr=INDEX==#PRIMESRC exclsrcsexpr=INDEX==#PRIMESRC bkgcorrect=no withbkgset=yes withbackgroundmodel=no edgechannels=2 rebin=1 withfracexp=no exposed=0.1 badquality=1 witharffile=no rmfbins=4000 fftdim=3 withmirrorpsf=yes angdistset=angdist.txt withangdist=no mergeorders=no flxformat=dal flxmode=wavelength flxmin=4 flxmax=40 flxbins=3600 flxquality=0 withflxnan=no flxnan=0 withdyneffarea=yes withrectification=no witheffectiveareacorrection=yes lambdabinref=4.005 lambdabinwidth=0.01 nlambdabins=3600 withheliocorr=no timebinsize=1000 withbkgsubtraction=yes  -w 1 -V 4
# rgsproc:- rgsproc (rgsproc-1.37)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:10.000
# rgsproc:- Executing (routine): attfilter attset=P0101440801OBX000ATTTSR0000.FIT timecol=TIME racol=AHFRA deccol=AHFDEC apacol=AHFPA instexpid=R1S004 gtitable=P0101440801R1S004attgti0000.FIT:STDGTI onlylastatt=no expression='' filtertype=cone tolangles=5.000000*#ARCMIN mingtisize=10 maxfracshort=0.1  -w 1 -V 4
# rgsproc:- attfilter (attfilter-1.4)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:11.000
# rgsproc::attfilter:- Exposure window: [2001-09-21T01:27:54.000, 2001-09-22T13:29:28.000]
# rgsproc::attfilter:- Median spacecraft attitude in exposure window: SpacecraftAttitude(04h55m53.58s/30o35'07.20''/83.5621deg)
# rgsproc::attfilter:- Executing (routine): tabgtigen table=/var/tmp/tmp.0.k9NvB2:ATTHK gtiset=P0101440801R1S004attgti0000.FIT:STDGTI expression='skyvector(AHFRA*#RAD, AHFDEC*#RAD) in cone(skyvector(1.2910768, 0.53381477), 5.000000*#ARCMIN)' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=10  -w 1 -V 4
# rgsproc::attfilter:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:11.000
# rgsproc::attfilter:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:11.000
# rgsproc:- attfilter (attfilter-1.4)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:11.000
# rgsproc:- Executing (routine): hkgtigen instrument=rgs1 gtiset=P0101440801R1S004hkgti_0000.FIT diagfile=STDOUT plotgtis=no diagnosticmode=no withgtiset=yes parameters=G5063 withparameters=yes except=yes overrideparameters='' overrideparametervalues='' withoverrideparameters=no timecolumn=TIME prefraction=0.5 postfraction=0.5  -w 1 -V 4
# rgsproc:- hkgtigen (hkgtigen-1.15)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:11.000
# rgsproc:- hkgtigen (hkgtigen-1.15)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:12.000
# rgsproc:- Executing (routine): rgssources changeprime=no changeattitude=no filemode=create srclist=P0101440801R1S004SRCLI_0000.FIT instexpid=R1S004 writeobskwds=yes writeexpkwds=yes clobberonlabel=no primeindex=1 primelabel=PROPOSAL primeexpression='' primestyle=auto meanset=atthk.dat medianset=atthk.dat attra=0 attdec=0 attapos=0 expmediantable=P0101440801R1S004attgti0000.FIT:STDGTI attstyle=expmedian label=USER rate=0 userasprime=no process=no bkgexclude=yes ra=0 dec=0 deltaxdsp=0 deltadisp=0 positionstyle=radec addusersource=no epicset='' epiclabelprefix=EPIC doconfusion=no instweights='3.5 1 1' flagepicsrcoutoffov=no withepicset=no enablefilter=no bandids='2 3' withboresightfudge=yes  -w 1 -V 4
# rgsproc:- rgssources (rgssources-6.3.3)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:12.000
# ** rgsproc::rgssources: warning (badPrimeRate), The prime source (INDEX=1) has a RATE value of <= zero. Confusion values cannot be calculated.
# rgsproc:- rgssources (rgssources-6.3.3)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:12.000
# rgsproc:- Executing (routine): rgsframes set=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_R1S00401SPE.FIT ccdset=P0101440801R1S004events1000.FIT minexposuretime=0.001 withratecolumn=no maxrawpixels=9999 withmaxrawpixels=no maxrawpixelrate=9999 withmaxrawpixelrate=no processall=no instrument=rgs1  -w 1 -V 4
# rgsproc:- rgsframes (rgsframes-3.19)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:12.000
# rgsproc::rgsframes:-  Observing mode was HighEventRateWithSES
# rgsproc::rgsframes:-  Identified           0 duplicate entries in EXPOSURE table
# rgsproc::rgsframes:-            2 frames flagged bad based on instrument bad-condition flags
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       12640 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       13456 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       14016 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       14776 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       91808 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       91880 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      182968 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      183416 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      183480 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      184408 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      184776 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      186256 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      186840 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      187976 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188064 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188232 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188296 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-            0 frames flagged bad based on minexposuretime
# rgsproc::rgsframes:-  Identified           0 duplicate entries in PIXELS table
# rgsproc::rgsframes:-  Total number of frames flagged bad:           2 out of a total of       27951
# rgsproc:- rgsframes (rgsframes-3.19)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:13.000
# rgsproc:- Executing (routine): rgsframes set=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_R1S00402SPE.FIT ccdset=P0101440801R1S004events2000.FIT minexposuretime=0.001 withratecolumn=no maxrawpixels=9999 withmaxrawpixels=no maxrawpixelrate=9999 withmaxrawpixelrate=no processall=no instrument=rgs1  -w 1 -V 4
# rgsproc:- rgsframes (rgsframes-3.19)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:13.000
# rgsproc::rgsframes:-  Observing mode was HighEventRateWithSES
# rgsproc::rgsframes:-  Identified           0 duplicate entries in EXPOSURE table
# rgsproc::rgsframes:-            1 frames flagged bad based on instrument bad-condition flags
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       12641 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       13457 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       14017 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       14777 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       91809 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       91881 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      182969 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      183417 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      184409 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      184777 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      186257 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      186841 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      187977 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188065 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188225 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188297 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-            0 frames flagged bad based on minexposuretime
# rgsproc::rgsframes:-  Identified           0 duplicate entries in PIXELS table
# rgsproc::rgsframes:-  Total number of frames flagged bad:           1 out of a total of       27952
# rgsproc:- rgsframes (rgsframes-3.19)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:13.000
# rgsproc:- Executing (routine): rgsframes set=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_R1S00403SPE.FIT ccdset=P0101440801R1S004events3000.FIT minexposuretime=0.001 withratecolumn=no maxrawpixels=9999 withmaxrawpixels=no maxrawpixelrate=9999 withmaxrawpixelrate=no processall=no instrument=rgs1  -w 1 -V 4
# rgsproc:- rgsframes (rgsframes-3.19)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:13.000
# rgsproc::rgsframes:-  Observing mode was HighEventRateWithSES
# rgsproc::rgsframes:-  Identified           0 duplicate entries in EXPOSURE table
# rgsproc::rgsframes:-            1 frames flagged bad based on instrument bad-condition flags
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       12642 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       13458 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       14018 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       14778 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       91810 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       91882 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      182970 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      183418 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      183474 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      184410 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      184778 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      186258 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      186842 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      187970 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188066 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188226 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188298 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-            0 frames flagged bad based on minexposuretime
# rgsproc::rgsframes:-  Identified           0 duplicate entries in PIXELS table
# rgsproc::rgsframes:-  Total number of frames flagged bad:           1 out of a total of       27951
# rgsproc:- rgsframes (rgsframes-3.19)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:13.000
# rgsproc:- Executing (routine): rgsframes set=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_R1S00404SPE.FIT ccdset=P0101440801R1S004events4000.FIT minexposuretime=0.001 withratecolumn=no maxrawpixels=9999 withmaxrawpixels=no maxrawpixelrate=9999 withmaxrawpixelrate=no processall=no instrument=rgs1  -w 1 -V 4
# rgsproc:- rgsframes (rgsframes-3.19)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:13.000
# rgsproc::rgsframes:-  Observing mode was HighEventRateWithSES
# rgsproc::rgsframes:-  Identified           0 duplicate entries in EXPOSURE table
# rgsproc::rgsframes:-            1 frames flagged bad based on instrument bad-condition flags
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       12643 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       13451 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       14019 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       14779 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       91803 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       91883 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      182971 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      183419 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      183475 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      184411 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      184779 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      186259 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      186843 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      187971 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188067 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188227 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188299 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-            0 frames flagged bad based on minexposuretime
# rgsproc::rgsframes:-  Identified           0 duplicate entries in PIXELS table
# rgsproc::rgsframes:-  Total number of frames flagged bad:           1 out of a total of       27949
# rgsproc:- rgsframes (rgsframes-3.19)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:13.000
# rgsproc:- Executing (routine): rgsframes set=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_R1S00405SPE.FIT ccdset=P0101440801R1S004events5000.FIT minexposuretime=0.001 withratecolumn=no maxrawpixels=9999 withmaxrawpixels=no maxrawpixelrate=9999 withmaxrawpixelrate=no processall=no instrument=rgs1  -w 1 -V 4
# rgsproc:- rgsframes (rgsframes-3.19)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:13.000
# rgsproc::rgsframes:-  Observing mode was HighEventRateWithSES
# rgsproc::rgsframes:-  Identified           0 duplicate entries in EXPOSURE table
# rgsproc::rgsframes:-            1 frames flagged bad based on instrument bad-condition flags
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       12644 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       13452 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       14020 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       14780 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       91804 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       91884 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      182972 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      183420 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      183476 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      184412 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      184780 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      186260 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      186836 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      187972 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188068 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188228 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188292 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-            0 frames flagged bad based on minexposuretime
# rgsproc::rgsframes:-  Identified           0 duplicate entries in PIXELS table
# rgsproc::rgsframes:-  Total number of frames flagged bad:           1 out of a total of       27950
# rgsproc:- rgsframes (rgsframes-3.19)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:13.000
# rgsproc:- Executing (routine): rgsframes set=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_R1S00406SPE.FIT ccdset=P0101440801R1S004events6000.FIT minexposuretime=0.001 withratecolumn=no maxrawpixels=9999 withmaxrawpixels=no maxrawpixelrate=9999 withmaxrawpixelrate=no processall=no instrument=rgs1  -w 1 -V 4
# rgsproc:- rgsframes (rgsframes-3.19)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:13.000
# rgsproc::rgsframes:-  Observing mode was HighEventRateWithSES
# rgsproc::rgsframes:-  Identified           0 duplicate entries in EXPOSURE table
# rgsproc::rgsframes:-            1 frames flagged bad based on instrument bad-condition flags
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       12637 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       13453 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       14021 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       14773 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       91805 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       91885 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      182973 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      183421 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      184413 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      184773 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      186261 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      186837 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      187973 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188069 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188229 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188293 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-            0 frames flagged bad based on minexposuretime
# rgsproc::rgsframes:-  Identified           0 duplicate entries in PIXELS table
# rgsproc::rgsframes:-  Total number of frames flagged bad:           1 out of a total of       27953
# rgsproc:- rgsframes (rgsframes-3.19)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:13.000
# rgsproc:- Executing (routine): rgsframes set=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_R1S00408SPE.FIT ccdset=P0101440801R1S004events8000.FIT minexposuretime=0.001 withratecolumn=no maxrawpixels=9999 withmaxrawpixels=no maxrawpixelrate=9999 withmaxrawpixelrate=no processall=no instrument=rgs1  -w 1 -V 4
# rgsproc:- rgsframes (rgsframes-3.19)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:13.000
# rgsproc::rgsframes:-  Observing mode was HighEventRateWithSES
# rgsproc::rgsframes:-  Identified           0 duplicate entries in EXPOSURE table
# rgsproc::rgsframes:-            1 frames flagged bad based on instrument bad-condition flags
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       12638 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       13454 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       14014 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       14774 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       91806 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       91878 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      182966 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      184414 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      184774 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      186262 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      186838 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      187974 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188070 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188230 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188294 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-            0 frames flagged bad based on minexposuretime
# rgsproc::rgsframes:-  Identified           0 duplicate entries in PIXELS table
# rgsproc::rgsframes:-  Total number of frames flagged bad:           1 out of a total of       27954
# rgsproc:- rgsframes (rgsframes-3.19)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:13.000
# rgsproc:- Executing (routine): rgsframes set=/Users/woodml/Observing/XMM-Newton/SU_Aur/0101440801/0327_0101440801_R1S00409SPE.FIT ccdset=P0101440801R1S004events9000.FIT minexposuretime=0.001 withratecolumn=no maxrawpixels=9999 withmaxrawpixels=no maxrawpixelrate=9999 withmaxrawpixelrate=no processall=no instrument=rgs1  -w 1 -V 4
# rgsproc:- rgsframes (rgsframes-3.19)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:13.000
# rgsproc::rgsframes:-  Observing mode was HighEventRateWithSES
# rgsproc::rgsframes:-  Identified           0 duplicate entries in EXPOSURE table
# rgsproc::rgsframes:-            2 frames flagged bad based on instrument bad-condition flags
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       12639 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       13455 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       14015 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       14775 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       91807 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number       91879 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      182967 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      183415 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      184407 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      184775 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      186255 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      186839 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      187975 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188071 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188231 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-  Missing frame detected in EXPOSURE table before frame number      188295 ; Estimating frame time from readout sequence.
# rgsproc::rgsframes:-            0 frames flagged bad based on minexposuretime
# rgsproc::rgsframes:-  Identified           0 duplicate entries in PIXELS table
# rgsproc::rgsframes:-  Total number of frames flagged bad:           2 out of a total of       27952
# rgsproc:- rgsframes (rgsframes-3.19)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:13.000
# rgsproc:- Executing (routine): rgsenergy ccdset=P0101440801R1S004events1000.FIT offset=offset.ds withoffset=no withdiagoffset=yes withgain=yes withcti=yes  -w 1 -V 4
# rgsproc:- rgsenergy (rgsenergy-2.2)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:13.000
# ** rgsproc::rgsenergy: warning (ArgumentIgnored), <time> argument of RGS CTI correction currently ignored
# rgsproc:- rgsenergy (rgsenergy-2.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:14.000
# rgsproc:- Executing (routine): rgsbadpix ccdset=P0101440801R1S004events1000.FIT badpixset=badpix.ds withbadpixset=no withadvisory=yes embadpixalgo=no withfoundhot=yes badpixalgo=badpixalgo keepcool=yes pixnoiselimit=0 colnoiselimit=250 pixsharpness=5 colsharpness=8  -w 1 -V 4
# rgsproc:- rgsbadpix (rgsbadpix-2.20)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:14.000
# ** rgsproc::rgsbadpix: warning (BadPixDiscrepancy), (CCD 1) advisory hot segment at (305,1): 128 out of 128 pixels not found hot in telemetry
# rgsproc:- rgsbadpix (rgsbadpix-2.20)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:15.000
# rgsproc:- Executing (routine): rgsevents ccdset=P0101440801R1S004events1000.FIT reconstruct=yes withdetcoord=no detcoord=cam  -w 1 -V 4
# rgsproc:- rgsevents (rgsevents-3.13)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:15.000
# rgsproc::rgsevents:- ##XMMEA_ON_NODE0: 276080 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_NODE1: 315942 events flagged
# rgsproc::rgsevents:- ##XMMEA_ONBOARD_SER: 36347 events flagged
# rgsproc::rgsevents:- ##XMMEA_IN_BAD_FRAME: 18 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_NODE_INTERFACE: 8056 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_BADPIX: 564889 events flagged
# rgsproc::rgsevents:- ##XMMEA_NEXT_TO_BADPIX: 180206 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_WINDOW_BORDER: 58171 events flagged
# rgsproc:- rgsevents (rgsevents-3.13)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:17.000
# rgsproc:- Executing (routine): rgsenergy ccdset=P0101440801R1S004events2000.FIT offset=offset.ds withoffset=no withdiagoffset=yes withgain=yes withcti=yes  -w 1 -V 4
# rgsproc:- rgsenergy (rgsenergy-2.2)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:17.000
# rgsproc:- rgsenergy (rgsenergy-2.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:18.000
# rgsproc:- Executing (routine): rgsbadpix ccdset=P0101440801R1S004events2000.FIT badpixset=badpix.ds withbadpixset=no withadvisory=yes embadpixalgo=no withfoundhot=yes badpixalgo=badpixalgo keepcool=yes pixnoiselimit=0 colnoiselimit=250 pixsharpness=5 colsharpness=8  -w 1 -V 4
# rgsproc:- rgsbadpix (rgsbadpix-2.20)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:18.000
# rgsproc:- rgsbadpix (rgsbadpix-2.20)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:19.000
# rgsproc:- Executing (routine): rgsevents ccdset=P0101440801R1S004events2000.FIT reconstruct=yes withdetcoord=no detcoord=cam  -w 1 -V 4
# rgsproc:- rgsevents (rgsevents-3.13)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:19.000
# rgsproc::rgsevents:- ##XMMEA_ON_NODE0: 267470 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_NODE1: 255429 events flagged
# rgsproc::rgsevents:- ##XMMEA_ONBOARD_SER: 20367 events flagged
# rgsproc::rgsevents:- ##XMMEA_IN_BAD_FRAME: 25 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_NODE_INTERFACE: 8126 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_BADPIX: 484378 events flagged
# rgsproc::rgsevents:- ##XMMEA_NEXT_TO_BADPIX: 210080 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_WINDOW_BORDER: 6629 events flagged
# rgsproc:- rgsevents (rgsevents-3.13)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:21.000
# rgsproc:- Executing (routine): rgsenergy ccdset=P0101440801R1S004events3000.FIT offset=offset.ds withoffset=no withdiagoffset=yes withgain=yes withcti=yes  -w 1 -V 4
# rgsproc:- rgsenergy (rgsenergy-2.2)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:21.000
# rgsproc:- rgsenergy (rgsenergy-2.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:21.000
# rgsproc:- Executing (routine): rgsbadpix ccdset=P0101440801R1S004events3000.FIT badpixset=badpix.ds withbadpixset=no withadvisory=yes embadpixalgo=no withfoundhot=yes badpixalgo=badpixalgo keepcool=yes pixnoiselimit=0 colnoiselimit=250 pixsharpness=5 colsharpness=8  -w 1 -V 4
# rgsproc:- rgsbadpix (rgsbadpix-2.20)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:21.000
# rgsproc:- rgsbadpix (rgsbadpix-2.20)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:22.000
# rgsproc:- Executing (routine): rgsevents ccdset=P0101440801R1S004events3000.FIT reconstruct=yes withdetcoord=no detcoord=cam  -w 1 -V 4
# rgsproc:- rgsevents (rgsevents-3.13)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:22.000
# rgsproc::rgsevents:- ##XMMEA_ON_NODE0: 182699 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_NODE1: 148358 events flagged
# rgsproc::rgsevents:- ##XMMEA_ONBOARD_SER: 25745 events flagged
# rgsproc::rgsevents:- ##XMMEA_IN_BAD_FRAME: 10 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_NODE_INTERFACE: 9332 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_BADPIX: 308798 events flagged
# rgsproc::rgsevents:- ##XMMEA_NEXT_TO_BADPIX: 124568 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_WINDOW_BORDER: 8108 events flagged
# rgsproc:- rgsevents (rgsevents-3.13)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:23.000
# rgsproc:- Executing (routine): rgsenergy ccdset=P0101440801R1S004events4000.FIT offset=offset.ds withoffset=no withdiagoffset=yes withgain=yes withcti=yes  -w 1 -V 4
# rgsproc:- rgsenergy (rgsenergy-2.2)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:23.000
# rgsproc:- rgsenergy (rgsenergy-2.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:23.000
# rgsproc:- Executing (routine): rgsbadpix ccdset=P0101440801R1S004events4000.FIT badpixset=badpix.ds withbadpixset=no withadvisory=yes embadpixalgo=no withfoundhot=yes badpixalgo=badpixalgo keepcool=yes pixnoiselimit=0 colnoiselimit=250 pixsharpness=5 colsharpness=8  -w 1 -V 4
# rgsproc:- rgsbadpix (rgsbadpix-2.20)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:23.000
# rgsproc:- rgsbadpix (rgsbadpix-2.20)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:24.000
# rgsproc:- Executing (routine): rgsevents ccdset=P0101440801R1S004events4000.FIT reconstruct=yes withdetcoord=no detcoord=cam  -w 1 -V 4
# rgsproc:- rgsevents (rgsevents-3.13)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:24.000
# rgsproc::rgsevents:- ##XMMEA_ON_NODE0: 142024 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_NODE1: 80111 events flagged
# rgsproc::rgsevents:- ##XMMEA_ONBOARD_SER: 34965 events flagged
# rgsproc::rgsevents:- ##XMMEA_IN_BAD_FRAME: 9 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_NODE_INTERFACE: 4105 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_BADPIX: 200041 events flagged
# rgsproc::rgsevents:- ##XMMEA_NEXT_TO_BADPIX: 129525 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_WINDOW_BORDER: 2137 events flagged
# rgsproc:- rgsevents (rgsevents-3.13)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:25.000
# rgsproc:- Executing (routine): rgsenergy ccdset=P0101440801R1S004events5000.FIT offset=offset.ds withoffset=no withdiagoffset=yes withgain=yes withcti=yes  -w 1 -V 4
# rgsproc:- rgsenergy (rgsenergy-2.2)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:25.000
# rgsproc:- rgsenergy (rgsenergy-2.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:25.000
# rgsproc:- Executing (routine): rgsbadpix ccdset=P0101440801R1S004events5000.FIT badpixset=badpix.ds withbadpixset=no withadvisory=yes embadpixalgo=no withfoundhot=yes badpixalgo=badpixalgo keepcool=yes pixnoiselimit=0 colnoiselimit=250 pixsharpness=5 colsharpness=8  -w 1 -V 4
# rgsproc:- rgsbadpix (rgsbadpix-2.20)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:25.000
# rgsproc:- rgsbadpix (rgsbadpix-2.20)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:25.000
# rgsproc:- Executing (routine): rgsevents ccdset=P0101440801R1S004events5000.FIT reconstruct=yes withdetcoord=no detcoord=cam  -w 1 -V 4
# rgsproc:- rgsevents (rgsevents-3.13)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:25.000
# rgsproc::rgsevents:- ##XMMEA_ON_NODE0: 90868 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_NODE1: 80137 events flagged
# rgsproc::rgsevents:- ##XMMEA_ONBOARD_SER: 19178 events flagged
# rgsproc::rgsevents:- ##XMMEA_IN_BAD_FRAME: 6 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_NODE_INTERFACE: 2356 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_BADPIX: 153407 events flagged
# rgsproc::rgsevents:- ##XMMEA_NEXT_TO_BADPIX: 48480 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_WINDOW_BORDER: 3048 events flagged
# rgsproc:- rgsevents (rgsevents-3.13)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:26.000
# rgsproc:- Executing (routine): rgsenergy ccdset=P0101440801R1S004events6000.FIT offset=offset.ds withoffset=no withdiagoffset=yes withgain=yes withcti=yes  -w 1 -V 4
# rgsproc:- rgsenergy (rgsenergy-2.2)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:26.000
# rgsproc:- rgsenergy (rgsenergy-2.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:26.000
# rgsproc:- Executing (routine): rgsbadpix ccdset=P0101440801R1S004events6000.FIT badpixset=badpix.ds withbadpixset=no withadvisory=yes embadpixalgo=no withfoundhot=yes badpixalgo=badpixalgo keepcool=yes pixnoiselimit=0 colnoiselimit=250 pixsharpness=5 colsharpness=8  -w 1 -V 4
# rgsproc:- rgsbadpix (rgsbadpix-2.20)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:26.000
# rgsproc:- rgsbadpix (rgsbadpix-2.20)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:26.000
# rgsproc:- Executing (routine): rgsevents ccdset=P0101440801R1S004events6000.FIT reconstruct=yes withdetcoord=no detcoord=cam  -w 1 -V 4
# rgsproc:- rgsevents (rgsevents-3.13)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:26.000
# rgsproc::rgsevents:- ##XMMEA_ON_NODE0: 143037 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_NODE1: 48792 events flagged
# rgsproc::rgsevents:- ##XMMEA_ONBOARD_SER: 24787 events flagged
# rgsproc::rgsevents:- ##XMMEA_IN_BAD_FRAME: 3 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_NODE_INTERFACE: 2497 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_BADPIX: 170689 events flagged
# rgsproc::rgsevents:- ##XMMEA_NEXT_TO_BADPIX: 126369 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_WINDOW_BORDER: 2646 events flagged
# rgsproc:- rgsevents (rgsevents-3.13)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:27.000
# rgsproc:- Executing (routine): rgsenergy ccdset=P0101440801R1S004events8000.FIT offset=offset.ds withoffset=no withdiagoffset=yes withgain=yes withcti=yes  -w 1 -V 4
# rgsproc:- rgsenergy (rgsenergy-2.2)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:27.000
# rgsproc:- rgsenergy (rgsenergy-2.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:27.000
# rgsproc:- Executing (routine): rgsbadpix ccdset=P0101440801R1S004events8000.FIT badpixset=badpix.ds withbadpixset=no withadvisory=yes embadpixalgo=no withfoundhot=yes badpixalgo=badpixalgo keepcool=yes pixnoiselimit=0 colnoiselimit=250 pixsharpness=5 colsharpness=8  -w 1 -V 4
# rgsproc:- rgsbadpix (rgsbadpix-2.20)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:27.000
# rgsproc:- rgsbadpix (rgsbadpix-2.20)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:28.000
# rgsproc:- Executing (routine): rgsevents ccdset=P0101440801R1S004events8000.FIT reconstruct=yes withdetcoord=no detcoord=cam  -w 1 -V 4
# rgsproc:- rgsevents (rgsevents-3.13)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:28.000
# rgsproc::rgsevents:- ##XMMEA_ON_NODE0: 108701 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_NODE1: 46920 events flagged
# rgsproc::rgsevents:- ##XMMEA_ONBOARD_SER: 13079 events flagged
# rgsproc::rgsevents:- ##XMMEA_IN_BAD_FRAME: 3 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_NODE_INTERFACE: 5814 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_BADPIX: 129213 events flagged
# rgsproc::rgsevents:- ##XMMEA_NEXT_TO_BADPIX: 103071 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_WINDOW_BORDER: 3042 events flagged
# rgsproc:- rgsevents (rgsevents-3.13)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:28.000
# rgsproc:- Executing (routine): rgsenergy ccdset=P0101440801R1S004events9000.FIT offset=offset.ds withoffset=no withdiagoffset=yes withgain=yes withcti=yes  -w 1 -V 4
# rgsproc:- rgsenergy (rgsenergy-2.2)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:28.000
# rgsproc:- rgsenergy (rgsenergy-2.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:28.000
# rgsproc:- Executing (routine): rgsbadpix ccdset=P0101440801R1S004events9000.FIT badpixset=badpix.ds withbadpixset=no withadvisory=yes embadpixalgo=no withfoundhot=yes badpixalgo=badpixalgo keepcool=yes pixnoiselimit=0 colnoiselimit=250 pixsharpness=5 colsharpness=8  -w 1 -V 4
# rgsproc:- rgsbadpix (rgsbadpix-2.20)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:28.000
# rgsproc:- rgsbadpix (rgsbadpix-2.20)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:29.000
# rgsproc:- Executing (routine): rgsevents ccdset=P0101440801R1S004events9000.FIT reconstruct=yes withdetcoord=no detcoord=cam  -w 1 -V 4
# rgsproc:- rgsevents (rgsevents-3.13)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:19:29.000
# rgsproc::rgsevents:- ##XMMEA_ON_NODE0: 69355 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_NODE1: 77767 events flagged
# rgsproc::rgsevents:- ##XMMEA_ONBOARD_SER: 12796 events flagged
# rgsproc::rgsevents:- ##XMMEA_IN_BAD_FRAME: 14 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_NODE_INTERFACE: 1569 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_BADPIX: 124428 events flagged
# rgsproc::rgsevents:- ##XMMEA_NEXT_TO_BADPIX: 124831 events flagged
# rgsproc::rgsevents:- ##XMMEA_ON_WINDOW_BORDER: 1768 events flagged
# rgsproc:- rgsevents (rgsevents-3.13)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:19:29.000
# ...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 4 Counts= 650 Area= 0.0016103880209658168968
# rgsproc::rgslccorr:- Background: CCD 4 Counts= 314 Area= 0.0026248320341729740324
# rgsproc::rgslccorr:- Selecting events from CCDNR==5
# rgsproc::rgslccorr:- selected 507 rows from source file CCDNR==5
# rgsproc::rgslccorr:- selected 279 rows from background file CCDNR==5
# rgsproc::rgslccorr:- Calculating source area for CCDNR==5
# rgsproc::rgslccorr:- Calculating background area for CCDNR==5
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==5...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==5...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 5 Counts= 507 Area= 0.0016252920211598537864
# rgsproc::rgslccorr:- Background: CCD 5 Counts= 279 Area= 0.0023524560306268809708
# rgsproc::rgslccorr:- Selecting events from CCDNR==6
# rgsproc::rgslccorr:- selected 446 rows from source file CCDNR==6
# rgsproc::rgslccorr:- selected 346 rows from background file CCDNR==6
# rgsproc::rgslccorr:- Calculating source area for CCDNR==6
# rgsproc::rgslccorr:- Calculating background area for CCDNR==6
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==6...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==6...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 6 Counts= 446 Area= 0.0015650280203752702565
# rgsproc::rgslccorr:- Background: CCD 6 Counts= 346 Area= 0.0020372040265225809311
# rgsproc::rgslccorr:- Selecting events from CCDNR==7
# rgsproc::rgslccorr:- selected 0 rows from source file CCDNR==7
# rgsproc::rgslccorr:- selected 0 rows from background file CCDNR==7
# rgsproc::rgslccorr:- Calculating source area for CCDNR==7
# rgsproc::rgslccorr:- Calculating background area for CCDNR==7
# rgsproc::rgslccorr:- Selecting events from CCDNR==8
# rgsproc::rgslccorr:- selected 502 rows from source file CCDNR==8
# rgsproc::rgslccorr:- selected 471 rows from background file CCDNR==8
# rgsproc::rgslccorr:- Calculating source area for CCDNR==8
# rgsproc::rgslccorr:- Calculating background area for CCDNR==8
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==8...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==8...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 8 Counts= 502 Area= 0.0014204160184925506728
# rgsproc::rgslccorr:- Background: CCD 8 Counts= 471 Area= 0.0015786360205524341185
# rgsproc::rgslccorr:- Selecting events from CCDNR==9
# rgsproc::rgslccorr:- selected 3 rows from source file CCDNR==9
# rgsproc::rgslccorr:- selected 1 rows from background file CCDNR==9
# rgsproc::rgslccorr:- Calculating source area for CCDNR==9
# rgsproc::rgslccorr:- Calculating background area for CCDNR==9
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==9...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==9...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 9 Counts= 3 Area= 0.0013439520174970576594
# rgsproc::rgslccorr:- Background: CCD 9 Counts= 1 Area= 0.0013755960179090342618
# rgsproc::rgslccorr:- Adding source lightcurves for each CCD...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Adding background lightcurves for each CCD...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Next CCD: Src counts 349 Src Area 0.0016211880211064232191
# rgsproc::rgslccorr:- Next CCD: Src counts 405 Src Area 0.0016840440219247523705
# rgsproc::rgslccorr:- Next CCD: Src counts 521 Src Area 0.0016949520220667648688
# rgsproc::rgslccorr:- Next CCD: Src counts 650 Src Area 0.0016103880209658168968
# rgsproc::rgslccorr:- Next CCD: Src counts 507 Src Area 0.0016252920211598537864
# rgsproc::rgslccorr:- Next CCD: Src counts 446 Src Area 0.0015650280203752702565
# rgsproc::rgslccorr:- Next CCD: Src counts 502 Src Area 0.0014204160184925506728
# rgsproc::rgslccorr:- Next CCD: Src counts 3 Src Area 0.0013439520174970576594
# rgsproc::rgslccorr:- Next CCD Bkg counts 612 Bkg Area 0.0033291000433419157614
# rgsproc::rgslccorr:- Next CCD Bkg counts 568 Bkg Area 0.0031925880415646511364
# rgsproc::rgslccorr:- Next CCD Bkg counts 458 Bkg Area 0.0029247480380776131291
# rgsproc::rgslccorr:- Next CCD Bkg counts 314 Bkg Area 0.0026248320341729740324
# rgsproc::rgslccorr:- Next CCD Bkg counts 279 Bkg Area 0.0023524560306268809708
# rgsproc::rgslccorr:- Next CCD Bkg counts 346 Bkg Area 0.0020372040265225809311
# rgsproc::rgslccorr:- Next CCD Bkg counts 471 Bkg Area 0.0015786360205524341185
# rgsproc::rgslccorr:- Next CCD Bkg counts 1 Bkg Area 0.0013755960179090342618
# rgsproc::rgslccorr:- Mean BACKSCALE 0.69292336979671664832
# rgsproc::rgslccorr:- subtracting background lightcurve...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Creating output file...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Deleting temporary files and cleaning memory...
# rgsproc::rgslccorr:- done.
# rgsproc:- rgslccorr (rgslccorr-0.57.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-01-02T16:03:56.000
# rgsproc:- Executing (routine): rgslccorr evlist=P0101440801R2S005EVENLI0000.FIT srclist=P0101440801R2S005SRCLI_0000.FIT timebinsize=1000 timemin=0 timemax=1000 withtimeranges=no orders=2 sourceid=1 outputsrcfilename=P0101440801R2S005SRTSR_2001.FIT outputbkgfilename=P0101440801R2S005BGTSR_2001.FIT withbkgsubtraction=yes withfiltering=no lambdamin=0 lambdamax=0 energymin=0 energymax=0 filtering=wavelength withccdselection=no ccds=1  -w 1 -V 4
# rgsproc:- rgslccorr (rgslccorr-0.57.2)  [xmmsas_20230412_1735-21.0.0] started:  2024-01-02T16:03:56.000
# rgsproc::rgslccorr:- Source expression used: REGION(P0101440801R2S005SRCLI_0000.FIT:RGS2_SRC1_SPATIAL,M_LAMBDA,XDSP_CORR) && ( REGION(P0101440801R2S005SRCLI_0000.FIT:RGS2_SRC1_ORDER_2,M_LAMBDA,PI)  )
# rgsproc::rgslccorr:- selected 3376 rows from the source input table.
# rgsproc::rgslccorr:- Background expression REGION(P0101440801R2S005SRCLI_0000.FIT:RGS2_BACKGROUND,M_LAMBDA,XDSP_CORR) && ( REGION(P0101440801R2S005SRCLI_0000.FIT:RGS2_SRC1_ORDER_2,M_LAMBDA,PI)  )
# rgsproc::rgslccorr:- selected 3332 rows from the background input table.
# rgsproc::rgslccorr:- Time start selected 117422980.75833491981
# rgsproc::rgslccorr:- Time stop selected  117552744.17265623808
# rgsproc::rgslccorr:- Selecting events from CCDNR==1
# rgsproc::rgslccorr:- selected 401 rows from source file CCDNR==1
# rgsproc::rgslccorr:- selected 483 rows from background file CCDNR==1
# rgsproc::rgslccorr:- Calculating source area for CCDNR==1
# rgsproc::rgslccorr:- Calculating background area for CCDNR==1
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==1...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==1...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 1 Counts= 401 Area= 0.0019261800250771473828
# rgsproc::rgslccorr:- Background: CCD 1 Counts= 483 Area= 0.0029597400385331777174
# rgsproc::rgslccorr:- Selecting events from CCDNR==2
# rgsproc::rgslccorr:- selected 499 rows from source file CCDNR==2
# rgsproc::rgslccorr:- selected 492 rows from background file CCDNR==2
# rgsproc::rgslccorr:- Calculating source area for CCDNR==2
# rgsproc::rgslccorr:- Calculating background area for CCDNR==2
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==2...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==2...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 2 Counts= 499 Area= 0.0018892440245962735784
# rgsproc::rgslccorr:- Background: CCD 2 Counts= 492 Area= 0.0029326320381802555189
# rgsproc::rgslccorr:- Selecting events from CCDNR==3
# rgsproc::rgslccorr:- selected 666 rows from source file CCDNR==3
# rgsproc::rgslccorr:- selected 426 rows from background file CCDNR==3
# rgsproc::rgslccorr:- Calculating source area for CCDNR==3
# rgsproc::rgslccorr:- Calculating background area for CCDNR==3
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==3...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==3...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 3 Counts= 666 Area= 0.0017582400228907182904
# rgsproc::rgslccorr:- Background: CCD 3 Counts= 426 Area= 0.0027252720354806131767
# rgsproc::rgslccorr:- Selecting events from CCDNR==4
# rgsproc::rgslccorr:- selected 0 rows from source file CCDNR==4
# rgsproc::rgslccorr:- selected 0 rows from background file CCDNR==4
# rgsproc::rgslccorr:- Calculating source area for CCDNR==4
# rgsproc::rgslccorr:- Calculating background area for CCDNR==4
# rgsproc::rgslccorr:- Selecting events from CCDNR==5
# rgsproc::rgslccorr:- selected 418 rows from source file CCDNR==5
# rgsproc::rgslccorr:- selected 252 rows from background file CCDNR==5
# rgsproc::rgslccorr:- Calculating source area for CCDNR==5
# rgsproc::rgslccorr:- Calculating background area for CCDNR==5
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==5...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==5...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 5 Counts= 418 Area= 0.0015188040197734748588
# rgsproc::rgslccorr:- Background: CCD 5 Counts= 252 Area= 0.002237544029130829424
# rgsproc::rgslccorr:- Selecting events from CCDNR==6
# rgsproc::rgslccorr:- selected 464 rows from source file CCDNR==6
# rgsproc::rgslccorr:- selected 383 rows from background file CCDNR==6
# rgsproc::rgslccorr:- Calculating source area for CCDNR==6
# rgsproc::rgslccorr:- Calculating background area for CCDNR==6
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==6...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==6...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 6 Counts= 464 Area= 0.0014359680186950239678
# rgsproc::rgslccorr:- Background: CCD 6 Counts= 383 Area= 0.0021558960280678449509
# rgsproc::rgslccorr:- Selecting events from CCDNR==7
# rgsproc::rgslccorr:- selected 702 rows from source file CCDNR==7
# rgsproc::rgslccorr:- selected 1002 rows from background file CCDNR==7
# rgsproc::rgslccorr:- Calculating source area for CCDNR==7
# rgsproc::rgslccorr:- Calculating background area for CCDNR==7
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==7...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==7...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 7 Counts= 702 Area= 0.0013046400169852503687
# rgsproc::rgslccorr:- Background: CCD 7 Counts= 1002 Area= 0.0019556640254610028508
# rgsproc::rgslccorr:- Selecting events from CCDNR==8
# rgsproc::rgslccorr:- selected 226 rows from source file CCDNR==8
# rgsproc::rgslccorr:- selected 294 rows from background file CCDNR==8
# rgsproc::rgslccorr:- Calculating source area for CCDNR==8
# rgsproc::rgslccorr:- Calculating background area for CCDNR==8
# rgsproc::rgslccorr:- Dead Time correction for CCDNR==8...
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating Count Rates...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Calculating  lightcurve errors...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Backscale correction for CCDNR==8...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Source: CCD 8 Counts= 226 Area= 0.0011564640150561308809
# rgsproc::rgslccorr:- Background: CCD 8 Counts= 294 Area= 0.0017996040234292407563
# rgsproc::rgslccorr:- Selecting events from CCDNR==9
# rgsproc::rgslccorr:- selected 0 rows from source file CCDNR==9
# rgsproc::rgslccorr:- selected 0 rows from background file CCDNR==9
# rgsproc::rgslccorr:- Calculating source area for CCDNR==9
# rgsproc::rgslccorr:- Calculating background area for CCDNR==9
# rgsproc::rgslccorr:- Adding source lightcurves for each CCD...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Adding background lightcurves for each CCD...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Next CCD: Src counts 401 Src Area 0.0019261800250771473828
# rgsproc::rgslccorr:- Next CCD: Src counts 499 Src Area 0.0018892440245962735784
# rgsproc::rgslccorr:- Next CCD: Src counts 666 Src Area 0.0017582400228907182904
# rgsproc::rgslccorr:- Next CCD: Src counts 418 Src Area 0.0015188040197734748588
# rgsproc::rgslccorr:- Next CCD: Src counts 464 Src Area 0.0014359680186950239678
# rgsproc::rgslccorr:- Next CCD: Src counts 702 Src Area 0.0013046400169852503687
# rgsproc::rgslccorr:- Next CCD: Src counts 226 Src Area 0.0011564640150561308809
# rgsproc::rgslccorr:- Next CCD Bkg counts 483 Bkg Area 0.0029597400385331777174
# rgsproc::rgslccorr:- Next CCD Bkg counts 492 Bkg Area 0.0029326320381802555189
# rgsproc::rgslccorr:- Next CCD Bkg counts 426 Bkg Area 0.0027252720354806131767
# rgsproc::rgslccorr:- Next CCD Bkg counts 252 Bkg Area 0.002237544029130829424
# rgsproc::rgslccorr:- Next CCD Bkg counts 383 Bkg Area 0.0021558960280678449509
# rgsproc::rgslccorr:- Next CCD Bkg counts 1002 Bkg Area 0.0019556640254610028508
# rgsproc::rgslccorr:- Next CCD Bkg counts 294 Bkg Area 0.0017996040234292407563
# rgsproc::rgslccorr:- Mean BACKSCALE 0.6563923598178079688
# rgsproc::rgslccorr:- subtracting background lightcurve...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Creating output file...
# rgsproc::rgslccorr:- done.
# rgsproc::rgslccorr:- Deleting temporary files and cleaning memory...
# rgsproc::rgslccorr:- done.
# rgsproc:- rgslccorr (rgslccorr-0.57.2)  [xmmsas_20230412_1735-21.0.0] ended:    2024-01-02T16:04:02.000
# rgsproc:- rgsproc (rgsproc-1.37)  [xmmsas_20230412_1735-21.0.0] ended:    2024-01-02T16:04:02.000
# ** rgsproc: warning (SummaryOfWarnings),
#    warning ArgumentIgnored silently occurred 47 times
#    warning BadPixDiscrepancy silently occurred 8 times
#    warning NoFilteredEvents silently occurred 4 times
#    warning badPrimeRate silently occurred 1 times
#    warning binning  silently occurred 212552 times
#    warning outside range silently occurred 212552 times

# %%
# Combine RGS 1 & 2 Spectra
# SAS Command
cmd        = "rgscombine" # SAS task to be executed                  

# Arguments of SAS Command
inargs = ['pha=P0101440801R1S004SRSPEC1001.FIT P0101440801R2S005SRSPEC1001.FIT', 'rmf=P0101440801R1S004RSPMAT1001.FIT P0101440801R2S005RSPMAT1001.FIT'] 

# Execute the SAS task to obtain RGS products
wrap(cmd, inargs).run()
# Out:
# Executing:
# rgscombine filepha='' filebkg='' filermf='' min='4' max='40' bins='3600' pha='P0101440801R1S004SRSPEC1001.FIT P0101440801R2S005SRSPEC1001.FIT' rmf='P0101440801R1S004RSPMAT1001.FIT P0101440801R2S005RSPMAT1001.FIT' bkg='' rmfgrid='4000'
# rgscombine:- Executing (routine): rgscombine filepha='' filebkg='' filermf='' min=4 max=40 bins=3600 pha='P0101440801R1S004SRSPEC1001.FIT P0101440801R2S005SRSPEC1001.FIT' rmf='P0101440801R1S004RSPMAT1001.FIT P0101440801R2S005RSPMAT1001.FIT' bkg='' rmfgrid=4000  -w 1 -V 4
# rgscombine:- rgscombine (rgscombine-1.4.1)  [xmmsas_20230412_1735-21.0.0] started:  2024-09-12T20:26:35.000
# ** rgscombine: warning (Filename parameter), Using default name
# rgscombine:- rgscombine (rgscombine-1.4.1)  [xmmsas_20230412_1735-21.0.0] ended:    2024-09-12T20:26:36.000
